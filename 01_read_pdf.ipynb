# %%
# 01_read_pdf.ipynb
# For each text in the CSV extracted in the script '01_read_pdf', it requests the LLM to identify the date.

# %%
# Force to reload extrernal modules every new cell execution
# %reload_ext autoreload
# %autoreload 2

# %%
### IMPORT ###
from pathlib import Path
import csv
from datetime import datetime
import pandas as pd
import PyPDF2

# %%
### LOCAL IMPORT ###
from config import config_reader
from utilities import list_files_by_type, list_subdirectories

# %%
### GLOBALS ###
yaml_config = config_reader.config_read_yaml("config.yml", "config")
download_dir = str(yaml_config["DOWNLOAD_DIR"])
guue_dir = str(yaml_config["GUUE_DIR"])
data_dir = str(yaml_config["DATA_DIR"])
csv_sep = str(yaml_config["CSV_SEP"])
ted_url = str(yaml_config["TED_URL"])
bid_file_text = str(yaml_config["FILE_BID_TEXT"]) # output
dic_lan = {"DE":0, "ES":0, "FR":0, "IT":1, "PT":0} # <-- INPUT: set 1 for the desired language; set only one language at time
dic_markers = {"DE":[], "ES":[], "FR":[], "IT":["Modalità di apertura delle offerte", "Sezione VI: Altre informazioni"], "PT":[]} # <-- INPUT: for each language, set start and end text markers
year_start = int(yaml_config["YEAR_START"])
year_end = int(yaml_config["YEAR_END"])
years_list = list(range(year_start, year_end + 1))
log_pdf = str(yaml_config["LOG_PDF_EXTRACTION"]) 
log_pdf_header = str(yaml_config["LOG_PDF_EXTRACTION_HEADER"])

# %% [markdown]
# ## FUNCTIONS

# %%
### FUNCTIONS ###
def extract_text_by_line(pdf_path: str) -> str:
    """
    Extracts and prints the text from a PDF file, line by line.

    Args:
        pdf_path (str): The path to the PDF file to be processed.

    Returns:
        str: Returns None if the file could not be opened, or if no text could be extracted.
    """
    # Initialize a list to hold all extracted text
    full_text = [] # Text of all lines in the PDF
    header_text = [] # Text in PDF header (to be found and avoided as footer)
    try:
        # Open the PDF file in binary read mode
        with open(pdf_path, 'rb') as file:
            # Create a PDF reader object
            pdf_reader = PyPDF2.PdfReader(file)
            
            # Loop through each page in the PDF
            for page_num, page in enumerate(pdf_reader.pages):
                # Extract text from the page
                page_text = page.extract_text()
                
                # Check if text was successfully extracted
                if page_text:
                    # Loop each line of text inside page_text
                    line_count = 0 # to detect header
                    parts_header = None
                    for line in page_text.split('\n'):
                        line_count+=1
                        # print("Line count:",line_count) # debug
                        # print("Line text:",line) # debug
                        if line_count <= 3:
                            header_text.append(line) # Trace the header text
                            if line_count == 1: # Special text in line 1 (header: GU/S S148 -> footer: 03/08/2022 S148)
                                parts_header = line.split(" ")
                                for part in parts_header:
                                    header_text.append(part)
                            if line_count == 2:
                                header_text.append(line)
                                h2 = f"{line} {parts_header[1]}"
                                header_text.append(h2)
                        if line_count > 3: # skip header text
                            if ted_url in line:
                                continue
                            else:
                                if line not in header_text: # not in header_text -> avoid the footer
                                    full_text.append(line)
                else:
                    print(f"Text could not be extracted from page {page_num + 1}")
    except FileNotFoundError:
        print(f"ERROR! File '{pdf_path}'. Error: not found.")
    except Exception as e:
        print(f"ERROR! File '{pdf_path}'. Error: {e}")
    finally:
        return full_text

# %%
def extract_elements_between_markers(string_list:list, start_marker:str, end_marker:str) -> list: 
    """
    Extracts a sublist of elements from the given list of strings, starting from the element that contains the start_marker and ending just before the element that contains the end_marker.

    Args:
        string_list (list of str): The list of strings to be processed.
        start_marker (str): The substring that marks the start of the extraction.
        end_marker (str): The substring that marks the end of the extraction.

    Returns:
        list of str: A sublist of the original list, containing elements between the start and end markers.
    """
    # Find the index of the start marker
    start_index = next((index for index, item in enumerate(string_list) if start_marker in item), None)
    # Find the index of the end marker
    end_index = next((index for index, item in enumerate(string_list) if end_marker in item), None)

    # Return the sublist if both markers are found
    if start_index is not None and end_index is not None and start_index < end_index:
        return string_list[start_index + 1:end_index]
    else:
        return []  # Return an empty list if markers are not found or in the wrong order

# %%
def filename_to_caseid(filename:str) -> str:
    """ 
    Given the name of a file, derive its case ID merging YEAR and file ID.

    Args:
        filename (str): The string containing the file name.
    
    Returns:
        str: YEARID
    """
    # Split the filename by dashes
    parts = filename.split('-')
    
    # Extract the first element
    first_element = parts[0]
    
    # Extract the third element and remove leading zeros
    third_element = parts[2].lstrip('0')
    
    # Concatenate the two parts
    result = first_element + third_element
    
    return result

# %% [markdown]
# ## MAIN

# %%
### MAIN ###
print()
print("*** PROGRAM START ***")
print()

start_time = datetime.now().replace(microsecond=0)
print("Start process:", str(start_time))
print()
# Out:
# *** PROGRAM START ***
#
# Start process: 2024-09-02 11:28:30

# %%
# print(yaml_config) # debug

# %%
print(">> Settings")
path_guee = Path(download_dir) / guue_dir
list_dirs = list_subdirectories(path_guee)
list_dirs_len = len(list_dirs)
print(f"Directories with GUUE found ({list_dirs_len}): {list_dirs}")
print("Years list")
print(years_list)
lang_code = None
key_with_value_1 = [key for key, value in dic_lan.items() if value == 1]
if key_with_value_1: 
    lang_code = key_with_value_1[0]
print("Desired language code for markers:", lang_code)
bid_opening_marker_start = dic_markers[lang_code][0]
bid_opening_marker_end = dic_markers[lang_code][1]
print("Markers (start):", bid_opening_marker_start)
print("Markers (end):", bid_opening_marker_end)
# Out:
# >> Settings
# Directories with GUUE found (5): ['DE', 'ES', 'FR', 'IT', 'PT']
# Years list
# [2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Desired language code for markers: IT
# Markers (start): Modalità di apertura delle offerte
# Markers (end): Sezione VI: Altre informazioni

# %%
print(">> Preparing the output timing log")
path_log = Path(data_dir) / log_pdf
if not path_log.exists():
    # If the file does not exist, create it with the specified header
    with path_log.open(mode='w') as fp:
        fp.write(f"{log_pdf_header}\n")
    print(f"File created with header: {path_log}")
else:
    print(f"The file already exists: {path_log}")
# Out:
# >> Preparing the output timing log
# The file already exists: data/ted_log_pdf_extraction.csv

# %%
# Create list of PDF files of a language
print(">> Listing PDF files")
list_pdf_files = []
path_guee_lang = Path(download_dir) / guue_dir / lang_code
print("Directory (lang):", path_guee_lang)
for year_value in years_list:
    path_guee_lang_year = path_guee_lang / str(year_value)
    list_pdf_files_y = list_files_by_type(path_guee_lang_year, "pdf")
    list_pdf_files_y_len = len(list_pdf_files_y)
    print(f"Files found for year {year_value}: {list_pdf_files_y_len}")
    list_pdf_files.extend(list_pdf_files_y)
list_pdf_files_len = len(list_pdf_files)
print("Total files found:", list_pdf_files_len)
# print("Files:", list_pdf_files) # debug
# Out:
# >> Listing PDF files
# Directory (lang): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT
# Files found for year 2016: 3052
# Files found for year 2017: 3581
# Files found for year 2018: 3671
# Files found for year 2019: 3822
# Files found for year 2020: 3777
# Files found for year 2021: 4557
# Files found for year 2022: 4783
# Total files found: 27243

# %%
# Parse the files
print(">> Parsing PDF files")

i = 0

list_bid_opening_dic = [] # Container of texts of interest extracted from PDFs

for pdf_file in list_pdf_files:
    i+=1
    print(f"[{i} / {list_pdf_files_len}]")
    print("Reading (path):", str(pdf_file))
    text_list = extract_text_by_line(pdf_file) # Extracts all lines of text from the PDF
    text_list_len = len(text_list)
    # print(text_list) # debug

    # prepare the dictionary output for the actual PDF
    file_name = pdf_file.name # get only the file name in str
    case_id  = filename_to_caseid(file_name) # get the case_id from the file_name
    dic_bid_opening = {"file_name":file_name, "case_id":case_id, "text": None}
    
    print(f"Case ID derived from file name '{file_name}': {case_id}")
    print("Lines found in the PDF:", text_list_len)

    # get only lines about bid opening
    if text_list_len > 0:
        marker_list = extract_elements_between_markers(text_list, bid_opening_marker_start, bid_opening_marker_end) 
        marker_list_len = len(marker_list)
        # print(marker_list) # debug
        print("Bid opening strings found between markers:", marker_list_len)
        
        if marker_list_len > 0:
            marker_text = "|".join(marker_list)
            # print(marker_text) # debug
            dic_bid_opening["text"] = marker_text

    # save the file and the text found in bid opening section into a dictionary
    list_bid_opening_dic.append(dic_bid_opening)
    print()
# Out:
# >> Parsing PDF files
# [1 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000108-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000108-it-ts.pdf': 2016108
# Lines found in the PDF: 235
# Bid opening strings found between markers: 7
#
# [2 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000236-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000236-it-ts.pdf': 2016236
# Lines found in the PDF: 629
# Bid opening strings found between markers: 7
#
# [3 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000277-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000277-it-ts.pdf': 2016277
# Lines found in the PDF: 209
# Bid opening strings found between markers: 2
#
# [4 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000307-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000307-it-ts.pdf': 2016307
# Lines found in the PDF: 229
# Bid opening strings found between markers: 3
#
# [5 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000320-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000320-it-ts.pdf': 2016320
# Lines found in the PDF: 145
# Bid opening strings found between markers: 7
#
# [6 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000329-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000329-it-ts.pdf': 2016329
# Lines found in the PDF: 150
# Bid opening strings found between markers: 6
#
# [7 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000541-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000541-it-ts.pdf': 2016541
# Lines found in the PDF: 387
# Bid opening strings found between markers: 0
#
# [8 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000554-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000554-it-ts.pdf': 2016554
# Lines found in the PDF: 211
# Bid opening strings found between markers: 4
#
# [9 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000558-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000558-it-ts.pdf': 2016558
# Lines found in the PDF: 171
# Bid opening strings found between markers: 5
#
# [10 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000569-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000569-it-ts.pdf': 2016569
# Lines found in the PDF: 173
# Bid opening strings found between markers: 1
#
# [11 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000570-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000570-it-ts.pdf': 2016570
# Lines found in the PDF: 193
# Bid opening strings found between markers: 5
#
# [12 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000587-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000587-it-ts.pdf': 2016587
# Lines found in the PDF: 137
# Bid opening strings found between markers: 1
#
# [13 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000600-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000600-it-ts.pdf': 2016600
# Lines found in the PDF: 128
# Bid opening strings found between markers: 0
#
# [14 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000605-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000605-it-ts.pdf': 2016605
# Lines found in the PDF: 184
# Bid opening strings found between markers: 3
#
# [15 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000610-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000610-it-ts.pdf': 2016610
# Lines found in the PDF: 187
# Bid opening strings found between markers: 6
#
# [16 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000645-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000645-it-ts.pdf': 2016645
# Lines found in the PDF: 205
# Bid opening strings found between markers: 8
#
# [17 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000648-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000648-it-ts.pdf': 2016648
# Lines found in the PDF: 190
# Bid opening strings found between markers: 6
#
# [18 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000655-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000655-it-ts.pdf': 2016655
# Lines found in the PDF: 239
# Bid opening strings found between markers: 6
#
# [19 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000705-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000705-it-ts.pdf': 2016705
# Lines found in the PDF: 145
# Bid opening strings found between markers: 6
#
# [20 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000707-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000707-it-ts.pdf': 2016707
# Lines found in the PDF: 179
# Bid opening strings found between markers: 4
#
# [21 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS001-00000719-it-ts.pdf
# Case ID derived from file name '2016-OJS001-00000719-it-ts.pdf': 2016719
# Lines found in the PDF: 157
# Bid opening strings found between markers: 0
#
# [22 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS002-00001192-it-ts.pdf
# Case ID derived from file name '2016-OJS002-00001192-it-ts.pdf': 20161192
# Lines found in the PDF: 172
# Bid opening strings found between markers: 6
#
# [23 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS002-00001194-it-ts.pdf
# Case ID derived from file name '2016-OJS002-00001194-it-ts.pdf': 20161194
# Lines found in the PDF: 414
# Bid opening strings found between markers: 6
#
# [24 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS002-00001328-it-ts.pdf
# Case ID derived from file name '2016-OJS002-00001328-it-ts.pdf': 20161328
# Lines found in the PDF: 147
# Bid opening strings found between markers: 0
#
# [25 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS002-00001655-it-ts.pdf
# Case ID derived from file name '2016-OJS002-00001655-it-ts.pdf': 20161655
# Lines found in the PDF: 191
# Bid opening strings found between markers: 7
#
# [26 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS002-00001684-it-ts.pdf
# Case ID derived from file name '2016-OJS002-00001684-it-ts.pdf': 20161684
# Lines found in the PDF: 225
# Bid opening strings found between markers: 4
#
# [27 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS002-00001702-it-ts.pdf
# Case ID derived from file name '2016-OJS002-00001702-it-ts.pdf': 20161702
# Lines found in the PDF: 224
# Bid opening strings found between markers: 8
#
# [28 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS002-00001707-it-ts.pdf
# Case ID derived from file name '2016-OJS002-00001707-it-ts.pdf': 20161707
# Lines found in the PDF: 163
# Bid opening strings found between markers: 5
#
# [29 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS002-00001716-it-ts.pdf
# Case ID derived from file name '2016-OJS002-00001716-it-ts.pdf': 20161716
# Lines found in the PDF: 133
# Bid opening strings found between markers: 4
#
# [30 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS002-00001720-it-ts.pdf
# Case ID derived from file name '2016-OJS002-00001720-it-ts.pdf': 20161720
# Lines found in the PDF: 291
# Bid opening strings found between markers: 6
#
# [31 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS002-00001725-it-ts.pdf
# Case ID derived from file name '2016-OJS002-00001725-it-ts.pdf': 20161725
# Lines found in the PDF: 277
# Bid opening strings found between markers: 0
#
# [32 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS002-00001762-it-ts.pdf
# Case ID derived from file name '2016-OJS002-00001762-it-ts.pdf': 20161762
# Lines found in the PDF: 209
# Bid opening strings found between markers: 6
#
# [33 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS003-00002417-it-ts.pdf
# Case ID derived from file name '2016-OJS003-00002417-it-ts.pdf': 20162417
# Lines found in the PDF: 177
# Bid opening strings found between markers: 3
#
# [34 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS003-00002418-it-ts.pdf
# Case ID derived from file name '2016-OJS003-00002418-it-ts.pdf': 20162418
# Lines found in the PDF: 157
# Bid opening strings found between markers: 3
#
# [35 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS003-00002419-it-ts.pdf
# Case ID derived from file name '2016-OJS003-00002419-it-ts.pdf': 20162419
# Lines found in the PDF: 167
# Bid opening strings found between markers: 3
#
# [36 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS003-00002805-it-ts.pdf
# Case ID derived from file name '2016-OJS003-00002805-it-ts.pdf': 20162805
# Lines found in the PDF: 140
# Bid opening strings found between markers: 3
#
# [37 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS003-00002806-it-ts.pdf
# Case ID derived from file name '2016-OJS003-00002806-it-ts.pdf': 20162806
# Lines found in the PDF: 155
# Bid opening strings found between markers: 5
#
# [38 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS003-00002808-it-ts.pdf
# Case ID derived from file name '2016-OJS003-00002808-it-ts.pdf': 20162808
# Lines found in the PDF: 115
# Bid opening strings found between markers: 1
#
# [39 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS003-00002816-it-ts.pdf
# Case ID derived from file name '2016-OJS003-00002816-it-ts.pdf': 20162816
# Lines found in the PDF: 201
# Bid opening strings found between markers: 0
#
# [40 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS003-00002872-it-ts.pdf
# Case ID derived from file name '2016-OJS003-00002872-it-ts.pdf': 20162872
# Lines found in the PDF: 185
# Bid opening strings found between markers: 6
#
# [41 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS003-00002882-it-ts.pdf
# Case ID derived from file name '2016-OJS003-00002882-it-ts.pdf': 20162882
# Lines found in the PDF: 130
# Bid opening strings found between markers: 6
#
# [42 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS004-00003443-it-ts.pdf
# Case ID derived from file name '2016-OJS004-00003443-it-ts.pdf': 20163443
# Lines found in the PDF: 151
# Bid opening strings found between markers: 9
#
# [43 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS004-00003444-it-ts.pdf
# Case ID derived from file name '2016-OJS004-00003444-it-ts.pdf': 20163444
# Lines found in the PDF: 152
# Bid opening strings found between markers: 9
#
# [44 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS004-00003445-it-ts.pdf
# Case ID derived from file name '2016-OJS004-00003445-it-ts.pdf': 20163445
# Lines found in the PDF: 223
# Bid opening strings found between markers: 8
#
# [45 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS004-00004009-it-ts.pdf
# Case ID derived from file name '2016-OJS004-00004009-it-ts.pdf': 20164009
# Lines found in the PDF: 211
# Bid opening strings found between markers: 4
#
# [46 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS004-00004019-it-ts.pdf
# Case ID derived from file name '2016-OJS004-00004019-it-ts.pdf': 20164019
# Lines found in the PDF: 102
# Bid opening strings found between markers: 0
#
# [47 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS004-00004021-it-ts.pdf
# Case ID derived from file name '2016-OJS004-00004021-it-ts.pdf': 20164021
# Lines found in the PDF: 120
# Bid opening strings found between markers: 0
#
# [48 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS004-00004026-it-ts.pdf
# Case ID derived from file name '2016-OJS004-00004026-it-ts.pdf': 20164026
# Lines found in the PDF: 166
# Bid opening strings found between markers: 1
#
# [49 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS004-00004029-it-ts.pdf
# Case ID derived from file name '2016-OJS004-00004029-it-ts.pdf': 20164029
# Lines found in the PDF: 110
# Bid opening strings found between markers: 1
#
# [50 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS004-00004078-it-ts.pdf
# Case ID derived from file name '2016-OJS004-00004078-it-ts.pdf': 20164078
# Lines found in the PDF: 121
# Bid opening strings found between markers: 0
#
# [51 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS005-00005377-it-ts.pdf
# Case ID derived from file name '2016-OJS005-00005377-it-ts.pdf': 20165377
# Lines found in the PDF: 163
# Bid opening strings found between markers: 10
#
# [52 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS005-00005380-it-ts.pdf
# Case ID derived from file name '2016-OJS005-00005380-it-ts.pdf': 20165380
# Lines found in the PDF: 228
# Bid opening strings found between markers: 5
#
# [53 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS006-00006827-it-ts.pdf
# Case ID derived from file name '2016-OJS006-00006827-it-ts.pdf': 20166827
# Lines found in the PDF: 298
# Bid opening strings found between markers: 6
#
# [54 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS006-00006848-it-ts.pdf
# Case ID derived from file name '2016-OJS006-00006848-it-ts.pdf': 20166848
# Lines found in the PDF: 153
# Bid opening strings found between markers: 3
#
# [55 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS006-00006861-it-ts.pdf
# Case ID derived from file name '2016-OJS006-00006861-it-ts.pdf': 20166861
# Lines found in the PDF: 130
# Bid opening strings found between markers: 6
#
# [56 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS006-00006883-it-ts.pdf
# Case ID derived from file name '2016-OJS006-00006883-it-ts.pdf': 20166883
# Lines found in the PDF: 472
# Bid opening strings found between markers: 7
#
# [57 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS006-00006884-it-ts.pdf
# Case ID derived from file name '2016-OJS006-00006884-it-ts.pdf': 20166884
# Lines found in the PDF: 116
# Bid opening strings found between markers: 1
#
# [58 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS006-00006886-it-ts.pdf
# Case ID derived from file name '2016-OJS006-00006886-it-ts.pdf': 20166886
# Lines found in the PDF: 183
# Bid opening strings found between markers: 5
#
# [59 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS006-00006903-it-ts.pdf
# Case ID derived from file name '2016-OJS006-00006903-it-ts.pdf': 20166903
# Lines found in the PDF: 291
# Bid opening strings found between markers: 6
#
# [60 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS007-00008277-it-ts.pdf
# Case ID derived from file name '2016-OJS007-00008277-it-ts.pdf': 20168277
# Lines found in the PDF: 258
# Bid opening strings found between markers: 7
#
# [61 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS007-00008286-it-ts.pdf
# Case ID derived from file name '2016-OJS007-00008286-it-ts.pdf': 20168286
# Lines found in the PDF: 202
# Bid opening strings found between markers: 7
#
# [62 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS007-00008290-it-ts.pdf
# Case ID derived from file name '2016-OJS007-00008290-it-ts.pdf': 20168290
# Lines found in the PDF: 213
# Bid opening strings found between markers: 6
#
# [63 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS007-00008292-it-ts.pdf
# Case ID derived from file name '2016-OJS007-00008292-it-ts.pdf': 20168292
# Lines found in the PDF: 139
# Bid opening strings found between markers: 5
#
# [64 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS007-00008443-it-ts.pdf
# Case ID derived from file name '2016-OJS007-00008443-it-ts.pdf': 20168443
# Lines found in the PDF: 149
# Bid opening strings found between markers: 7
#
# [65 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS008-00009420-it-ts.pdf
# Case ID derived from file name '2016-OJS008-00009420-it-ts.pdf': 20169420
# Lines found in the PDF: 190
# Bid opening strings found between markers: 7
#
# [66 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS008-00009452-it-ts.pdf
# Case ID derived from file name '2016-OJS008-00009452-it-ts.pdf': 20169452
# Lines found in the PDF: 213
# Bid opening strings found between markers: 7
#
# [67 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS008-00009456-it-ts.pdf
# Case ID derived from file name '2016-OJS008-00009456-it-ts.pdf': 20169456
# Lines found in the PDF: 191
# Bid opening strings found between markers: 6
#
# [68 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS008-00009503-it-ts.pdf
# Case ID derived from file name '2016-OJS008-00009503-it-ts.pdf': 20169503
# Lines found in the PDF: 227
# Bid opening strings found between markers: 6
#
# [69 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS008-00009964-it-ts.pdf
# Case ID derived from file name '2016-OJS008-00009964-it-ts.pdf': 20169964
# Lines found in the PDF: 155
# Bid opening strings found between markers: 6
#
# [70 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS008-00009967-it-ts.pdf
# Case ID derived from file name '2016-OJS008-00009967-it-ts.pdf': 20169967
# Lines found in the PDF: 145
# Bid opening strings found between markers: 7
#
# [71 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS009-00011068-it-ts.pdf
# Case ID derived from file name '2016-OJS009-00011068-it-ts.pdf': 201611068
# Lines found in the PDF: 202
# Bid opening strings found between markers: 0
#
# [72 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS009-00011216-it-ts.pdf
# Case ID derived from file name '2016-OJS009-00011216-it-ts.pdf': 201611216
# Lines found in the PDF: 183
# Bid opening strings found between markers: 6
#
# [73 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS009-00011289-it-ts.pdf
# Case ID derived from file name '2016-OJS009-00011289-it-ts.pdf': 201611289
# Lines found in the PDF: 182
# Bid opening strings found between markers: 1
#
# [74 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS009-00011707-it-ts.pdf
# Case ID derived from file name '2016-OJS009-00011707-it-ts.pdf': 201611707
# Lines found in the PDF: 229
# Bid opening strings found between markers: 5
#
# [75 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS009-00011715-it-ts.pdf
# Case ID derived from file name '2016-OJS009-00011715-it-ts.pdf': 201611715
# Lines found in the PDF: 143
# Bid opening strings found between markers: 8
#
# [76 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS009-00011756-it-ts.pdf
# Case ID derived from file name '2016-OJS009-00011756-it-ts.pdf': 201611756
# Lines found in the PDF: 147
# Bid opening strings found between markers: 3
#
# [77 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS009-00011809-it-ts.pdf
# Case ID derived from file name '2016-OJS009-00011809-it-ts.pdf': 201611809
# Lines found in the PDF: 264
# Bid opening strings found between markers: 9
#
# [78 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS009-00011813-it-ts.pdf
# Case ID derived from file name '2016-OJS009-00011813-it-ts.pdf': 201611813
# Lines found in the PDF: 172
# Bid opening strings found between markers: 9
#
# [79 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS010-00012931-it-ts.pdf
# Case ID derived from file name '2016-OJS010-00012931-it-ts.pdf': 201612931
# Lines found in the PDF: 336
# Bid opening strings found between markers: 0
#
# [80 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS010-00012961-it-ts.pdf
# Case ID derived from file name '2016-OJS010-00012961-it-ts.pdf': 201612961
# Lines found in the PDF: 412
# Bid opening strings found between markers: 3
#
# [81 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS010-00012967-it-ts.pdf
# Case ID derived from file name '2016-OJS010-00012967-it-ts.pdf': 201612967
# Lines found in the PDF: 387
# Bid opening strings found between markers: 3
#
# [82 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS010-00012986-it-ts.pdf
# Case ID derived from file name '2016-OJS010-00012986-it-ts.pdf': 201612986
# Lines found in the PDF: 295
# Bid opening strings found between markers: 3
#
# [83 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS010-00013517-it-ts.pdf
# Case ID derived from file name '2016-OJS010-00013517-it-ts.pdf': 201613517
# Lines found in the PDF: 150
# Bid opening strings found between markers: 8
#
# [84 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS010-00013518-it-ts.pdf
# Case ID derived from file name '2016-OJS010-00013518-it-ts.pdf': 201613518
# Lines found in the PDF: 182
# Bid opening strings found between markers: 6
#
# [85 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS010-00013522-it-ts.pdf
# Case ID derived from file name '2016-OJS010-00013522-it-ts.pdf': 201613522
# Lines found in the PDF: 145
# Bid opening strings found between markers: 7
#
# [86 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS010-00013525-it-ts.pdf
# Case ID derived from file name '2016-OJS010-00013525-it-ts.pdf': 201613525
# Lines found in the PDF: 184
# Bid opening strings found between markers: 6
#
# [87 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS010-00013546-it-ts.pdf
# Case ID derived from file name '2016-OJS010-00013546-it-ts.pdf': 201613546
# Lines found in the PDF: 202
# Bid opening strings found between markers: 7
#
# [88 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS010-00013618-it-ts.pdf
# Case ID derived from file name '2016-OJS010-00013618-it-ts.pdf': 201613618
# Lines found in the PDF: 240
# Bid opening strings found between markers: 5
#
# [89 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS010-00013639-it-ts.pdf
# Case ID derived from file name '2016-OJS010-00013639-it-ts.pdf': 201613639
# Lines found in the PDF: 110
# Bid opening strings found between markers: 1
#
# [90 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS011-00014427-it-ts.pdf
# Case ID derived from file name '2016-OJS011-00014427-it-ts.pdf': 201614427
# Lines found in the PDF: 136
# Bid opening strings found between markers: 0
#
# [91 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS011-00014554-it-ts.pdf
# Case ID derived from file name '2016-OJS011-00014554-it-ts.pdf': 201614554
# Lines found in the PDF: 135
# Bid opening strings found between markers: 4
#
# [92 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS011-00015326-it-ts.pdf
# Case ID derived from file name '2016-OJS011-00015326-it-ts.pdf': 201615326
# Lines found in the PDF: 179
# Bid opening strings found between markers: 5
#
# [93 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS011-00015327-it-ts.pdf
# Case ID derived from file name '2016-OJS011-00015327-it-ts.pdf': 201615327
# Lines found in the PDF: 142
# Bid opening strings found between markers: 3
#
# [94 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS011-00015509-it-ts.pdf
# Case ID derived from file name '2016-OJS011-00015509-it-ts.pdf': 201615509
# Lines found in the PDF: 307
# Bid opening strings found between markers: 9
#
# [95 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS011-00015514-it-ts.pdf
# Case ID derived from file name '2016-OJS011-00015514-it-ts.pdf': 201615514
# Lines found in the PDF: 173
# Bid opening strings found between markers: 6
#
# [96 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS011-00015517-it-ts.pdf
# Case ID derived from file name '2016-OJS011-00015517-it-ts.pdf': 201615517
# Lines found in the PDF: 185
# Bid opening strings found between markers: 7
#
# [97 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS011-00015520-it-ts.pdf
# Case ID derived from file name '2016-OJS011-00015520-it-ts.pdf': 201615520
# Lines found in the PDF: 241
# Bid opening strings found between markers: 6
#
# [98 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS011-00015530-it-ts.pdf
# Case ID derived from file name '2016-OJS011-00015530-it-ts.pdf': 201615530
# Lines found in the PDF: 183
# Bid opening strings found between markers: 3
#
# [99 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS011-00015531-it-ts.pdf
# Case ID derived from file name '2016-OJS011-00015531-it-ts.pdf': 201615531
# Lines found in the PDF: 157
# Bid opening strings found between markers: 6
#
# [100 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS012-00016209-it-ts.pdf
# Case ID derived from file name '2016-OJS012-00016209-it-ts.pdf': 201616209
# Lines found in the PDF: 128
# Bid opening strings found between markers: 0
#
# [101 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS012-00016726-it-ts.pdf
# Case ID derived from file name '2016-OJS012-00016726-it-ts.pdf': 201616726
# Lines found in the PDF: 142
# Bid opening strings found between markers: 3
#
# [102 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS012-00016729-it-ts.pdf
# Case ID derived from file name '2016-OJS012-00016729-it-ts.pdf': 201616729
# Lines found in the PDF: 132
# Bid opening strings found between markers: 4
#
# [103 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS012-00017122-it-ts.pdf
# Case ID derived from file name '2016-OJS012-00017122-it-ts.pdf': 201617122
# Lines found in the PDF: 487
# Bid opening strings found between markers: 7
#
# [104 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS012-00017147-it-ts.pdf
# Case ID derived from file name '2016-OJS012-00017147-it-ts.pdf': 201617147
# Lines found in the PDF: 160
# Bid opening strings found between markers: 3
#
# [105 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS012-00017249-it-ts.pdf
# Case ID derived from file name '2016-OJS012-00017249-it-ts.pdf': 201617249
# Lines found in the PDF: 160
# Bid opening strings found between markers: 3
#
# [106 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS013-00017806-it-ts.pdf
# Case ID derived from file name '2016-OJS013-00017806-it-ts.pdf': 201617806
# Lines found in the PDF: 538
# Bid opening strings found between markers: 9
#
# [107 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS013-00017811-it-ts.pdf
# Case ID derived from file name '2016-OJS013-00017811-it-ts.pdf': 201617811
# Lines found in the PDF: 128
# Bid opening strings found between markers: 0
#
# [108 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS013-00017823-it-ts.pdf
# Case ID derived from file name '2016-OJS013-00017823-it-ts.pdf': 201617823
# Lines found in the PDF: 113
# Bid opening strings found between markers: 2
#
# [109 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS013-00018737-it-ts.pdf
# Case ID derived from file name '2016-OJS013-00018737-it-ts.pdf': 201618737
# Lines found in the PDF: 193
# Bid opening strings found between markers: 7
#
# [110 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS013-00018738-it-ts.pdf
# Case ID derived from file name '2016-OJS013-00018738-it-ts.pdf': 201618738
# Lines found in the PDF: 96
# Bid opening strings found between markers: 0
#
# [111 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS013-00018739-it-ts.pdf
# ...
# Bid opening strings found between markers: 3
#
# [186 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS022-00035325-it-ts.pdf
# Case ID derived from file name '2016-OJS022-00035325-it-ts.pdf': 201635325
# Lines found in the PDF: 539
# Bid opening strings found between markers: 7
#
# [187 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS022-00035345-it-ts.pdf
# Case ID derived from file name '2016-OJS022-00035345-it-ts.pdf': 201635345
# Lines found in the PDF: 160
# Bid opening strings found between markers: 0
#
# [188 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036098-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036098-it-ts.pdf': 201636098
# Lines found in the PDF: 452
# Bid opening strings found between markers: 7
#
# [189 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036294-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036294-it-ts.pdf': 201636294
# Lines found in the PDF: 198
# Bid opening strings found between markers: 5
#
# [190 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036340-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036340-it-ts.pdf': 201636340
# Lines found in the PDF: 181
# Bid opening strings found between markers: 7
#
# [191 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036409-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036409-it-ts.pdf': 201636409
# Lines found in the PDF: 599
# Bid opening strings found between markers: 3
#
# [192 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036422-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036422-it-ts.pdf': 201636422
# Lines found in the PDF: 383
# Bid opening strings found between markers: 3
#
# [193 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036803-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036803-it-ts.pdf': 201636803
# Lines found in the PDF: 168
# Bid opening strings found between markers: 6
#
# [194 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036807-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036807-it-ts.pdf': 201636807
# Lines found in the PDF: 109
# Bid opening strings found between markers: 1
#
# [195 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036809-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036809-it-ts.pdf': 201636809
# Lines found in the PDF: 112
# Bid opening strings found between markers: 1
#
# [196 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036810-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036810-it-ts.pdf': 201636810
# Lines found in the PDF: 111
# Bid opening strings found between markers: 1
#
# [197 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036811-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036811-it-ts.pdf': 201636811
# Lines found in the PDF: 113
# Bid opening strings found between markers: 1
#
# [198 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036813-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036813-it-ts.pdf': 201636813
# Lines found in the PDF: 134
# Bid opening strings found between markers: 3
#
# [199 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036816-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036816-it-ts.pdf': 201636816
# Lines found in the PDF: 169
# Bid opening strings found between markers: 6
#
# [200 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036854-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036854-it-ts.pdf': 201636854
# Lines found in the PDF: 216
# Bid opening strings found between markers: 7
#
# [201 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036864-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036864-it-ts.pdf': 201636864
# Lines found in the PDF: 236
# Bid opening strings found between markers: 6
#
# [202 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036901-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036901-it-ts.pdf': 201636901
# Lines found in the PDF: 298
# Bid opening strings found between markers: 8
#
# [203 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00036956-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00036956-it-ts.pdf': 201636956
# Lines found in the PDF: 213
# Bid opening strings found between markers: 5
#
# [204 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00037010-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00037010-it-ts.pdf': 201637010
# Lines found in the PDF: 214
# Bid opening strings found between markers: 6
#
# [205 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00037018-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00037018-it-ts.pdf': 201637018
# Lines found in the PDF: 256
# Bid opening strings found between markers: 6
#
# [206 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS023-00037036-it-ts.pdf
# Case ID derived from file name '2016-OJS023-00037036-it-ts.pdf': 201637036
# Lines found in the PDF: 327
# Bid opening strings found between markers: 7
#
# [207 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS024-00038082-it-ts.pdf
# Case ID derived from file name '2016-OJS024-00038082-it-ts.pdf': 201638082
# Lines found in the PDF: 132
# Bid opening strings found between markers: 8
#
# [208 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS024-00038472-it-ts.pdf
# Case ID derived from file name '2016-OJS024-00038472-it-ts.pdf': 201638472
# Lines found in the PDF: 188
# Bid opening strings found between markers: 4
#
# [209 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS024-00038666-it-ts.pdf
# Case ID derived from file name '2016-OJS024-00038666-it-ts.pdf': 201638666
# Lines found in the PDF: 142
# Bid opening strings found between markers: 6
#
# [210 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS024-00038668-it-ts.pdf
# Case ID derived from file name '2016-OJS024-00038668-it-ts.pdf': 201638668
# Lines found in the PDF: 244
# Bid opening strings found between markers: 7
#
# [211 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS024-00038674-it-ts.pdf
# Case ID derived from file name '2016-OJS024-00038674-it-ts.pdf': 201638674
# Lines found in the PDF: 174
# Bid opening strings found between markers: 6
#
# [212 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS024-00038679-it-ts.pdf
# Case ID derived from file name '2016-OJS024-00038679-it-ts.pdf': 201638679
# Lines found in the PDF: 206
# Bid opening strings found between markers: 6
#
# [213 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS024-00038681-it-ts.pdf
# Case ID derived from file name '2016-OJS024-00038681-it-ts.pdf': 201638681
# Lines found in the PDF: 207
# Bid opening strings found between markers: 6
#
# [214 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS024-00038691-it-ts.pdf
# Case ID derived from file name '2016-OJS024-00038691-it-ts.pdf': 201638691
# Lines found in the PDF: 174
# Bid opening strings found between markers: 6
#
# [215 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS024-00038694-it-ts.pdf
# Case ID derived from file name '2016-OJS024-00038694-it-ts.pdf': 201638694
# Lines found in the PDF: 133
# Bid opening strings found between markers: 4
#
# [216 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS025-00039501-it-ts.pdf
# Case ID derived from file name '2016-OJS025-00039501-it-ts.pdf': 201639501
# Lines found in the PDF: 164
# Bid opening strings found between markers: 5
#
# [217 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS025-00039635-it-ts.pdf
# Case ID derived from file name '2016-OJS025-00039635-it-ts.pdf': 201639635
# Lines found in the PDF: 76
# Bid opening strings found between markers: 0
#
# [218 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS025-00039768-it-ts.pdf
# Case ID derived from file name '2016-OJS025-00039768-it-ts.pdf': 201639768
# Lines found in the PDF: 127
# Bid opening strings found between markers: 0
#
# [219 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS025-00039970-it-ts.pdf
# Case ID derived from file name '2016-OJS025-00039970-it-ts.pdf': 201639970
# Lines found in the PDF: 103
# Bid opening strings found between markers: 0
#
# [220 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS025-00040337-it-ts.pdf
# Case ID derived from file name '2016-OJS025-00040337-it-ts.pdf': 201640337
# Lines found in the PDF: 136
# Bid opening strings found between markers: 1
#
# [221 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS025-00040349-it-ts.pdf
# Case ID derived from file name '2016-OJS025-00040349-it-ts.pdf': 201640349
# Lines found in the PDF: 155
# Bid opening strings found between markers: 6
#
# [222 / 27243]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/IT/2016/2016-OJS025-00040352-it-ts.pdf

# %%
# Create a file with the texts extracted from the PDFs
print(">> Saving bid opening texts")
df_bid = pd.DataFrame.from_records(list_bid_opening_dic) # Create a dataframe from a list of dictionaries
df_bid = df_bid.sort_values(by='file_name')
# print(df_bid.head()) # debug
path_out = Path(data_dir) / bid_file_text
print("Path:", path_out)
df_bid.to_csv(path_out, sep=csv_sep, index=False, quoting=csv.QUOTE_ALL)
# Out:
# >> Saving bid opening texts
# Path: data/bid_opening_text.csv

# %%
# program end
end_time = datetime.now().replace(microsecond=0)
delta_time = end_time - start_time

# Save the timing
print(">> Saving timing to log")
csv_str = f"{lang_code};{str(start_time)};{str(end_time)};{str(delta_time)}\n"
with open(path_log, "a") as fp:
    fp.write(csv_str)
    
print()
print("End process:", end_time)
print("Time to finish:", delta_time)
print()

print()
print("*** PROGRAM END ***")
print()
# Out:
# End process: 2024-05-08 15:27:34
# Time to finish: 0:00:37
#
#
# *** PROGRAM END ***
