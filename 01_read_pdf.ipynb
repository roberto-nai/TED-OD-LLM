# %%
# 01_read_pdf.ipynb
# For each text in the CSV extracted in the script '01_read_pdf', it requests the LLM to identify the date.

# %%
# Force to reload extrernal modules every new cell execution
# %reload_ext autoreload
# %autoreload 2

# %%
### IMPORT ###
from pathlib import Path
import csv
from datetime import datetime
import pandas as pd
import PyPDF2
import fitz  # PyMuPDF

# %%
### LOCAL IMPORT ###
from config import config_reader
from utilities import list_files_by_type, list_subdirectories

# %%
### GLOBALS ###
yaml_config = config_reader.config_read_yaml("config.yml", "config")
download_dir = str(yaml_config["DOWNLOAD_DIR"])
guue_dir = str(yaml_config["GUUE_DIR"])
data_dir = str(yaml_config["DATA_DIR"])
csv_sep = str(yaml_config["CSV_SEP"])
ted_url = str(yaml_config["TED_URL"])
ted_url_http = str(yaml_config["TED_URL_HTTP"])
year_start = int(yaml_config["YEAR_START"])
year_end = int(yaml_config["YEAR_END"])
years_list = list(range(year_start, year_end + 1))
sample_size = int(yaml_config["TEST_SAMPLE"])
# INPUT
dic_lan = {"DE":0, "ES":0, "FR":0, "IT":0, "PT":1} # <-- INPUT: set 1 for the desired language; set only one language at time
dic_markers = {"DE":["Bedingungen für die Öffnung der Angebote", "Abschnitt VI: Weitere Angaben"], 
               "ES":["Condiciones para la apertura de las plicas", "Apartado VI: Información complementaria"], 
               "FR":["Modalités d’ouverture des offres", "Section VI: Renseignements complémentaires"], 
               "IT":["Modalità di apertura delle offerte", "Sezione VI: Altre informazioni"], 
               "PT":["Condições de abertura das propostas", "Secção VI: Informação complementar"]} # <-- INPUT: for each language, set start and end text markers
dic_lan_clean = {"DE":"Tag", "ES":"Fecha", "FR":"Date", "IT":"Data", "PT":"Data"} # <-- Remove verbose word

# OUTPUT
bid_file_text = str(yaml_config["FILE_BID_TEXT"]) # with lang_code
log_pdf = str(yaml_config["LOG_PDF_EXTRACTION"]) 
log_pdf_header = str(yaml_config["LOG_PDF_EXTRACTION_HEADER"])

# %% [markdown]
# ## FUNCTIONS

# %%
### FUNCTIONS ###
def extract_text_by_line_v1(pdf_path: str) -> str:
    """
    Extracts and prints the text from a PDF file, line by line.

    Args:
        pdf_path (str): The path to the PDF file to be processed.

    Returns:
        str: Returns None if the file could not be opened, or if no text could be extracted.
    """
    # Initialize a list to hold all extracted text
    full_text = [] # Text of all lines in the PDF
    header_text = [] # Text in PDF header (to be found and avoided as footer)
    try:
        # Open the PDF file in binary read mode
        with open(pdf_path, 'rb') as file:
            # Create a PDF reader object
            pdf_reader = PyPDF2.PdfReader(file)
            
            # Loop through each page in the PDF
            for page_num, page in enumerate(pdf_reader.pages):
                # Extract text from the page
                page_text = page.extract_text()
                
                # Check if text was successfully extracted
                if page_text:
                    # Loop each line of text inside page_text
                    line_count = 0 # to detect header
                    parts_header = None
                    for line in page_text.split('\n'):
                        line_count+=1
                        # print("Line count:",line_count) # debug
                        # print("Line text:",line) # debug
                        if line_count <= 3:
                            header_text.append(line) # Trace the header text
                            if line_count == 1: # Special text in line 1 (header: GU/S S148 -> footer: 03/08/2022 S148)
                                parts_header = line.split(" ")
                                for part in parts_header:
                                    header_text.append(part)
                            if line_count == 2:
                                header_text.append(line)
                                h2 = f"{line} {parts_header[1]}"
                                header_text.append(h2)
                        if line_count > 3: # skip header text
                            if ted_url in line:
                                continue
                            else:
                                if line not in header_text: # not in header_text -> avoid the footer
                                    full_text.append(line)
                else:
                    print(f"Text could not be extracted from page {page_num + 1}")
    except FileNotFoundError:
        print(f"ERROR! File '{pdf_path}'. Error: not found.")
    except Exception as e:
        print(f"ERROR! File '{pdf_path}'. Error: {e}")
    finally:
        return full_text

# %%
def extract_text_by_line_v2(pdf_path: str) -> list:
    """
    Extracts text from a PDF file, line by line, while avoiding headers and footers using PyMuPDF.

    Args:
        pdf_path (str): The path to the PDF file to be processed.

    Returns:
        list: A list of strings, each representing a line from the PDF. Returns None if the file could not be opened, or if no text could be extracted.
    """
    full_text = []
    header_text = set()  # Use a set for faster 'in' operations
    ted_url = "ted.europa.eu"  # Example TED URL, replace with actual URL or criteria if necessary

    try:
        # Open the PDF file
        doc = fitz.open(pdf_path)

        for page_num in range(len(doc)):
            # Extract the page
            page = doc[page_num]

            # Extract the text from the page
            page_text = page.get_text()

            if page_text:
                lines = page_text.split('\n')
                for i, line in enumerate(lines):
                    # Extract headers from the first few lines
                    if i < 3:
                        header_text.add(line)
                        if i == 0:
                            parts_header = line.split(" ")
                            header_text.update(parts_header)
                        elif i == 1 and parts_header:
                            h2 = f"{line} {parts_header[1]}"
                            header_text.add(h2)
                    else:
                        # Skip TED URLs or lines that match headers
                        if ted_url not in line and line not in header_text:
                            full_text.append(line)
            else:
                print(f"Text could not be extracted from page {page_num + 1}")

    except FileNotFoundError:
        print(f"ERROR! File '{pdf_path}' not found.")
        return None
    except Exception as e:
        print(f"ERROR! File '{pdf_path}'. Error: {e}")
        return None
    finally:
        if 'doc' in locals():
            doc.close()

    return full_text

# %%
def extract_elements_between_markers(string_list:list, start_marker:str, end_marker:str) -> list: 
    """
    Extracts a sublist of elements from the given list of strings, starting from the element that contains the start_marker and ending just before the element that contains the end_marker.

    Args:
        string_list (list of str): The list of strings to be processed.
        start_marker (str): The substring that marks the start of the extraction.
        end_marker (str): The substring that marks the end of the extraction.

    Returns:
        list of str: A sublist of the original list, containing elements between the start and end markers.
    """
    # Find the index of the start marker
    start_index = next((index for index, item in enumerate(string_list) if start_marker in item), None)
    # Find the index of the end marker
    end_index = next((index for index, item in enumerate(string_list) if end_marker in item), None)

    # Return the sublist if both markers are found
    if start_index is not None and end_index is not None and start_index < end_index:
        return string_list[start_index + 1:end_index]
    else:
        return []  # Return an empty list if markers are not found or in the wrong order

# %%
def filename_to_caseid(filename:str) -> str:
    """ 
    Given the name of a file, derive its case ID merging YEAR and file ID.

    Args:
        filename (str): The string containing the file name.
    
    Returns:
        str: YEARID
    """
    # Split the filename by dashes
    parts = filename.split('-')
    
    # Extract the first element
    first_element = parts[0]
    
    # Extract the third element and remove leading zeros
    third_element = parts[2].lstrip('0')
    
    # Concatenate the two parts
    result = first_element + third_element
    
    return result

# %% [markdown]
# ## MAIN

# %%
### MAIN ###
print()
print("*** PROGRAM START ***")
print()

start_time = datetime.now().replace(microsecond=0)
print("Start process:", str(start_time))
print()
# Out:
# *** PROGRAM START ***
#
# Start process: 2024-09-03 16:30:10

# %%
# print(yaml_config) # debug

# %%
print(">> Settings")
path_guee = Path(download_dir) / guue_dir
list_dirs = list_subdirectories(path_guee)
list_dirs_len = len(list_dirs)
print(f"Directories with GUUE found ({list_dirs_len}): {list_dirs}")
print("Years list")
print(years_list)
lang_code = None
key_with_value_1 = [key for key, value in dic_lan.items() if value == 1]
if key_with_value_1: 
    lang_code = key_with_value_1[0]
print("Desired language code for markers:", lang_code)
bid_opening_marker_start = dic_markers[lang_code][0]
bid_opening_marker_end = dic_markers[lang_code][1]
print("Markers (start):", bid_opening_marker_start)
print("Markers (end):", bid_opening_marker_end)
bid_file_text_lang = bid_file_text.replace("LANG", lang_code)
print("Output file with BID OPENING sections:", bid_file_text_lang)
# Out:
# >> Settings
# Directories with GUUE found (5): ['DE', 'ES', 'FR', 'IT', 'PT']
# Years list
# [2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Desired language code for markers: PT
# Markers (start): Condições de abertura das propostas
# Markers (end): Secção VI: Informação complementar
# Output file with BID OPENING sections: bid_opening_text_PT.csv

# %%
print(">> Preparing the output timing log")
path_log = Path(data_dir) / log_pdf
if not path_log.exists():
    # If the file does not exist, create it with the specified header
    with path_log.open(mode='w') as fp:
        fp.write(f"{log_pdf_header}\n")
    print(f"File created with header: {path_log}")
else:
    print(f"The file already exists: {path_log}")
# Out:
# >> Preparing the output timing log
# The file already exists: data/ted_log_pdf_extraction.csv

# %%
# Create list of PDF files of a language
print(">> Listing PDF files")
list_pdf_files = []
path_guee_lang = Path(download_dir) / guue_dir / lang_code
print("Directory (lang):", path_guee_lang)
for year_value in years_list:
    path_guee_lang_year = path_guee_lang / str(year_value)
    list_pdf_files_y = list_files_by_type(path_guee_lang_year, "pdf")
    list_pdf_files_y_len = len(list_pdf_files_y)
    print(f"Files found for year {year_value}: {list_pdf_files_y_len}")
    list_pdf_files.extend(list_pdf_files_y)
list_pdf_files_len = len(list_pdf_files)
print("Total files found:", list_pdf_files_len)
# print("Files:", list_pdf_files) # debug
print("Sample size (0 = ALL):", sample_size)
# Out:
# >> Listing PDF files
# Directory (lang): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT
# Files found for year 2016: 420
# Files found for year 2017: 459
# Files found for year 2018: 521
# Files found for year 2019: 625
# Files found for year 2020: 614
# Files found for year 2021: 622
# Files found for year 2022: 815
# Total files found: 4076
# Sample size (0 = ALL): 0

# %%
# Parse the files
print(">> Parsing PDF files")

i = 0

list_bid_opening_dic = [] # Container of texts of interest extracted from PDFs

for pdf_file in list_pdf_files:
    i+=1
    if sample_size!=0 and i>sample_size:
        break
    print(f"[{i} / {list_pdf_files_len}]")
    print("Reading (path):", str(pdf_file))
    # text_list = extract_text_by_line_v1(pdf_file) # Extracts all lines of text from the PDF (with PyPDF2)
    text_list = extract_text_by_line_v2(pdf_file) # Extracts all lines of text from the PDF (with PyMuPDF)
    text_list_len = len(text_list)
    # print(text_list) # debug

    # prepare the dictionary output for the actual PDF
    file_name = pdf_file.name # get only the file name in str
    case_id  = filename_to_caseid(file_name) # get the case_id from the file_name
    dic_bid_opening = {"file_name":file_name, "case_id":case_id, "text": None}
    
    print(f"Case ID derived from file name '{file_name}': {case_id}")
    print("Lines found in the PDF:", text_list_len)

    # get only lines about bid opening
    if text_list_len > 0:
        marker_list = extract_elements_between_markers(text_list, bid_opening_marker_start, bid_opening_marker_end) 
        marker_list_len = len(marker_list)
        # print(marker_list) # debug
        print("Bid opening strings found between markers:", marker_list_len)
        
        if marker_list_len > 0:
            if len(marker_list) == 1:
                marker_text = marker_list[0] + " | " # If the marker contains only one element adds |
            else:
                marker_text = " | ".join(marker_list)
            # print(marker_text) # debug
            # clean
            marker_text_clean = marker_text.replace(ted_url_http, "")
            dic_bid_opening["text"] = marker_text_clean

    # save the file and the text found in bid opening section into a dictionary
    list_bid_opening_dic.append(dic_bid_opening)
    print()
# Out:
# >> Parsing PDF files
# [1 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS001-00000268-pt-ts.pdf
# Case ID derived from file name '2016-OJS001-00000268-pt-ts.pdf': 2016268
# Lines found in the PDF: 176
# Bid opening strings found between markers: 0
#
# [2 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS004-00004017-pt-ts.pdf
# Case ID derived from file name '2016-OJS004-00004017-pt-ts.pdf': 20164017
# Lines found in the PDF: 170
# Bid opening strings found between markers: 0
#
# [3 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS005-00004854-pt-ts.pdf
# Case ID derived from file name '2016-OJS005-00004854-pt-ts.pdf': 20164854
# Lines found in the PDF: 219
# Bid opening strings found between markers: 6
#
# [4 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS006-00006881-pt-ts.pdf
# Case ID derived from file name '2016-OJS006-00006881-pt-ts.pdf': 20166881
# Lines found in the PDF: 184
# Bid opening strings found between markers: 1
#
# [5 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS006-00006904-pt-ts.pdf
# Case ID derived from file name '2016-OJS006-00006904-pt-ts.pdf': 20166904
# Lines found in the PDF: 177
# Bid opening strings found between markers: 0
#
# [6 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS006-00006907-pt-ts.pdf
# Case ID derived from file name '2016-OJS006-00006907-pt-ts.pdf': 20166907
# Lines found in the PDF: 176
# Bid opening strings found between markers: 0
#
# [7 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS007-00008275-pt-ts.pdf
# Case ID derived from file name '2016-OJS007-00008275-pt-ts.pdf': 20168275
# Lines found in the PDF: 188
# Bid opening strings found between markers: 0
#
# [8 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS008-00010001-pt-ts.pdf
# Case ID derived from file name '2016-OJS008-00010001-pt-ts.pdf': 201610001
# Lines found in the PDF: 174
# Bid opening strings found between markers: 0
#
# [9 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS009-00011244-pt-ts.pdf
# Case ID derived from file name '2016-OJS009-00011244-pt-ts.pdf': 201611244
# Lines found in the PDF: 177
# Bid opening strings found between markers: 0
#
# [10 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS009-00011735-pt-ts.pdf
# Case ID derived from file name '2016-OJS009-00011735-pt-ts.pdf': 201611735
# Lines found in the PDF: 171
# Bid opening strings found between markers: 0
#
# [11 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS010-00012575-pt-ts.pdf
# Case ID derived from file name '2016-OJS010-00012575-pt-ts.pdf': 201612575
# Lines found in the PDF: 243
# Bid opening strings found between markers: 9
#
# [12 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS010-00012614-pt-ts.pdf
# Case ID derived from file name '2016-OJS010-00012614-pt-ts.pdf': 201612614
# Lines found in the PDF: 201
# Bid opening strings found between markers: 1
#
# [13 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS010-00012916-pt-ts.pdf
# Case ID derived from file name '2016-OJS010-00012916-pt-ts.pdf': 201612916
# Lines found in the PDF: 171
# Bid opening strings found between markers: 0
#
# [14 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS010-00013560-pt-ts.pdf
# Case ID derived from file name '2016-OJS010-00013560-pt-ts.pdf': 201613560
# Lines found in the PDF: 192
# Bid opening strings found between markers: 5
#
# [15 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS011-00015472-pt-ts.pdf
# Case ID derived from file name '2016-OJS011-00015472-pt-ts.pdf': 201615472
# Lines found in the PDF: 182
# Bid opening strings found between markers: 1
#
# [16 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS011-00015476-pt-ts.pdf
# Case ID derived from file name '2016-OJS011-00015476-pt-ts.pdf': 201615476
# Lines found in the PDF: 177
# Bid opening strings found between markers: 0
#
# [17 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS015-00022230-pt-ts.pdf
# Case ID derived from file name '2016-OJS015-00022230-pt-ts.pdf': 201622230
# Lines found in the PDF: 185
# Bid opening strings found between markers: 0
#
# [18 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS017-00025962-pt-ts.pdf
# Case ID derived from file name '2016-OJS017-00025962-pt-ts.pdf': 201625962
# Lines found in the PDF: 175
# Bid opening strings found between markers: 0
#
# [19 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS017-00025978-pt-ts.pdf
# Case ID derived from file name '2016-OJS017-00025978-pt-ts.pdf': 201625978
# Lines found in the PDF: 172
# Bid opening strings found between markers: 0
#
# [20 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS017-00026006-pt-ts.pdf
# Case ID derived from file name '2016-OJS017-00026006-pt-ts.pdf': 201626006
# Lines found in the PDF: 171
# Bid opening strings found between markers: 0
#
# [21 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS018-00027331-pt-ts.pdf
# Case ID derived from file name '2016-OJS018-00027331-pt-ts.pdf': 201627331
# Lines found in the PDF: 188
# Bid opening strings found between markers: 1
#
# [22 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS019-00029294-pt-ts.pdf
# Case ID derived from file name '2016-OJS019-00029294-pt-ts.pdf': 201629294
# Lines found in the PDF: 173
# Bid opening strings found between markers: 0
#
# [23 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS020-00031061-pt-ts.pdf
# Case ID derived from file name '2016-OJS020-00031061-pt-ts.pdf': 201631061
# Lines found in the PDF: 172
# Bid opening strings found between markers: 0
#
# [24 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS020-00031659-pt-ts.pdf
# Case ID derived from file name '2016-OJS020-00031659-pt-ts.pdf': 201631659
# Lines found in the PDF: 170
# Bid opening strings found between markers: 0
#
# [25 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS021-00032855-pt-ts.pdf
# Case ID derived from file name '2016-OJS021-00032855-pt-ts.pdf': 201632855
# Lines found in the PDF: 169
# Bid opening strings found between markers: 0
#
# [26 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS022-00034647-pt-ts.pdf
# Case ID derived from file name '2016-OJS022-00034647-pt-ts.pdf': 201634647
# Lines found in the PDF: 213
# Bid opening strings found between markers: 6
#
# [27 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS022-00035201-pt-ts.pdf
# Case ID derived from file name '2016-OJS022-00035201-pt-ts.pdf': 201635201
# Lines found in the PDF: 256
# Bid opening strings found between markers: 9
#
# [28 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS022-00035211-pt-ts.pdf
# Case ID derived from file name '2016-OJS022-00035211-pt-ts.pdf': 201635211
# Lines found in the PDF: 175
# Bid opening strings found between markers: 0
#
# [29 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS025-00040350-pt-ts.pdf
# Case ID derived from file name '2016-OJS025-00040350-pt-ts.pdf': 201640350
# Lines found in the PDF: 170
# Bid opening strings found between markers: 0
#
# [30 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS026-00042119-pt-ts.pdf
# Case ID derived from file name '2016-OJS026-00042119-pt-ts.pdf': 201642119
# Lines found in the PDF: 170
# Bid opening strings found between markers: 0
#
# [31 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS026-00042120-pt-ts.pdf
# Case ID derived from file name '2016-OJS026-00042120-pt-ts.pdf': 201642120
# Lines found in the PDF: 176
# Bid opening strings found between markers: 0
#
# [32 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS026-00042162-pt-ts.pdf
# Case ID derived from file name '2016-OJS026-00042162-pt-ts.pdf': 201642162
# Lines found in the PDF: 317
# Bid opening strings found between markers: 3
#
# [33 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS027-00043812-pt-ts.pdf
# Case ID derived from file name '2016-OJS027-00043812-pt-ts.pdf': 201643812
# Lines found in the PDF: 240
# Bid opening strings found between markers: 0
#
# [34 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS028-00045458-pt-ts.pdf
# Case ID derived from file name '2016-OJS028-00045458-pt-ts.pdf': 201645458
# Lines found in the PDF: 207
# Bid opening strings found between markers: 6
#
# [35 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS029-00046611-pt-ts.pdf
# Case ID derived from file name '2016-OJS029-00046611-pt-ts.pdf': 201646611
# Lines found in the PDF: 244
# Bid opening strings found between markers: 2
#
# [36 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS031-00050163-pt-ts.pdf
# Case ID derived from file name '2016-OJS031-00050163-pt-ts.pdf': 201650163
# Lines found in the PDF: 181
# Bid opening strings found between markers: 0
#
# [37 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS032-00051462-pt-ts.pdf
# Case ID derived from file name '2016-OJS032-00051462-pt-ts.pdf': 201651462
# Lines found in the PDF: 170
# Bid opening strings found between markers: 0
#
# [38 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS032-00051466-pt-ts.pdf
# Case ID derived from file name '2016-OJS032-00051466-pt-ts.pdf': 201651466
# Lines found in the PDF: 174
# Bid opening strings found between markers: 0
#
# [39 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS032-00051844-pt-ts.pdf
# Case ID derived from file name '2016-OJS032-00051844-pt-ts.pdf': 201651844
# Lines found in the PDF: 223
# Bid opening strings found between markers: 0
#
# [40 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS035-00055885-pt-ts.pdf
# Case ID derived from file name '2016-OJS035-00055885-pt-ts.pdf': 201655885
# Lines found in the PDF: 180
# Bid opening strings found between markers: 1
#
# [41 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS035-00055887-pt-ts.pdf
# Case ID derived from file name '2016-OJS035-00055887-pt-ts.pdf': 201655887
# Lines found in the PDF: 177
# Bid opening strings found between markers: 0
#
# [42 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS035-00055890-pt-ts.pdf
# Case ID derived from file name '2016-OJS035-00055890-pt-ts.pdf': 201655890
# Lines found in the PDF: 169
# Bid opening strings found between markers: 0
#
# [43 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS035-00055929-pt-ts.pdf
# Case ID derived from file name '2016-OJS035-00055929-pt-ts.pdf': 201655929
# Lines found in the PDF: 239
# Bid opening strings found between markers: 0
#
# [44 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS035-00056457-pt-ts.pdf
# Case ID derived from file name '2016-OJS035-00056457-pt-ts.pdf': 201656457
# Lines found in the PDF: 202
# Bid opening strings found between markers: 1
#
# [45 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS035-00056463-pt-ts.pdf
# Case ID derived from file name '2016-OJS035-00056463-pt-ts.pdf': 201656463
# Lines found in the PDF: 169
# Bid opening strings found between markers: 0
#
# [46 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS035-00056464-pt-ts.pdf
# Case ID derived from file name '2016-OJS035-00056464-pt-ts.pdf': 201656464
# Lines found in the PDF: 184
# Bid opening strings found between markers: 1
#
# [47 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS036-00057622-pt-ts.pdf
# Case ID derived from file name '2016-OJS036-00057622-pt-ts.pdf': 201657622
# Lines found in the PDF: 173
# Bid opening strings found between markers: 0
#
# [48 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS037-00059578-pt-ts.pdf
# Case ID derived from file name '2016-OJS037-00059578-pt-ts.pdf': 201659578
# Lines found in the PDF: 170
# Bid opening strings found between markers: 0
#
# [49 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS038-00062118-pt-ts.pdf
# Case ID derived from file name '2016-OJS038-00062118-pt-ts.pdf': 201662118
# Lines found in the PDF: 176
# Bid opening strings found between markers: 0
#
# [50 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS038-00062124-pt-ts.pdf
# Case ID derived from file name '2016-OJS038-00062124-pt-ts.pdf': 201662124
# Lines found in the PDF: 173
# Bid opening strings found between markers: 0
#
# [51 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS038-00062136-pt-ts.pdf
# Case ID derived from file name '2016-OJS038-00062136-pt-ts.pdf': 201662136
# Lines found in the PDF: 249
# Bid opening strings found between markers: 6
#
# [52 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS039-00063880-pt-ts.pdf
# Case ID derived from file name '2016-OJS039-00063880-pt-ts.pdf': 201663880
# Lines found in the PDF: 170
# Bid opening strings found between markers: 0
#
# [53 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS039-00063898-pt-ts.pdf
# Case ID derived from file name '2016-OJS039-00063898-pt-ts.pdf': 201663898
# Lines found in the PDF: 172
# Bid opening strings found between markers: 0
#
# [54 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS040-00065506-pt-ts.pdf
# Case ID derived from file name '2016-OJS040-00065506-pt-ts.pdf': 201665506
# Lines found in the PDF: 180
# Bid opening strings found between markers: 0
#
# [55 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS040-00065520-pt-ts.pdf
# Case ID derived from file name '2016-OJS040-00065520-pt-ts.pdf': 201665520
# Lines found in the PDF: 176
# Bid opening strings found between markers: 0
#
# [56 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS041-00066829-pt-ts.pdf
# Case ID derived from file name '2016-OJS041-00066829-pt-ts.pdf': 201666829
# Lines found in the PDF: 169
# Bid opening strings found between markers: 0
#
# [57 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS041-00066834-pt-ts.pdf
# Case ID derived from file name '2016-OJS041-00066834-pt-ts.pdf': 201666834
# Lines found in the PDF: 260
# Bid opening strings found between markers: 1
#
# [58 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS041-00066845-pt-ts.pdf
# Case ID derived from file name '2016-OJS041-00066845-pt-ts.pdf': 201666845
# Lines found in the PDF: 179
# Bid opening strings found between markers: 0
#
# [59 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS041-00067549-pt-ts.pdf
# Case ID derived from file name '2016-OJS041-00067549-pt-ts.pdf': 201667549
# Lines found in the PDF: 173
# Bid opening strings found between markers: 0
#
# [60 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS041-00067561-pt-ts.pdf
# Case ID derived from file name '2016-OJS041-00067561-pt-ts.pdf': 201667561
# Lines found in the PDF: 171
# Bid opening strings found between markers: 0
#
# [61 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS042-00069515-pt-ts.pdf
# Case ID derived from file name '2016-OJS042-00069515-pt-ts.pdf': 201669515
# Lines found in the PDF: 189
# Bid opening strings found between markers: 1
#
# [62 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS042-00069517-pt-ts.pdf
# Case ID derived from file name '2016-OJS042-00069517-pt-ts.pdf': 201669517
# Lines found in the PDF: 217
# Bid opening strings found between markers: 6
#
# [63 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS042-00069519-pt-ts.pdf
# Case ID derived from file name '2016-OJS042-00069519-pt-ts.pdf': 201669519
# Lines found in the PDF: 174
# Bid opening strings found between markers: 0
#
# [64 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS043-00071230-pt-ts.pdf
# Case ID derived from file name '2016-OJS043-00071230-pt-ts.pdf': 201671230
# Lines found in the PDF: 173
# Bid opening strings found between markers: 0
#
# [65 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS043-00071239-pt-ts.pdf
# Case ID derived from file name '2016-OJS043-00071239-pt-ts.pdf': 201671239
# Lines found in the PDF: 181
# Bid opening strings found between markers: 0
#
# [66 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS045-00073538-pt-ts.pdf
# Case ID derived from file name '2016-OJS045-00073538-pt-ts.pdf': 201673538
# Lines found in the PDF: 194
# Bid opening strings found between markers: 1
#
# [67 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS045-00073550-pt-ts.pdf
# Case ID derived from file name '2016-OJS045-00073550-pt-ts.pdf': 201673550
# Lines found in the PDF: 214
# Bid opening strings found between markers: 6
#
# [68 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS045-00073589-pt-ts.pdf
# Case ID derived from file name '2016-OJS045-00073589-pt-ts.pdf': 201673589
# Lines found in the PDF: 234
# Bid opening strings found between markers: 1
#
# [69 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS045-00074189-pt-ts.pdf
# Case ID derived from file name '2016-OJS045-00074189-pt-ts.pdf': 201674189
# Lines found in the PDF: 191
# Bid opening strings found between markers: 0
#
# [70 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS045-00074190-pt-ts.pdf
# Case ID derived from file name '2016-OJS045-00074190-pt-ts.pdf': 201674190
# Lines found in the PDF: 169
# Bid opening strings found between markers: 0
#
# [71 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS045-00074191-pt-ts.pdf
# Case ID derived from file name '2016-OJS045-00074191-pt-ts.pdf': 201674191
# Lines found in the PDF: 174
# Bid opening strings found between markers: 0
#
# [72 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS045-00074211-pt-ts.pdf
# Case ID derived from file name '2016-OJS045-00074211-pt-ts.pdf': 201674211
# Lines found in the PDF: 176
# Bid opening strings found between markers: 0
#
# [73 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS046-00075627-pt-ts.pdf
# Case ID derived from file name '2016-OJS046-00075627-pt-ts.pdf': 201675627
# Lines found in the PDF: 321
# Bid opening strings found between markers: 1
#
# [74 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS046-00076607-pt-ts.pdf
# Case ID derived from file name '2016-OJS046-00076607-pt-ts.pdf': 201676607
# Lines found in the PDF: 172
# Bid opening strings found between markers: 0
#
# [75 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS047-00077748-pt-ts.pdf
# Case ID derived from file name '2016-OJS047-00077748-pt-ts.pdf': 201677748
# Lines found in the PDF: 210
# Bid opening strings found between markers: 6
#
# [76 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS048-00080057-pt-ts.pdf
# Case ID derived from file name '2016-OJS048-00080057-pt-ts.pdf': 201680057
# Lines found in the PDF: 179
# Bid opening strings found between markers: 0
#
# [77 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS048-00080071-pt-ts.pdf
# Case ID derived from file name '2016-OJS048-00080071-pt-ts.pdf': 201680071
# Lines found in the PDF: 226
# Bid opening strings found between markers: 1
#
# [78 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS050-00082474-pt-ts.pdf
# Case ID derived from file name '2016-OJS050-00082474-pt-ts.pdf': 201682474
# Lines found in the PDF: 295
# Bid opening strings found between markers: 1
#
# [79 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS050-00082589-pt-ts.pdf
# Case ID derived from file name '2016-OJS050-00082589-pt-ts.pdf': 201682589
# Lines found in the PDF: 179
# Bid opening strings found between markers: 1
#
# [80 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS050-00083068-pt-ts.pdf
# Case ID derived from file name '2016-OJS050-00083068-pt-ts.pdf': 201683068
# Lines found in the PDF: 213
# Bid opening strings found between markers: 1
#
# [81 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS050-00083168-pt-ts.pdf
# Case ID derived from file name '2016-OJS050-00083168-pt-ts.pdf': 201683168
# Lines found in the PDF: 186
# Bid opening strings found between markers: 0
#
# [82 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS050-00083178-pt-ts.pdf
# Case ID derived from file name '2016-OJS050-00083178-pt-ts.pdf': 201683178
# Lines found in the PDF: 170
# Bid opening strings found between markers: 0
#
# [83 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS050-00083185-pt-ts.pdf
# Case ID derived from file name '2016-OJS050-00083185-pt-ts.pdf': 201683185
# Lines found in the PDF: 171
# Bid opening strings found between markers: 0
#
# [84 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS050-00083188-pt-ts.pdf
# Case ID derived from file name '2016-OJS050-00083188-pt-ts.pdf': 201683188
# Lines found in the PDF: 187
# Bid opening strings found between markers: 1
#
# [85 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS050-00083206-pt-ts.pdf
# Case ID derived from file name '2016-OJS050-00083206-pt-ts.pdf': 201683206
# Lines found in the PDF: 221
# Bid opening strings found between markers: 8
#
# [86 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS052-00087190-pt-ts.pdf
# Case ID derived from file name '2016-OJS052-00087190-pt-ts.pdf': 201687190
# Lines found in the PDF: 223
# Bid opening strings found between markers: 2
#
# [87 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS052-00087207-pt-ts.pdf
# Case ID derived from file name '2016-OJS052-00087207-pt-ts.pdf': 201687207
# Lines found in the PDF: 289
# Bid opening strings found between markers: 1
#
# [88 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS053-00089012-pt-ts.pdf
# Case ID derived from file name '2016-OJS053-00089012-pt-ts.pdf': 201689012
# Lines found in the PDF: 286
# Bid opening strings found between markers: 0
#
# [89 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS055-00091657-pt-ts.pdf
# Case ID derived from file name '2016-OJS055-00091657-pt-ts.pdf': 201691657
# Lines found in the PDF: 295
# Bid opening strings found between markers: 6
#
# [90 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS056-00093218-pt-ts.pdf
# Case ID derived from file name '2016-OJS056-00093218-pt-ts.pdf': 201693218
# Lines found in the PDF: 175
# Bid opening strings found between markers: 0
#
# [91 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS056-00093219-pt-ts.pdf
# Case ID derived from file name '2016-OJS056-00093219-pt-ts.pdf': 201693219
# Lines found in the PDF: 171
# Bid opening strings found between markers: 0
#
# [92 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS057-00095678-pt-ts.pdf
# Case ID derived from file name '2016-OJS057-00095678-pt-ts.pdf': 201695678
# Lines found in the PDF: 171
# Bid opening strings found between markers: 0
#
# [93 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS057-00096179-pt-ts.pdf
# Case ID derived from file name '2016-OJS057-00096179-pt-ts.pdf': 201696179
# Lines found in the PDF: 175
# Bid opening strings found between markers: 1
#
# [94 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS057-00096189-pt-ts.pdf
# Case ID derived from file name '2016-OJS057-00096189-pt-ts.pdf': 201696189
# Lines found in the PDF: 209
# Bid opening strings found between markers: 0
#
# [95 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS057-00096195-pt-ts.pdf
# Case ID derived from file name '2016-OJS057-00096195-pt-ts.pdf': 201696195
# Lines found in the PDF: 186
# Bid opening strings found between markers: 0
#
# [96 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS058-00097448-pt-ts.pdf
# Case ID derived from file name '2016-OJS058-00097448-pt-ts.pdf': 201697448
# Lines found in the PDF: 177
# Bid opening strings found between markers: 1
#
# [97 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS058-00097986-pt-ts.pdf
# Case ID derived from file name '2016-OJS058-00097986-pt-ts.pdf': 201697986
# Lines found in the PDF: 186
# Bid opening strings found between markers: 5
#
# [98 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS058-00097990-pt-ts.pdf
# Case ID derived from file name '2016-OJS058-00097990-pt-ts.pdf': 201697990
# Lines found in the PDF: 171
# Bid opening strings found between markers: 0
#
# [99 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS059-00099264-pt-ts.pdf
# Case ID derived from file name '2016-OJS059-00099264-pt-ts.pdf': 201699264
# Lines found in the PDF: 170
# Bid opening strings found between markers: 0
#
# [100 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS059-00099789-pt-ts.pdf
# Case ID derived from file name '2016-OJS059-00099789-pt-ts.pdf': 201699789
# Lines found in the PDF: 277
# Bid opening strings found between markers: 1
#
# [101 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS059-00099797-pt-ts.pdf
# Case ID derived from file name '2016-OJS059-00099797-pt-ts.pdf': 201699797
# Lines found in the PDF: 325
# Bid opening strings found between markers: 0
#
# [102 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS060-00100685-pt-ts.pdf
# Case ID derived from file name '2016-OJS060-00100685-pt-ts.pdf': 2016100685
# Lines found in the PDF: 170
# Bid opening strings found between markers: 0
#
# [103 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS060-00101102-pt-ts.pdf
# Case ID derived from file name '2016-OJS060-00101102-pt-ts.pdf': 2016101102
# Lines found in the PDF: 184
# Bid opening strings found between markers: 1
#
# [104 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS060-00101188-pt-ts.pdf
# Case ID derived from file name '2016-OJS060-00101188-pt-ts.pdf': 2016101188
# Lines found in the PDF: 190
# Bid opening strings found between markers: 0
#
# [105 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS060-00101190-pt-ts.pdf
# Case ID derived from file name '2016-OJS060-00101190-pt-ts.pdf': 2016101190
# Lines found in the PDF: 209
# Bid opening strings found between markers: 6
#
# [106 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS060-00101717-pt-ts.pdf
# Case ID derived from file name '2016-OJS060-00101717-pt-ts.pdf': 2016101717
# Lines found in the PDF: 171
# Bid opening strings found between markers: 0
#
# [107 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS060-00101806-pt-ts.pdf
# Case ID derived from file name '2016-OJS060-00101806-pt-ts.pdf': 2016101806
# Lines found in the PDF: 215
# Bid opening strings found between markers: 6
#
# [108 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS060-00101809-pt-ts.pdf
# Case ID derived from file name '2016-OJS060-00101809-pt-ts.pdf': 2016101809
# Lines found in the PDF: 185
# Bid opening strings found between markers: 0
#
# [109 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS061-00103356-pt-ts.pdf
# Case ID derived from file name '2016-OJS061-00103356-pt-ts.pdf': 2016103356
# Lines found in the PDF: 188
# Bid opening strings found between markers: 2
#
# [110 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS062-00107233-pt-ts.pdf
# Case ID derived from file name '2016-OJS062-00107233-pt-ts.pdf': 2016107233
# Lines found in the PDF: 169
# Bid opening strings found between markers: 0
#
# [111 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2016/2016-OJS063-00108589-pt-ts.pdf
# ...
# Case ID derived from file name '2022-OJS243-00703016-pt-ts.pdf': 2022703016
# Lines found in the PDF: 142
# Bid opening strings found between markers: 5
#
# [4041 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS243-00703512-pt-ts.pdf
# Case ID derived from file name '2022-OJS243-00703512-pt-ts.pdf': 2022703512
# Lines found in the PDF: 172
# Bid opening strings found between markers: 2
#
# [4042 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS244-00704870-pt-ts.pdf
# Case ID derived from file name '2022-OJS244-00704870-pt-ts.pdf': 2022704870
# Lines found in the PDF: 179
# Bid opening strings found between markers: 2
#
# [4043 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS244-00704997-pt-ts.pdf
# Case ID derived from file name '2022-OJS244-00704997-pt-ts.pdf': 2022704997
# Lines found in the PDF: 144
# Bid opening strings found between markers: 7
#
# [4044 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS244-00705060-pt-ts.pdf
# Case ID derived from file name '2022-OJS244-00705060-pt-ts.pdf': 2022705060
# Lines found in the PDF: 195
# Bid opening strings found between markers: 2
#
# [4045 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS244-00705969-pt-ts.pdf
# Case ID derived from file name '2022-OJS244-00705969-pt-ts.pdf': 2022705969
# Lines found in the PDF: 138
# Bid opening strings found between markers: 2
#
# [4046 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS244-00706450-pt-ts.pdf
# Case ID derived from file name '2022-OJS244-00706450-pt-ts.pdf': 2022706450
# Lines found in the PDF: 143
# Bid opening strings found between markers: 2
#
# [4047 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS245-00707107-pt-ts.pdf
# Case ID derived from file name '2022-OJS245-00707107-pt-ts.pdf': 2022707107
# Lines found in the PDF: 163
# Bid opening strings found between markers: 2
#
# [4048 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS245-00708054-pt-ts.pdf
# Case ID derived from file name '2022-OJS245-00708054-pt-ts.pdf': 2022708054
# Lines found in the PDF: 142
# Bid opening strings found between markers: 2
#
# [4049 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS245-00708234-pt-ts.pdf
# Case ID derived from file name '2022-OJS245-00708234-pt-ts.pdf': 2022708234
# Lines found in the PDF: 190
# Bid opening strings found between markers: 2
#
# [4050 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS246-00710815-pt-ts.pdf
# Case ID derived from file name '2022-OJS246-00710815-pt-ts.pdf': 2022710815
# Lines found in the PDF: 164
# Bid opening strings found between markers: 2
#
# [4051 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00714392-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00714392-pt-ts.pdf': 2022714392
# Lines found in the PDF: 344
# Bid opening strings found between markers: 4
#
# [4052 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00714471-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00714471-pt-ts.pdf': 2022714471
# Lines found in the PDF: 141
# Bid opening strings found between markers: 5
#
# [4053 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00715949-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00715949-pt-ts.pdf': 2022715949
# Lines found in the PDF: 193
# Bid opening strings found between markers: 2
#
# [4054 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00716029-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00716029-pt-ts.pdf': 2022716029
# Lines found in the PDF: 187
# Bid opening strings found between markers: 4
#
# [4055 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00716224-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00716224-pt-ts.pdf': 2022716224
# Lines found in the PDF: 157
# Bid opening strings found between markers: 4
#
# [4056 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00716747-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00716747-pt-ts.pdf': 2022716747
# Lines found in the PDF: 427
# Bid opening strings found between markers: 2
#
# [4057 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00717129-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00717129-pt-ts.pdf': 2022717129
# Lines found in the PDF: 139
# Bid opening strings found between markers: 2
#
# [4058 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00717297-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00717297-pt-ts.pdf': 2022717297
# Lines found in the PDF: 224
# Bid opening strings found between markers: 0
#
# [4059 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00718461-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00718461-pt-ts.pdf': 2022718461
# Lines found in the PDF: 148
# Bid opening strings found between markers: 2
#
# [4060 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00719118-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00719118-pt-ts.pdf': 2022719118
# Lines found in the PDF: 144
# Bid opening strings found between markers: 2
#
# [4061 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00719351-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00719351-pt-ts.pdf': 2022719351
# Lines found in the PDF: 153
# Bid opening strings found between markers: 2
#
# [4062 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00719733-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00719733-pt-ts.pdf': 2022719733
# Lines found in the PDF: 144
# Bid opening strings found between markers: 7
#
# [4063 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00721219-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00721219-pt-ts.pdf': 2022721219
# Lines found in the PDF: 139
# Bid opening strings found between markers: 2
#
# [4064 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00722014-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00722014-pt-ts.pdf': 2022722014
# Lines found in the PDF: 146
# Bid opening strings found between markers: 2
#
# [4065 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00722471-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00722471-pt-ts.pdf': 2022722471
# Lines found in the PDF: 395
# Bid opening strings found between markers: 5
#
# [4066 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00723870-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00723870-pt-ts.pdf': 2022723870
# Lines found in the PDF: 345
# Bid opening strings found between markers: 2
#
# [4067 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS248-00724660-pt-ts.pdf
# Case ID derived from file name '2022-OJS248-00724660-pt-ts.pdf': 2022724660
# Lines found in the PDF: 422
# Bid opening strings found between markers: 4
#
# [4068 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS249-00725440-pt-ts.pdf
# Case ID derived from file name '2022-OJS249-00725440-pt-ts.pdf': 2022725440
# Lines found in the PDF: 173
# Bid opening strings found between markers: 2
#
# [4069 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS249-00726431-pt-ts.pdf
# Case ID derived from file name '2022-OJS249-00726431-pt-ts.pdf': 2022726431
# Lines found in the PDF: 150
# Bid opening strings found between markers: 2
#
# [4070 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS250-00730791-pt-ts.pdf
# Case ID derived from file name '2022-OJS250-00730791-pt-ts.pdf': 2022730791
# Lines found in the PDF: 143
# Bid opening strings found between markers: 2
#
# [4071 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS252-00732797-pt-ts.pdf
# Case ID derived from file name '2022-OJS252-00732797-pt-ts.pdf': 2022732797
# Lines found in the PDF: 202
# Bid opening strings found between markers: 5
#
# [4072 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS252-00733298-pt-ts.pdf
# Case ID derived from file name '2022-OJS252-00733298-pt-ts.pdf': 2022733298
# Lines found in the PDF: 140
# Bid opening strings found between markers: 5
#
# [4073 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS252-00733419-pt-ts.pdf
# Case ID derived from file name '2022-OJS252-00733419-pt-ts.pdf': 2022733419
# Lines found in the PDF: 139
# Bid opening strings found between markers: 2
#
# [4074 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS252-00734151-pt-ts.pdf
# Case ID derived from file name '2022-OJS252-00734151-pt-ts.pdf': 2022734151
# Lines found in the PDF: 139
# Bid opening strings found between markers: 2
#
# [4075 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS252-00734660-pt-ts.pdf
# Case ID derived from file name '2022-OJS252-00734660-pt-ts.pdf': 2022734660
# Lines found in the PDF: 139
# Bid opening strings found between markers: 2
#
# [4076 / 4076]
# Reading (path): /Volumes/SAMSUNG-PHD/PhD/Corsi da seguire/Knowledge management and information extraction from structured and unstructured data for process mining (techniques, algorithms, and tools)/Python - GUUE in CSV per LOG/guue/PT/2022/2022-OJS252-00734866-pt-ts.pdf
# Case ID derived from file name '2022-OJS252-00734866-pt-ts.pdf': 2022734866
# Lines found in the PDF: 202
# Bid opening strings found between markers: 2

# %%
# Create a file with the texts extracted from the PDFs
print(">> Saving bid opening texts")
dtype_dict = {"file_name":"object", "case_id":"object", "text":"object"}
df_bid = pd.DataFrame.from_records(list_bid_opening_dic) # Create a dataframe from a list of dictionaries
df_bid = df_bid.astype(dtype_dict)
df_bid = df_bid.sort_values(by='file_name')
# print(df_bid.head()) # debug

# Get the first part of the data
df_bid['text_date'] = df_bid['text'].apply(lambda x: '0' if pd.isna(x) or x.strip() == '' else x.split('|')[0].strip())
df_bid['text_date'] = df_bid['text_date'].str.replace(dic_lan_clean[lang_code], '', regex=False)  # Removes redundant words
df_bid['text_date'] = df_bid['text_date'].str.strip()

# Save in CSV
path_out = Path(data_dir) / bid_file_text_lang
print("Path CSV:", path_out)
df_bid.to_csv(path_out, sep=csv_sep, index=False, quoting=csv.QUOTE_ALL)
# Save in XLSX
path_out = Path(data_dir) / f"{Path(bid_file_text_lang).stem}.xlsx"
print("Path XLSX:", path_out)
df_bid.to_excel(path_out, sheet_name=f"{Path(bid_file_text_lang).stem}", index=False)
# Out:
# >> Saving bid opening texts
# Path CSV: data/bid_opening_text_PT.csv
# Path XLSX: data/bid_opening_text_PT.xlsx

# %%
# program end
end_time = datetime.now().replace(microsecond=0)
delta_time = end_time - start_time

# Save the timing
print(">> Saving timing to log")
data_len = list_pdf_files_len
if sample_size != 0:
    data_len = sample_size
csv_str = f"{lang_code};{str(start_time)};{str(end_time)};{str(delta_time)};{str(data_len)}\n"
with open(path_log, "a") as fp:
    fp.write(csv_str)
    
print()
print("End process:", end_time)
print("Time to finish:", delta_time)
print()

print()
print("*** PROGRAM END ***")
print()
# Out:
# >> Saving timing to log
#
# End process: 2024-09-03 16:32:37
# Time to finish: 0:02:27
#
#
# *** PROGRAM END ***
