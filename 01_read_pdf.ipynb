# %%
# 01_read_pdf.ipynb
# For each text in the CSV extracted in the script '01_read_pdf', it requests the LLM to identify the date.

# %%
# Force to reload extrernal modules every new cell execution
# %reload_ext autoreload
# %autoreload 2

# %%
### IMPORT ###
from pathlib import Path
import csv
from datetime import datetime
import pandas as pd
import PyPDF2

# %%
### LOCAL IMPORT ###
from config import config_reader
from utilities import list_files_by_type

# %%
### GLOBALS ###
yaml_config = config_reader.config_read_yaml("config.yml", "config")
# print(yaml_config) # debug
guue_dir = str(yaml_config["GUUE_DIR"])
data_dir = str(yaml_config["DATA_DIR"])
bid_opening_marker_start =  str(yaml_config["BID_OPENING_MARKER_START"])
bid_opening_marker_end =  str(yaml_config["BID_OPENING_MARKER_END"])
bid_file_text = str(yaml_config["FILE_BID_TEXT"])
csv_sep = str(yaml_config["CSV_SEP"])
ted_url = str(yaml_config["TED_URL"])

# %%
### FUNCTIONS ###
def extract_text_by_line(pdf_path: str) -> str:
    """
    Extracts and prints the text from a PDF file, line by line.

    Args:
        pdf_path (str): The path to the PDF file to be processed.

    Returns:
        Optional[str]: Returns None if the file could not be opened, or if no text could be extracted.
    """
    # Initialize a list to hold all extracted text
    full_text = [] # Text of all lines in the PDF
    header_text = [] # Text in PDF header (to be found and avoided as footer)
    try:
        # Open the PDF file in binary read mode
        with open(pdf_path, 'rb') as file:
            # Create a PDF reader object
            pdf_reader = PyPDF2.PdfReader(file)
            
            # Loop through each page in the PDF
            for page_num, page in enumerate(pdf_reader.pages):
                # Extract text from the page
                page_text = page.extract_text()
                
                # Check if text was successfully extracted
                if page_text:
                    # Loop each line of text inside page_text
                    line_count = 0 # to detect header
                    parts_header = None
                    for line in page_text.split('\n'):
                        line_count+=1
                        # print("Line count:",line_count) # debug
                        # print("Line text:",line) # debug
                        if line_count <= 3:
                            header_text.append(line) # Trace the header text
                            if line_count == 1: # Special text in line 1 (header: GU/S S148 -> footer: 03/08/2022 S148)
                                parts_header = line.split(" ")
                                for part in parts_header:
                                    header_text.append(part)
                            if line_count == 2:
                                header_text.append(line)
                                h2 = f"{line} {parts_header[1]}"
                                header_text.append(h2)
                        if line_count > 3: # skip header text
                            if ted_url in line:
                                continue
                            else:
                                if line not in header_text: # not in header_text -> avoid the footer
                                    full_text.append(line)
                else:
                    print(f"Text could not be extracted from page {page_num + 1}")
    except FileNotFoundError:
        print(f"ERROR! File '{pdf_path}'. Error: not found.")
    except Exception as e:
        print(f"ERROR! File '{pdf_path}'. Error: {e}")
    finally:
        return full_text

# %%
def extract_elements_between_markers(string_list:list, start_marker:str, end_marker:str) -> list: 
    """
    Extracts a sublist of elements from the given list of strings, starting from the element that contains the start_marker and ending just before the element that contains the end_marker.

    Args:
        string_list (list of str): The list of strings to be processed.
        start_marker (str): The substring that marks the start of the extraction.
        end_marker (str): The substring that marks the end of the extraction.

    Returns:
        list of str: A sublist of the original list, containing elements between the start and end markers.
    """
    # Find the index of the start marker
    start_index = next((index for index, item in enumerate(string_list) if start_marker in item), None)
    # Find the index of the end marker
    end_index = next((index for index, item in enumerate(string_list) if end_marker in item), None)

    # Return the sublist if both markers are found
    if start_index is not None and end_index is not None and start_index < end_index:
        return string_list[start_index + 1:end_index]
    else:
        return []  # Return an empty list if markers are not found or in the wrong order

# %%
### MAIN ###
print()
print("*** PROGRAM START ***")
print()

start_time = datetime.now().replace(microsecond=0)
print("Start process:", str(start_time))
print()
# Out:
# *** PROGRAM START ***
#
# Start process: 2024-05-08 15:26:57

# %%
# Create list of PDF files
print(">> Listing PDF files")
print("Directory:", guue_dir)
list_pdf_files = list_files_by_type(guue_dir, "pdf")
list_pdf_files_len = len(list_pdf_files)
print("Files found:", list_pdf_files_len)
# print("Files:", list_csv_files) # debug
print()
# Out:
# >> Listing PDF files
# Directory: guue
# Files found: 1063

# %%
# Parse the files
print(">> Parsing PDF files")

i = 0

list_bid_opening_dic = [] # Container of texts of interest extracted from PDFs

for pdf_file in list_pdf_files:
    i+=1
    print(f"[{i} / {list_pdf_files_len}]")
    print("Reading (path):", str(pdf_file))
    text_list = extract_text_by_line(pdf_file) # Extracts all lines of text from the PDF
    text_list_len = len(text_list)
    # print(text_list) # debug

    # prepare the dictionary output for the actual PDF
    file_name = pdf_file.name # get only the file name in str
    dic_bid_opening = {"file_name":file_name, "text": None}
    
    print("Lines found in the PDF:", text_list_len)

    # get only lines about bid opening
    if text_list_len > 0:
        marker_list = extract_elements_between_markers(text_list, bid_opening_marker_start, bid_opening_marker_end) 
        marker_list_len = len(marker_list)
        # print(marker_list) # debug
        print("Bid opening strings found between markers:", marker_list_len)
        
        if marker_list_len > 0:
            marker_text = "|".join(marker_list)
            # print(marker_text) # debug
            dic_bid_opening["text"] = marker_text

    # save the file and the text found in bid opening section into a dictionary
    list_bid_opening_dic.append(dic_bid_opening)
    print()
# Out:
# >> Parsing PDF files
# [1 / 1063]
# Reading (path): guue/2016-OJS003-002872-it.pdf
# Lines found in the PDF: 186
# Bid opening strings found: 6
#
# [2 / 1063]
# Reading (path): guue/2016-OJS004-004078-it.pdf
# Lines found in the PDF: 122
# Bid opening strings found: 0
#
# [3 / 1063]
# Reading (path): guue/2016-OJS008-009964-it.pdf
# Lines found in the PDF: 155
# Bid opening strings found: 6
#
# [4 / 1063]
# Reading (path): guue/2016-OJS011-015326-it.pdf
# Lines found in the PDF: 179
# Bid opening strings found: 5
#
# [5 / 1063]
# Reading (path): guue/2016-OJS012-017147-it.pdf
# Lines found in the PDF: 161
# Bid opening strings found: 3
#
# [6 / 1063]
# Reading (path): guue/2016-OJS022-035271-it.pdf
# Lines found in the PDF: 152
# Bid opening strings found: 6
#
# [7 / 1063]
# Reading (path): guue/2016-OJS022-035325-it.pdf
# Lines found in the PDF: 530
# Bid opening strings found: 6
#
# [8 / 1063]
# Reading (path): guue/2016-OJS023-036422-it.pdf
# Lines found in the PDF: 378
# Bid opening strings found: 3
#
# [9 / 1063]
# Reading (path): guue/2016-OJS025-040488-it.pdf
# Lines found in the PDF: 214
# Bid opening strings found: 8
#
# [10 / 1063]
# Reading (path): guue/2016-OJS029-047040-it.pdf
# Lines found in the PDF: 237
# Bid opening strings found: 4
#
# [11 / 1063]
# Reading (path): guue/2016-OJS032-051841-it.pdf
# Lines found in the PDF: 156
# Bid opening strings found: 3
#
# [12 / 1063]
# Reading (path): guue/2016-OJS033-053596-it.pdf
# Lines found in the PDF: 183
# Bid opening strings found: 7
#
# [13 / 1063]
# Reading (path): guue/2016-OJS035-056620-it.pdf
# Lines found in the PDF: 242
# Bid opening strings found: 7
#
# [14 / 1063]
# Reading (path): guue/2016-OJS042-069583-it.pdf
# Lines found in the PDF: 401
# Bid opening strings found: 9
#
# [15 / 1063]
# Reading (path): guue/2016-OJS043-071175-it.pdf
# Lines found in the PDF: 199
# Bid opening strings found: 8
#
# [16 / 1063]
# Reading (path): guue/2016-OJS043-071190-it.pdf
# Lines found in the PDF: 167
# Bid opening strings found: 6
#
# [17 / 1063]
# Reading (path): guue/2016-OJS047-078534-it.pdf
# Lines found in the PDF: 193
# Bid opening strings found: 6
#
# [18 / 1063]
# Reading (path): guue/2016-OJS048-079969-it.pdf
# Lines found in the PDF: 141
# Bid opening strings found: 6
#
# [19 / 1063]
# Reading (path): guue/2016-OJS048-080250-it.pdf
# Lines found in the PDF: 142
# Bid opening strings found: 1
#
# [20 / 1063]
# Reading (path): guue/2016-OJS052-087129-it.pdf
# Lines found in the PDF: 180
# Bid opening strings found: 5
#
# [21 / 1063]
# Reading (path): guue/2016-OJS052-087359-it.pdf
# Lines found in the PDF: 185
# Bid opening strings found: 5
#
# [22 / 1063]
# Reading (path): guue/2016-OJS052-087379-it.pdf
# Lines found in the PDF: 110
# Bid opening strings found: 1
#
# [23 / 1063]
# Reading (path): guue/2016-OJS053-089086-it.pdf
# Lines found in the PDF: 188
# Bid opening strings found: 7
#
# [24 / 1063]
# Reading (path): guue/2016-OJS056-093911-it.pdf
# Lines found in the PDF: 300
# Bid opening strings found: 5
#
# [25 / 1063]
# Reading (path): guue/2016-OJS056-094033-it.pdf
# Lines found in the PDF: 158
# Bid opening strings found: 4
#
# [26 / 1063]
# Reading (path): guue/2016-OJS057-096294-it.pdf
# Lines found in the PDF: 140
# Bid opening strings found: 5
#
# [27 / 1063]
# Reading (path): guue/2016-OJS058-097927-it.pdf
# Lines found in the PDF: 107
# Bid opening strings found: 0
#
# [28 / 1063]
# Reading (path): guue/2016-OJS059-099856-it.pdf
# Lines found in the PDF: 173
# Bid opening strings found: 6
#
# [29 / 1063]
# Reading (path): guue/2016-OJS061-102606-it.pdf
# Lines found in the PDF: 91
# Bid opening strings found: 0
#
# [30 / 1063]
# Reading (path): guue/2016-OJS062-107163-it.pdf
# Lines found in the PDF: 178
# Bid opening strings found: 6
#
# [31 / 1063]
# Reading (path): guue/2016-OJS065-112699-it.pdf
# Lines found in the PDF: 199
# Bid opening strings found: 3
#
# [32 / 1063]
# Reading (path): guue/2016-OJS066-114079-it.pdf
# Lines found in the PDF: 193
# Bid opening strings found: 4
#
# [33 / 1063]
# Reading (path): guue/2016-OJS066-114659-it.pdf
# Lines found in the PDF: 145
# Bid opening strings found: 7
#
# [34 / 1063]
# Reading (path): guue/2016-OJS066-115352-it.pdf
# Lines found in the PDF: 158
# Bid opening strings found: 7
#
# [35 / 1063]
# Reading (path): guue/2016-OJS066-115445-it.pdf
# Lines found in the PDF: 153
# Bid opening strings found: 6
#
# [36 / 1063]
# Reading (path): guue/2016-OJS067-117315-it.pdf
# Lines found in the PDF: 137
# Bid opening strings found: 5
#
# [37 / 1063]
# Reading (path): guue/2016-OJS067-117323-it.pdf
# Lines found in the PDF: 201
# Bid opening strings found: 9
#
# [38 / 1063]
# Reading (path): guue/2016-OJS068-118823-it.pdf
# Lines found in the PDF: 158
# Bid opening strings found: 3
#
# [39 / 1063]
# Reading (path): guue/2016-OJS069-120532-it.pdf
# Lines found in the PDF: 163
# Bid opening strings found: 6
#
# [40 / 1063]
# Reading (path): guue/2016-OJS069-120555-it.pdf
# Lines found in the PDF: 185
# Bid opening strings found: 5
#
# [41 / 1063]
# Reading (path): guue/2016-OJS069-120729-it.pdf
# Lines found in the PDF: 191
# Bid opening strings found: 6
#
# [42 / 1063]
# Reading (path): guue/2016-OJS069-120768-it.pdf
# Lines found in the PDF: 148
# Bid opening strings found: 5
#
# [43 / 1063]
# Reading (path): guue/2016-OJS070-122509-it.pdf
# Lines found in the PDF: 204
# Bid opening strings found: 5
#
# [44 / 1063]
# Reading (path): guue/2016-OJS070-122592-it.pdf
# Lines found in the PDF: 162
# Bid opening strings found: 6
#
# [45 / 1063]
# Reading (path): guue/2016-OJS070-122672-it.pdf
# Lines found in the PDF: 201
# Bid opening strings found: 7
#
# [46 / 1063]
# Reading (path): guue/2016-OJS070-122683-it.pdf
# Lines found in the PDF: 161
# Bid opening strings found: 4
#
# [47 / 1063]
# Reading (path): guue/2016-OJS071-123451-it.pdf
# Lines found in the PDF: 143
# Bid opening strings found: 6
#
# [48 / 1063]
# Reading (path): guue/2016-OJS071-123565-it.pdf
# Lines found in the PDF: 123
# Bid opening strings found: 0
#
# [49 / 1063]
# Reading (path): guue/2016-OJS071-124507-it.pdf
# Lines found in the PDF: 324
# Bid opening strings found: 7
#
# [50 / 1063]
# Reading (path): guue/2016-OJS072-126144-it.pdf
# Lines found in the PDF: 156
# Bid opening strings found: 5
#
# [51 / 1063]
# Reading (path): guue/2016-OJS072-126198-it.pdf
# Lines found in the PDF: 205
# Bid opening strings found: 6
#
# [52 / 1063]
# Reading (path): guue/2016-OJS072-126203-it.pdf
# Lines found in the PDF: 272
# Bid opening strings found: 5
#
# [53 / 1063]
# Reading (path): guue/2016-OJS073-127692-it.pdf
# Lines found in the PDF: 154
# Bid opening strings found: 5
#
# [54 / 1063]
# Reading (path): guue/2016-OJS073-127779-it.pdf
# Lines found in the PDF: 207
# Bid opening strings found: 9
#
# [55 / 1063]
# Reading (path): guue/2016-OJS073-127812-it.pdf
# Lines found in the PDF: 379
# Bid opening strings found: 12
#
# [56 / 1063]
# Reading (path): guue/2016-OJS073-127837-it.pdf
# Lines found in the PDF: 176
# Bid opening strings found: 6
#
# [57 / 1063]
# Reading (path): guue/2016-OJS074-129505-it.pdf
# Lines found in the PDF: 191
# Bid opening strings found: 8
#
# [58 / 1063]
# Reading (path): guue/2016-OJS074-129527-it.pdf
# Lines found in the PDF: 233
# Bid opening strings found: 5
#
# [59 / 1063]
# Reading (path): guue/2016-OJS074-129536-it.pdf
# Lines found in the PDF: 177
# Bid opening strings found: 6
#
# [60 / 1063]
# Reading (path): guue/2016-OJS074-129540-it.pdf
# Lines found in the PDF: 112
# Bid opening strings found: 1
#
# [61 / 1063]
# Reading (path): guue/2016-OJS074-129718-it.pdf
# Lines found in the PDF: 157
# Bid opening strings found: 5
#
# [62 / 1063]
# Reading (path): guue/2016-OJS075-130393-it.pdf
# Lines found in the PDF: 130
# Bid opening strings found: 4
#
# [63 / 1063]
# Reading (path): guue/2016-OJS075-131663-it.pdf
# Lines found in the PDF: 213
# Bid opening strings found: 7
#
# [64 / 1063]
# Reading (path): guue/2016-OJS075-131875-it.pdf
# Lines found in the PDF: 238
# Bid opening strings found: 8
#
# [65 / 1063]
# Reading (path): guue/2016-OJS075-131877-it.pdf
# Lines found in the PDF: 199
# Bid opening strings found: 6
#
# [66 / 1063]
# Reading (path): guue/2016-OJS075-131908-it.pdf
# Lines found in the PDF: 195
# Bid opening strings found: 7
#
# [67 / 1063]
# Reading (path): guue/2016-OJS075-131963-it.pdf
# Lines found in the PDF: 352
# Bid opening strings found: 11
#
# [68 / 1063]
# Reading (path): guue/2016-OJS075-131967-it.pdf
# Lines found in the PDF: 131
# Bid opening strings found: 6
#
# [69 / 1063]
# Reading (path): guue/2016-OJS075-131992-it.pdf
# Lines found in the PDF: 178
# Bid opening strings found: 6
#
# [70 / 1063]
# Reading (path): guue/2016-OJS075-132020-it.pdf
# Lines found in the PDF: 176
# Bid opening strings found: 6
#
# [71 / 1063]
# Reading (path): guue/2016-OJS076-132890-it.pdf
# Lines found in the PDF: 124
# Bid opening strings found: 4
#
# [72 / 1063]
# Reading (path): guue/2016-OJS076-134104-it.pdf
# Lines found in the PDF: 164
# Bid opening strings found: 4
#
# [73 / 1063]
# Reading (path): guue/2016-OJS076-134166-it.pdf
# Lines found in the PDF: 208
# Bid opening strings found: 4
#
# [74 / 1063]
# Reading (path): guue/2016-OJS076-134206-it.pdf
# Lines found in the PDF: 299
# Bid opening strings found: 6
#
# [75 / 1063]
# Reading (path): guue/2016-OJS076-134384-it.pdf
# Lines found in the PDF: 283
# Bid opening strings found: 7
#
# [76 / 1063]
# Reading (path): guue/2016-OJS077-136740-it.pdf
# Lines found in the PDF: 315
# Bid opening strings found: 6
#
# [77 / 1063]
# Reading (path): guue/2016-OJS077-136748-it.pdf
# Lines found in the PDF: 169
# Bid opening strings found: 6
#
# [78 / 1063]
# Reading (path): guue/2016-OJS077-136755-it.pdf
# Lines found in the PDF: 159
# Bid opening strings found: 5
#
# [79 / 1063]
# Reading (path): guue/2016-OJS077-136804-it.pdf
# Lines found in the PDF: 180
# Bid opening strings found: 6
#
# [80 / 1063]
# Reading (path): guue/2016-OJS077-137290-it.pdf
# Lines found in the PDF: 205
# Bid opening strings found: 6
#
# [81 / 1063]
# Reading (path): guue/2016-OJS077-137350-it.pdf
# Lines found in the PDF: 155
# Bid opening strings found: 6
#
# [82 / 1063]
# Reading (path): guue/2016-OJS079-140353-it.pdf
# Lines found in the PDF: 160
# Bid opening strings found: 3
#
# [83 / 1063]
# Reading (path): guue/2016-OJS079-140372-it.pdf
# Lines found in the PDF: 222
# Bid opening strings found: 8
#
# [84 / 1063]
# Reading (path): guue/2016-OJS079-140376-it.pdf
# Lines found in the PDF: 155
# Bid opening strings found: 3
#
# [85 / 1063]
# Reading (path): guue/2016-OJS080-142425-it.pdf
# Lines found in the PDF: 161
# Bid opening strings found: 5
#
# [86 / 1063]
# Reading (path): guue/2016-OJS084-148762-it.pdf
# Lines found in the PDF: 187
# Bid opening strings found: 4
#
# [87 / 1063]
# Reading (path): guue/2016-OJS088-154767-it.pdf
# Lines found in the PDF: 98
# Bid opening strings found: 2
#
# [88 / 1063]
# Reading (path): guue/2016-OJS089-158591-it.pdf
# Lines found in the PDF: 182
# Bid opening strings found: 3
#
# [89 / 1063]
# Reading (path): guue/2016-OJS090-160175-it.pdf
# Lines found in the PDF: 112
# Bid opening strings found: 2
#
# [90 / 1063]
# Reading (path): guue/2016-OJS096-171748-it.pdf
# Lines found in the PDF: 164
# Bid opening strings found: 8
#
# [91 / 1063]
# Reading (path): guue/2016-OJS100-178309-it.pdf
# Lines found in the PDF: 99
# Bid opening strings found: 6
#
# [92 / 1063]
# Reading (path): guue/2016-OJS101-179923-it.pdf
# Lines found in the PDF: 173
# Bid opening strings found: 4
#
# [93 / 1063]
# Reading (path): guue/2016-OJS101-180626-it.pdf
# Lines found in the PDF: 219
# Bid opening strings found: 3
#
# [94 / 1063]
# Reading (path): guue/2016-OJS102-182834-it.pdf
# Lines found in the PDF: 199
# Bid opening strings found: 6
#
# [95 / 1063]
# Reading (path): guue/2016-OJS106-188718-it.pdf
# Lines found in the PDF: 180
# Bid opening strings found: 0
#
# [96 / 1063]
# Reading (path): guue/2016-OJS107-190403-it.pdf
# Lines found in the PDF: 162
# Bid opening strings found: 2
#
# [97 / 1063]
# Reading (path): guue/2016-OJS107-190454-it.pdf
# Lines found in the PDF: 100
# Bid opening strings found: 4
#
# [98 / 1063]
# Reading (path): guue/2016-OJS107-191663-it.pdf
# Lines found in the PDF: 298
# Bid opening strings found: 7
#
# [99 / 1063]
# Reading (path): guue/2016-OJS109-195278-it.pdf
# Lines found in the PDF: 138
# Bid opening strings found: 2
#
# [100 / 1063]
# Reading (path): guue/2016-OJS111-197203-it.pdf
# Lines found in the PDF: 212
# Bid opening strings found: 9
#
# [101 / 1063]
# Reading (path): guue/2016-OJS112-199994-it.pdf
# Lines found in the PDF: 119
# Bid opening strings found: 7
#
# [102 / 1063]
# Reading (path): guue/2016-OJS113-200934-it.pdf
# Lines found in the PDF: 96
# Bid opening strings found: 2
#
# [103 / 1063]
# Reading (path): guue/2016-OJS113-201153-it.pdf
# Lines found in the PDF: 122
# Bid opening strings found: 0
#
# [104 / 1063]
# Reading (path): guue/2016-OJS114-203565-it.pdf
# Lines found in the PDF: 159
# Bid opening strings found: 4
#
# [105 / 1063]
# Reading (path): guue/2016-OJS115-204348-it.pdf
# Lines found in the PDF: 193
# Bid opening strings found: 7
#
# [106 / 1063]
# Reading (path): guue/2016-OJS115-205085-it.pdf
# Lines found in the PDF: 144
# Bid opening strings found: 5
#
# [107 / 1063]
# Reading (path): guue/2016-OJS117-207907-it.pdf
# Lines found in the PDF: 199
# Bid opening strings found: 8
#
# [108 / 1063]
# Reading (path): guue/2016-OJS117-209054-it.pdf
# Lines found in the PDF: 166
# Bid opening strings found: 2
#
# [109 / 1063]
# Reading (path): guue/2016-OJS118-210742-it.pdf
# Lines found in the PDF: 141
# Bid opening strings found: 6
#
# [110 / 1063]
# Reading (path): guue/2016-OJS118-210777-it.pdf
# Lines found in the PDF: 270
# Bid opening strings found: 6
#
# [111 / 1063]
# Reading (path): guue/2016-OJS119-211568-it.pdf
# Lines found in the PDF: 104
# Bid opening strings found: 6
#
# [112 / 1063]
# Reading (path): guue/2016-OJS121-215176-it.pdf
# Lines found in the PDF: 104
# Bid opening strings found: 6
#
# [113 / 1063]
# Reading (path): guue/2016-OJS121-215215-it.pdf
# Lines found in the PDF: 125
# Bid opening strings found: 4
#
# [114 / 1063]
# Reading (path): guue/2016-OJS121-215235-it.pdf
# Lines found in the PDF: 108
# Bid opening strings found: 2
#
# [115 / 1063]
# Reading (path): guue/2016-OJS121-217048-it.pdf
# Lines found in the PDF: 278
# Bid opening strings found: 6
#
# [116 / 1063]
# Reading (path): guue/2016-OJS121-217076-it.pdf
# Lines found in the PDF: 164
# Bid opening strings found: 6
#
# [117 / 1063]
# Reading (path): guue/2016-OJS121-217081-it.pdf
# Lines found in the PDF: 179
# Bid opening strings found: 6
#
# [118 / 1063]
# Reading (path): guue/2016-OJS121-217128-it.pdf
# Lines found in the PDF: 178
# Bid opening strings found: 7
#
# [119 / 1063]
# Reading (path): guue/2016-OJS121-217157-it.pdf
# Lines found in the PDF: 152
# Bid opening strings found: 6
#
# [120 / 1063]
# Reading (path): guue/2016-OJS122-218393-it.pdf
# Lines found in the PDF: 109
# Bid opening strings found: 5
#
# [121 / 1063]
# Reading (path): guue/2016-OJS122-219279-it.pdf
# Lines found in the PDF: 218
# Bid opening strings found: 9
#
# [122 / 1063]
# Reading (path): guue/2016-OJS122-219326-it.pdf
# Lines found in the PDF: 177
# Bid opening strings found: 5
#
# [123 / 1063]
# Reading (path): guue/2016-OJS123-220466-it.pdf
# Lines found in the PDF: 134
# Bid opening strings found: 0
#
# [124 / 1063]
# Reading (path): guue/2016-OJS126-225294-it.pdf
# Lines found in the PDF: 242
# Bid opening strings found: 9
#
# [125 / 1063]
# Reading (path): guue/2016-OJS126-225308-it.pdf
# Lines found in the PDF: 110
# Bid opening strings found: 2
#
# [126 / 1063]
# Reading (path): guue/2016-OJS126-225418-it.pdf
# Lines found in the PDF: 138
# Bid opening strings found: 6
#
# [127 / 1063]
# Reading (path): guue/2016-OJS127-227729-it.pdf
# Lines found in the PDF: 256
# Bid opening strings found: 6
#
# [128 / 1063]
# Reading (path): guue/2016-OJS129-232027-it.pdf
# Lines found in the PDF: 171
# Bid opening strings found: 7
#
# [129 / 1063]
# Reading (path): guue/2016-OJS131-235082-it.pdf
# Lines found in the PDF: 156
# Bid opening strings found: 6
#
# [130 / 1063]
# Reading (path): guue/2016-OJS131-235151-it.pdf
# Lines found in the PDF: 227
# Bid opening strings found: 10
#
# [131 / 1063]
# Reading (path): guue/2016-OJS132-237538-it.pdf
# Lines found in the PDF: 288
# Bid opening strings found: 6
#
# [132 / 1063]
# Reading (path): guue/2016-OJS132-237553-it.pdf
# Lines found in the PDF: 191
# Bid opening strings found: 6
#
# [133 / 1063]
# Reading (path): guue/2016-OJS134-241982-it.pdf
# Lines found in the PDF: 208
# Bid opening strings found: 5
#
# [134 / 1063]
# Reading (path): guue/2016-OJS136-244786-it.pdf
# Lines found in the PDF: 188
# Bid opening strings found: 6
#
# [135 / 1063]
# Reading (path): guue/2016-OJS137-248912-it.pdf
# Lines found in the PDF: 173
# Bid opening strings found: 2
#
# [136 / 1063]
# Reading (path): guue/2016-OJS137-248919-it.pdf
# Lines found in the PDF: 167
# Bid opening strings found: 8
#
# [137 / 1063]
# Reading (path): guue/2016-OJS139-251438-it.pdf
# Lines found in the PDF: 109
# Bid opening strings found: 6
#
# [138 / 1063]
# Reading (path): guue/2016-OJS141-254636-it.pdf
# Lines found in the PDF: 144
# Bid opening strings found: 6
#
# [139 / 1063]
# Reading (path): guue/2016-OJS141-254762-it.pdf
# Lines found in the PDF: 112
# Bid opening strings found: 4
#
# [140 / 1063]
# Reading (path): guue/2016-OJS142-257617-it.pdf
# Lines found in the PDF: 185
# Bid opening strings found: 3
#
# [141 / 1063]
# Reading (path): guue/2016-OJS143-258641-it.pdf
# Lines found in the PDF: 103
# Bid opening strings found: 2
#
# [142 / 1063]
# Reading (path): guue/2016-OJS145-261595-it.pdf
# Lines found in the PDF: 119
# Bid opening strings found: 6
#
# [143 / 1063]
# Reading (path): guue/2016-OJS146-264439-it.pdf
# Lines found in the PDF: 365
# Bid opening strings found: 5
#
# [144 / 1063]
# Reading (path): guue/2016-OJS146-264923-it.pdf
# Lines found in the PDF: 295
# Bid opening strings found: 4
#
# [145 / 1063]
# Reading (path): guue/2016-OJS148-267681-it.pdf
# Lines found in the PDF: 153
# Bid opening strings found: 4
#
# [146 / 1063]
# Reading (path): guue/2016-OJS148-267787-it.pdf
# Lines found in the PDF: 149
# Bid opening strings found: 4
#
# [147 / 1063]
# Reading (path): guue/2016-OJS148-267824-it.pdf
# Lines found in the PDF: 189
# Bid opening strings found: 6
#
# [148 / 1063]
# Reading (path): guue/2016-OJS148-268788-it.pdf
# Lines found in the PDF: 162
# Bid opening strings found: 6
#
# [149 / 1063]
# Reading (path): guue/2016-OJS151-273307-it.pdf
# Lines found in the PDF: 169
# Bid opening strings found: 9
#
# [150 / 1063]
# Reading (path): guue/2016-OJS152-275290-it.pdf
# Lines found in the PDF: 286
# Bid opening strings found: 6
#
# [151 / 1063]
# Reading (path): guue/2016-OJS152-276132-it.pdf
# Lines found in the PDF: 170
# Bid opening strings found: 7
#
# [152 / 1063]
# Reading (path): guue/2016-OJS154-278700-it.pdf
# Lines found in the PDF: 202
# Bid opening strings found: 6
#
# [153 / 1063]
# Reading (path): guue/2016-OJS156-282539-it.pdf
# Lines found in the PDF: 394
# Bid opening strings found: 8
#
# [154 / 1063]
# Reading (path): guue/2016-OJS156-282684-it.pdf
# Lines found in the PDF: 263
# Bid opening strings found: 2
#
# [155 / 1063]
# Reading (path): guue/2016-OJS159-287580-it.pdf
# Lines found in the PDF: 166
# Bid opening strings found: 7
#
# [156 / 1063]
# Reading (path): guue/2016-OJS159-288527-it.pdf
# Lines found in the PDF: 131
# Bid opening strings found: 6
#
# [157 / 1063]
# Reading (path): guue/2016-OJS161-290939-it.pdf
# Lines found in the PDF: 155
# Bid opening strings found: 7
#
# [158 / 1063]
# Reading (path): guue/2016-OJS161-290967-it.pdf
# Lines found in the PDF: 178
# Bid opening strings found: 7
#
# [159 / 1063]
# Reading (path): guue/2016-OJS162-293157-it.pdf
# Lines found in the PDF: 216
# Bid opening strings found: 5
#
# [160 / 1063]
# Reading (path): guue/2016-OJS164-296126-it.pdf
# Lines found in the PDF: 244
# Bid opening strings found: 15
#
# [161 / 1063]
# Reading (path): guue/2016-OJS167-300464-it.pdf
# Lines found in the PDF: 219
# Bid opening strings found: 6
#
# [162 / 1063]
# Reading (path): guue/2016-OJS170-306597-it.pdf
# Lines found in the PDF: 193
# Bid opening strings found: 5
#
# [163 / 1063]
# Reading (path): guue/2016-OJS172-309959-it.pdf
# Lines found in the PDF: 186
# Bid opening strings found: 7
#
# [164 / 1063]
# Reading (path): guue/2016-OJS172-309981-it.pdf
# Lines found in the PDF: 214
# Bid opening strings found: 5
#
# [165 / 1063]
# Reading (path): guue/2016-OJS175-315170-it.pdf
# Lines found in the PDF: 228
# Bid opening strings found: 4
#
# [166 / 1063]
# Reading (path): guue/2016-OJS176-316026-it.pdf
# Lines found in the PDF: 155
# Bid opening strings found: 4
#
# [167 / 1063]
# Reading (path): guue/2016-OJS177-317670-it.pdf
# Lines found in the PDF: 109
# Bid opening strings found: 2
#
# [168 / 1063]
# Reading (path): guue/2016-OJS181-325675-it.pdf
# Lines found in the PDF: 381
# Bid opening strings found: 13
#
# [169 / 1063]
# Reading (path): guue/2016-OJS182-326679-it.pdf
# Lines found in the PDF: 109
# Bid opening strings found: 2
#
# [170 / 1063]
# Reading (path): guue/2016-OJS185-331858-it.pdf
# Lines found in the PDF: 141
# Bid opening strings found: 4
#
# [171 / 1063]
# Reading (path): guue/2016-OJS185-331873-it.pdf
# Lines found in the PDF: 235
# Bid opening strings found: 6
#
# [172 / 1063]
# Reading (path): guue/2016-OJS185-333059-it.pdf
# Lines found in the PDF: 191
# Bid opening strings found: 3
#
# [173 / 1063]
# Reading (path): guue/2016-OJS187-336053-it.pdf
# Lines found in the PDF: 105
# Bid opening strings found: 0
#
# [174 / 1063]
# Reading (path): guue/2016-OJS190-340721-it.pdf
# Lines found in the PDF: 163
# Bid opening strings found: 8
#
# [175 / 1063]
# Reading (path): guue/2016-OJS190-340874-it.pdf
# Lines found in the PDF: 182
# Bid opening strings found: 8
#
# [176 / 1063]
# Reading (path): guue/2016-OJS190-342194-it.pdf
# Lines found in the PDF: 243
# Bid opening strings found: 5
#
# [177 / 1063]
# Reading (path): guue/2016-OJS192-345467-it.pdf
# Lines found in the PDF: 163
# Bid opening strings found: 6
#
# [178 / 1063]
# Reading (path): guue/2016-OJS192-346112-it.pdf
# Lines found in the PDF: 339
# Bid opening strings found: 4
#
# [179 / 1063]
# Reading (path): guue/2016-OJS193-347486-it.pdf
# Lines found in the PDF: 137
# Bid opening strings found: 4
#
# [180 / 1063]
# Reading (path): guue/2016-OJS193-348178-it.pdf
# Lines found in the PDF: 244
# Bid opening strings found: 7
#
# [181 / 1063]
# Reading (path): guue/2016-OJS194-349016-it.pdf
# Lines found in the PDF: 141
# Bid opening strings found: 7
#
# [182 / 1063]
# Reading (path): guue/2016-OJS194-349020-it.pdf
# Lines found in the PDF: 356
# Bid opening strings found: 6
#
# [183 / 1063]
# Reading (path): guue/2016-OJS195-351207-it.pdf
# Lines found in the PDF: 151
# Bid opening strings found: 9
#
# [184 / 1063]
# Reading (path): guue/2016-OJS195-352356-it.pdf
# Lines found in the PDF: 164
# Bid opening strings found: 6
#
# [185 / 1063]
# Reading (path): guue/2016-OJS197-355929-it.pdf
# Lines found in the PDF: 245
# Bid opening strings found: 5
#
# [186 / 1063]
# Reading (path): guue/2016-OJS199-358547-it.pdf
# Lines found in the PDF: 123
# Bid opening strings found: 6
#
# [187 / 1063]
# Reading (path): guue/2016-OJS199-358655-it.pdf
# Lines found in the PDF: 179
# Bid opening strings found: 8
#
# [188 / 1063]
# Reading (path): guue/2016-OJS199-359602-it.pdf
# Lines found in the PDF: 232
# Bid opening strings found: 4
#
# [189 / 1063]
# Reading (path): guue/2016-OJS199-359633-it.pdf
# Lines found in the PDF: 176
# Bid opening strings found: 6
#
# [190 / 1063]
# Reading (path): guue/2016-OJS199-359690-it.pdf
# Lines found in the PDF: 159
# Bid opening strings found: 6
#
# [191 / 1063]
# Reading (path): guue/2016-OJS200-360905-it.pdf
# Lines found in the PDF: 104
# Bid opening strings found: 4
#
# [192 / 1063]
# Reading (path): guue/2016-OJS200-361902-it.pdf
# Lines found in the PDF: 256
# Bid opening strings found: 6
#
# [193 / 1063]
# Reading (path): guue/2016-OJS201-362988-it.pdf
# Lines found in the PDF: 154
# Bid opening strings found: 6
#
# [194 / 1063]
# Reading (path): guue/2016-OJS201-363044-it.pdf
# Lines found in the PDF: 214
# Bid opening strings found: 11
#
# [195 / 1063]
# Reading (path): guue/2016-OJS201-364062-it.pdf
# Lines found in the PDF: 274
# Bid opening strings found: 6
#
# [196 / 1063]
# Reading (path): guue/2016-OJS201-364102-it.pdf
# Lines found in the PDF: 173
# Bid opening strings found: 4
#
# [197 / 1063]
# Reading (path): guue/2016-OJS202-365941-it.pdf
# Lines found in the PDF: 194
# Bid opening strings found: 7
#
# [198 / 1063]
# Reading (path): guue/2016-OJS205-370974-it.pdf
# Lines found in the PDF: 138
# Bid opening strings found: 4
#
# [199 / 1063]
# Reading (path): guue/2016-OJS205-372022-it.pdf
# Lines found in the PDF: 220
# Bid opening strings found: 6
#
# [200 / 1063]
# Reading (path): guue/2016-OJS206-373077-it.pdf
# Lines found in the PDF: 155
# Bid opening strings found: 6
#
# [201 / 1063]
# Reading (path): guue/2016-OJS206-373833-it.pdf
# Lines found in the PDF: 221
# Bid opening strings found: 5
#
# [202 / 1063]
# Reading (path): guue/2016-OJS207-374772-it.pdf
# Lines found in the PDF: 220
# Bid opening strings found: 7
#
# [203 / 1063]
# Reading (path): guue/2016-OJS209-378341-it.pdf
# Lines found in the PDF: 155
# Bid opening strings found: 6
#
# [204 / 1063]
# Reading (path): guue/2016-OJS209-379741-it.pdf
# Lines found in the PDF: 235
# Bid opening strings found: 9
#
# [205 / 1063]
# Reading (path): guue/2016-OJS210-381156-it.pdf
# Lines found in the PDF: 118
# Bid opening strings found: 4
#
# [206 / 1063]
# Reading (path): guue/2016-OJS210-382869-it.pdf
# Lines found in the PDF: 166
# Bid opening strings found: 6
#
# [207 / 1063]
# Reading (path): guue/2016-OJS210-382959-it.pdf
# Lines found in the PDF: 269
# Bid opening strings found: 7
#
# [208 / 1063]
# Reading (path): guue/2016-OJS211-385265-it.pdf
# Lines found in the PDF: 197
# Bid opening strings found: 6
#
# [209 / 1063]
# Reading (path): guue/2016-OJS213-388830-it.pdf
# Lines found in the PDF: 186
# Bid opening strings found: 4
#
# [210 / 1063]
# Reading (path): guue/2016-OJS213-388917-it.pdf
# Lines found in the PDF: 256
# Bid opening strings found: 1
#
# [211 / 1063]
# Reading (path): guue/2016-OJS216-393460-it.pdf
# Lines found in the PDF: 145
# Bid opening strings found: 8
#
# [212 / 1063]
# Reading (path): guue/2016-OJS218-397011-it.pdf
# Lines found in the PDF: 177
# Bid opening strings found: 9
#
# [213 / 1063]
# Reading (path): guue/2016-OJS219-399027-it.pdf
# Lines found in the PDF: 102
# Bid opening strings found: 2
#
# [214 / 1063]
# Reading (path): guue/2016-OJS219-399039-it.pdf
# Lines found in the PDF: 134
# Bid opening strings found: 6
#
# [215 / 1063]
# Reading (path): guue/2016-OJS219-400078-it.pdf
# Lines found in the PDF: 156
# Bid opening strings found: 3
#
# [216 / 1063]
# Reading (path): guue/2016-OJS220-401082-it.pdf
# Lines found in the PDF: 240
# Bid opening strings found: 6
#
# [217 / 1063]
# Reading (path): guue/2016-OJS221-402865-it.pdf
# Lines found in the PDF: 123
# Bid opening strings found: 6
#
# [218 / 1063]
# Reading (path): guue/2016-OJS222-405382-it.pdf
# Lines found in the PDF: 318
# Bid opening strings found: 7
#
# [219 / 1063]
# Reading (path): guue/2016-OJS222-405395-it.pdf
# Lines found in the PDF: 236
# Bid opening strings found: 5
#
# [220 / 1063]
# Reading (path): guue/2016-OJS223-406583-it.pdf
# Lines found in the PDF: 106
# Bid opening strings found: 4
#
# [221 / 1063]
# Reading (path): guue/2016-OJS228-414925-it.pdf
# Lines found in the PDF: 102
# Bid opening strings found: 2
#
# [222 / 1063]
# Reading (path): guue/2016-OJS228-415416-it.pdf
# Lines found in the PDF: 153
# Bid opening strings found: 4
#
# [223 / 1063]
# Reading (path): guue/2016-OJS233-424364-it.pdf
# Lines found in the PDF: 195
# Bid opening strings found: 6
#
# [224 / 1063]
# Reading (path): guue/2016-OJS233-424442-it.pdf
# Lines found in the PDF: 192
# Bid opening strings found: 7
#
# [225 / 1063]
# Reading (path): guue/2016-OJS233-424537-it.pdf
# Lines found in the PDF: 230
# Bid opening strings found: 7
#
# [226 / 1063]
# Reading (path): guue/2016-OJS236-429964-it.pdf
# Lines found in the PDF: 210
# Bid opening strings found: 5
#
# [227 / 1063]
# Reading (path): guue/2016-OJS238-433468-it.pdf
# Lines found in the PDF: 148
# Bid opening strings found: 7
#
# [228 / 1063]
# Reading (path): guue/2016-OJS239-435748-it.pdf
# Lines found in the PDF: 137
# Bid opening strings found: 6
#
# [229 / 1063]
# Reading (path): guue/2016-OJS239-436597-it.pdf
# Lines found in the PDF: 163
# Bid opening strings found: 5
#
# [230 / 1063]
# Reading (path): guue/2016-OJS243-443577-it.pdf
# Lines found in the PDF: 142
# Bid opening strings found: 2
#
# [231 / 1063]
# Reading (path): guue/2016-OJS243-444454-it.pdf
# Lines found in the PDF: 160
# Bid opening strings found: 6
#
# [232 / 1063]
# Reading (path): guue/2016-OJS245-447604-it.pdf
# Lines found in the PDF: 157
# Bid opening strings found: 6
#
# [233 / 1063]
# Reading (path): guue/2016-OJS247-451477-it.pdf
# Lines found in the PDF: 104
# Bid opening strings found: 2
#
# [234 / 1063]
# Reading (path): guue/2016-OJS249-458112-it.pdf
# Lines found in the PDF: 106
# Bid opening strings found: 4
#
# [235 / 1063]
# Reading (path): guue/2016-OJS249-459785-it.pdf
# Lines found in the PDF: 361
# Bid opening strings found: 6
#
# [236 / 1063]
# Reading (path): guue/2017-OJS001-000860-it.pdf
# Lines found in the PDF: 121
# Bid opening strings found: 0
#
# [237 / 1063]
# Reading (path): guue/2017-OJS001-001207-it.pdf
# Lines found in the PDF: 354
# Bid opening strings found: 5
#
# [238 / 1063]
# Reading (path): guue/2017-OJS001-001210-it.pdf
# Lines found in the PDF: 214
# Bid opening strings found: 8
#
# [239 / 1063]
# Reading (path): guue/2017-OJS005-006924-it.pdf
# Lines found in the PDF: 125
# Bid opening strings found: 2
#
# [240 / 1063]
# Reading (path): guue/2017-OJS007-010237-it.pdf
# Lines found in the PDF: 129
# Bid opening strings found: 2
#
# [241 / 1063]
# Reading (path): guue/2017-OJS014-022032-it.pdf
# Lines found in the PDF: 142
# Bid opening strings found: 0
#
# [242 / 1063]
# Reading (path): guue/2017-OJS015-023820-it.pdf
# Lines found in the PDF: 263
# Bid opening strings found: 2
#
# [243 / 1063]
# Reading (path): guue/2017-OJS016-025488-it.pdf
# Lines found in the PDF: 144
# Bid opening strings found: 9
#
# [244 / 1063]
# Reading (path): guue/2017-OJS017-027726-it.pdf
# Lines found in the PDF: 97
# Bid opening strings found: 2
#
# [245 / 1063]
# Reading (path): guue/2017-OJS017-027728-it.pdf
# Lines found in the PDF: 98
# Bid opening strings found: 4
#
# [246 / 1063]
# Reading (path): guue/2017-OJS018-030575-it.pdf
# Lines found in the PDF: 208
# Bid opening strings found: 6
#
# [247 / 1063]
# Reading (path): guue/2017-OJS019-032658-it.pdf
# Lines found in the PDF: 313
# Bid opening strings found: 10
#
# [248 / 1063]
# Reading (path): guue/2017-OJS019-032671-it.pdf
# Lines found in the PDF: 196
# Bid opening strings found: 6
#
# [249 / 1063]
# Reading (path): guue/2017-OJS022-037488-it.pdf
# Lines found in the PDF: 101
# Bid opening strings found: 2
#
# [250 / 1063]
# Reading (path): guue/2017-OJS022-037511-it.pdf
# Lines found in the PDF: 90
# Bid opening strings found: 2
#
# [251 / 1063]
# Reading (path): guue/2017-OJS023-039652-it.pdf
# Lines found in the PDF: 105
# Bid opening strings found: 2
#
# [252 / 1063]
# Reading (path): guue/2017-OJS026-045749-it.pdf
# Lines found in the PDF: 106
# Bid opening strings found: 2
#
# [253 / 1063]
# Reading (path): guue/2017-OJS029-052113-it.pdf
# Lines found in the PDF: 99
# Bid opening strings found: 2
#
# [254 / 1063]
# Reading (path): guue/2017-OJS029-052953-it.pdf
# Lines found in the PDF: 227
# Bid opening strings found: 3
#
# [255 / 1063]
# Reading (path): guue/2017-OJS029-052990-it.pdf
# Lines found in the PDF: 178
# Bid opening strings found: 7
#
# [256 / 1063]
# Reading (path): guue/2017-OJS030-054213-it.pdf
# Lines found in the PDF: 456
# Bid opening strings found: 10
#
# [257 / 1063]
# Reading (path): guue/2017-OJS032-057565-it.pdf
# Lines found in the PDF: 174
# Bid opening strings found: 7
#
# [258 / 1063]
# Reading (path): guue/2017-OJS032-058765-it.pdf
# Lines found in the PDF: 210
# Bid opening strings found: 5
#
# [259 / 1063]
# Reading (path): guue/2017-OJS032-058814-it.pdf
# Lines found in the PDF: 243
# Bid opening strings found: 5
#
# [260 / 1063]
# Reading (path): guue/2017-OJS035-063777-it.pdf
# Lines found in the PDF: 131
# Bid opening strings found: 0
#
# [261 / 1063]
# Reading (path): guue/2017-OJS038-069795-it.pdf
# Lines found in the PDF: 228
# Bid opening strings found: 6
#
# [262 / 1063]
# Reading (path): guue/2017-OJS039-071928-it.pdf
# Lines found in the PDF: 174
# Bid opening strings found: 6
#
# [263 / 1063]
# Reading (path): guue/2017-OJS040-073108-it.pdf
# Lines found in the PDF: 266
# Bid opening strings found: 6
#
# [264 / 1063]
# Reading (path): guue/2017-OJS040-073110-it.pdf
# Lines found in the PDF: 138
# Bid opening strings found: 2
#
# [265 / 1063]
# Reading (path): guue/2017-OJS040-073941-it.pdf
# Lines found in the PDF: 186
# Bid opening strings found: 5
#
# [266 / 1063]
# Reading (path): guue/2017-OJS042-077250-it.pdf
# Lines found in the PDF: 136
# Bid opening strings found: 0
#
# [267 / 1063]
# Reading (path): guue/2017-OJS044-080702-it.pdf
# Lines found in the PDF: 157
# Bid opening strings found: 4
#
# [268 / 1063]
# Reading (path): guue/2017-OJS044-081472-it.pdf
# Lines found in the PDF: 416
# Bid opening strings found: 6
#
# [269 / 1063]
# Reading (path): guue/2017-OJS044-081481-it.pdf
# Lines found in the PDF: 220
# Bid opening strings found: 6
#
# [270 / 1063]
# Reading (path): guue/2017-OJS047-086430-it.pdf
# Lines found in the PDF: 186
# Bid opening strings found: 4
#
# [271 / 1063]
# Reading (path): guue/2017-OJS047-086711-it.pdf
# Lines found in the PDF: 216
# Bid opening strings found: 0
#
# [272 / 1063]
# Reading (path): guue/2017-OJS048-088224-it.pdf
# Lines found in the PDF: 138
# Bid opening strings found: 4
#
# [273 / 1063]
# Reading (path): guue/2017-OJS052-096066-it.pdf
# Lines found in the PDF: 256
# Bid opening strings found: 2
#
# [274 / 1063]
# Reading (path): guue/2017-OJS052-097045-it.pdf
# Lines found in the PDF: 287
# Bid opening strings found: 8
#
# [275 / 1063]
# Reading (path): guue/2017-OJS053-098788-it.pdf
# Lines found in the PDF: 158
# Bid opening strings found: 6
#
# [276 / 1063]
# Reading (path): guue/2017-OJS054-100544-it.pdf
# Lines found in the PDF: 181
# Bid opening strings found: 5
#
# [277 / 1063]
# Reading (path): guue/2017-OJS057-106811-it.pdf
# Lines found in the PDF: 240
# Bid opening strings found: 4
#
# [278 / 1063]
# Reading (path): guue/2017-OJS057-106814-it.pdf
# Lines found in the PDF: 202
# Bid opening strings found: 3
#
# [279 / 1063]
# Reading (path): guue/2017-OJS058-107939-it.pdf
# Lines found in the PDF: 116
# Bid opening strings found: 4
#
# [280 / 1063]
# Reading (path): guue/2017-OJS058-107945-it.pdf
# Lines found in the PDF: 138
# Bid opening strings found: 9
#
# [281 / 1063]
# Reading (path): guue/2017-OJS058-107959-it.pdf
# Lines found in the PDF: 111
# Bid opening strings found: 2
#
# [282 / 1063]
# Reading (path): guue/2017-OJS058-108032-it.pdf
# Lines found in the PDF: 152
# Bid opening strings found: 8
#
# [283 / 1063]
# Reading (path): guue/2017-OJS059-109426-it.pdf
# Lines found in the PDF: 104
# Bid opening strings found: 2
#
# [284 / 1063]
# Reading (path): guue/2017-OJS062-116167-it.pdf
# Lines found in the PDF: 118
# Bid opening strings found: 4
#
# [285 / 1063]
# Reading (path): guue/2017-OJS062-116769-it.pdf
# Lines found in the PDF: 114
# Bid opening strings found: 0
#
# [286 / 1063]
# Reading (path): guue/2017-OJS063-119279-it.pdf
# Lines found in the PDF: 235
# Bid opening strings found: 5
#
# [287 / 1063]
# Reading (path): guue/2017-OJS064-121432-it.pdf
# Lines found in the PDF: 239
# Bid opening strings found: 3
#
# [288 / 1063]
# Reading (path): guue/2017-OJS065-122512-it.pdf
# Lines found in the PDF: 151
# Bid opening strings found: 6
#
# [289 / 1063]
# Reading (path): guue/2017-OJS065-122515-it.pdf
# Lines found in the PDF: 122
# Bid opening strings found: 2
#
# [290 / 1063]
# Reading (path): guue/2017-OJS066-124464-it.pdf
# Lines found in the PDF: 226
# Bid opening strings found: 8
#
# [291 / 1063]
# Reading (path): guue/2017-OJS067-125931-it.pdf
# Lines found in the PDF: 257
# Bid opening strings found: 6
#
# [292 / 1063]
# Reading (path): guue/2017-OJS067-126891-it.pdf
# Lines found in the PDF: 135
# Bid opening strings found: 0
#
# [293 / 1063]
# Reading (path): guue/2017-OJS069-130314-it.pdf
# Lines found in the PDF: 146
# Bid opening strings found: 4
#
# [294 / 1063]
# Reading (path): guue/2017-OJS069-130492-it.pdf
# Lines found in the PDF: 114
# Bid opening strings found: 2
#
# [295 / 1063]
# Reading (path): guue/2017-OJS070-133590-it.pdf
# Lines found in the PDF: 184
# Bid opening strings found: 6
#
# [296 / 1063]
# Reading (path): guue/2017-OJS072-137321-it.pdf
# Lines found in the PDF: 149
# Bid opening strings found: 9
#
# [297 / 1063]
# Reading (path): guue/2017-OJS073-139719-it.pdf
# Lines found in the PDF: 133
# Bid opening strings found: 6
#
# [298 / 1063]
# Reading (path): guue/2017-OJS074-142186-it.pdf
# Lines found in the PDF: 170
# Bid opening strings found: 6
#
# [299 / 1063]
# Reading (path): guue/2017-OJS074-142226-it.pdf
# Lines found in the PDF: 114
# Bid opening strings found: 2
#
# [300 / 1063]
# Reading (path): guue/2017-OJS074-142503-it.pdf
# Lines found in the PDF: 134
# Bid opening strings found: 0
#
# [301 / 1063]
# Reading (path): guue/2017-OJS074-143720-it.pdf
# Lines found in the PDF: 176
# Bid opening strings found: 3
#
# [302 / 1063]
# Reading (path): guue/2017-OJS074-143722-it.pdf
# Lines found in the PDF: 188
# Bid opening strings found: 5
#
# [303 / 1063]
# Reading (path): guue/2017-OJS075-145237-it.pdf
# Lines found in the PDF: 108
# Bid opening strings found: 2
#
# [304 / 1063]
# Reading (path): guue/2017-OJS075-145343-it.pdf
# Lines found in the PDF: 252
# Bid opening strings found: 6
#
# [305 / 1063]
# Reading (path): guue/2017-OJS075-146302-it.pdf
# Lines found in the PDF: 150
# Bid opening strings found: 5
#
# [306 / 1063]
# Reading (path): guue/2017-OJS076-147923-it.pdf
# Lines found in the PDF: 183
# Bid opening strings found: 7
#
# [307 / 1063]
# Reading (path): guue/2017-OJS076-147924-it.pdf
# Lines found in the PDF: 199
# Bid opening strings found: 7
#
# [308 / 1063]
# Reading (path): guue/2017-OJS077-149013-it.pdf
# Lines found in the PDF: 165
# Bid opening strings found: 7
#
# [309 / 1063]
# Reading (path): guue/2017-OJS077-149865-it.pdf
# Lines found in the PDF: 191
# Bid opening strings found: 4
#
# [310 / 1063]
# Reading (path): guue/2017-OJS078-150660-it.pdf
# Lines found in the PDF: 147
# Bid opening strings found: 6
#
# [311 / 1063]
# Reading (path): guue/2017-OJS078-151500-it.pdf
# Lines found in the PDF: 146
# Bid opening strings found: 8
#
# [312 / 1063]
# Reading (path): guue/2017-OJS080-154528-it.pdf
# Lines found in the PDF: 131
# Bid opening strings found: 2
#
# [313 / 1063]
# Reading (path): guue/2017-OJS080-154779-it.pdf
# Lines found in the PDF: 128
# Bid opening strings found: 0
#
# [314 / 1063]
# Reading (path): guue/2017-OJS080-155191-it.pdf
# Lines found in the PDF: 219
# Bid opening strings found: 6
#
# [315 / 1063]
# Reading (path): guue/2017-OJS081-156295-it.pdf
# Lines found in the PDF: 143
# Bid opening strings found: 7
#
# [316 / 1063]
# Reading (path): guue/2017-OJS081-156296-it.pdf
# Lines found in the PDF: 158
# Bid opening strings found: 4
#
# [317 / 1063]
# Reading (path): guue/2017-OJS083-161038-it.pdf
# Lines found in the PDF: 89
# Bid opening strings found: 2
#
# [318 / 1063]
# Reading (path): guue/2017-OJS083-161108-it.pdf
# Lines found in the PDF: 124
# Bid opening strings found: 6
#
# [319 / 1063]
# Reading (path): guue/2017-OJS083-162169-it.pdf
# Lines found in the PDF: 231
# Bid opening strings found: 8
#
# [320 / 1063]
# Reading (path): guue/2017-OJS085-165737-it.pdf
# Lines found in the PDF: 185
# Bid opening strings found: 7
#
# [321 / 1063]
# Reading (path): guue/2017-OJS085-165758-it.pdf
# Lines found in the PDF: 258
# Bid opening strings found: 6
#
# [322 / 1063]
# Reading (path): guue/2017-OJS085-165938-it.pdf
# Lines found in the PDF: 120
# Bid opening strings found: 4
#
# [323 / 1063]
# Reading (path): guue/2017-OJS085-165960-it.pdf
# Lines found in the PDF: 145
# Bid opening strings found: 9
#
# [324 / 1063]
# Reading (path): guue/2017-OJS085-166889-it.pdf
# Lines found in the PDF: 217
# Bid opening strings found: 8
#
# [325 / 1063]
# Reading (path): guue/2017-OJS086-167954-it.pdf
# Lines found in the PDF: 190
# Bid opening strings found: 6
#
# [326 / 1063]
# Reading (path): guue/2017-OJS086-168773-it.pdf
# Lines found in the PDF: 154
# Bid opening strings found: 2
#
# [327 / 1063]
# Reading (path): guue/2017-OJS087-170898-it.pdf
# Lines found in the PDF: 218
# Bid opening strings found: 5
#
# [328 / 1063]
# Reading (path): guue/2017-OJS088-172009-it.pdf
# Lines found in the PDF: 96
# Bid opening strings found: 2
#
# [329 / 1063]
# Reading (path): guue/2017-OJS088-172310-it.pdf
# Lines found in the PDF: 142
# Bid opening strings found: 7
#
# [330 / 1063]
# Reading (path): guue/2017-OJS088-172311-it.pdf
# Lines found in the PDF: 141
# Bid opening strings found: 7
#
# [331 / 1063]
# Reading (path): guue/2017-OJS090-177187-it.pdf
# Lines found in the PDF: 122
# Bid opening strings found: 4
#
# [332 / 1063]
# Reading (path): guue/2017-OJS090-177264-it.pdf
# Lines found in the PDF: 241
# Bid opening strings found: 9
#
# [333 / 1063]
# Reading (path): guue/2017-OJS090-178857-it.pdf
# Lines found in the PDF: 135
# Bid opening strings found: 6
#
# [334 / 1063]
# Reading (path): guue/2017-OJS091-180143-it.pdf
# Lines found in the PDF: 162
# Bid opening strings found: 9
#
# [335 / 1063]
# Reading (path): guue/2017-OJS091-180155-it.pdf
# Lines found in the PDF: 297
# Bid opening strings found: 2
#
# [336 / 1063]
# Reading (path): guue/2017-OJS091-180170-it.pdf
# Lines found in the PDF: 104
# Bid opening strings found: 2
#
# [337 / 1063]
# Reading (path): guue/2017-OJS091-180237-it.pdf
# Lines found in the PDF: 104
# Bid opening strings found: 2
#
# [338 / 1063]
# Reading (path): guue/2017-OJS091-180522-it.pdf
# Lines found in the PDF: 159
# Bid opening strings found: 0
#
# [339 / 1063]
# Reading (path): guue/2017-OJS091-180523-it.pdf
# Lines found in the PDF: 196
# Bid opening strings found: 0
#
# [340 / 1063]
# Reading (path): guue/2017-OJS091-180975-it.pdf
# Lines found in the PDF: 225
# Bid opening strings found: 7
#
# [341 / 1063]
# Reading (path): guue/2017-OJS091-180984-it.pdf
# Lines found in the PDF: 204
# Bid opening strings found: 5
#
# [342 / 1063]
# Reading (path): guue/2017-OJS092-181631-it.pdf
# Lines found in the PDF: 103
# Bid opening strings found: 2
#
# [343 / 1063]
# Reading (path): guue/2017-OJS093-182519-it.pdf
# Lines found in the PDF: 146
# Bid opening strings found: 9
#
# [344 / 1063]
# Reading (path): guue/2017-OJS093-182576-it.pdf
# Lines found in the PDF: 151
# Bid opening strings found: 7
#
# [345 / 1063]
# Reading (path): guue/2017-OJS094-184001-it.pdf
# Lines found in the PDF: 107
# Bid opening strings found: 2
#
# [346 / 1063]
# Reading (path): guue/2017-OJS095-186941-it.pdf
# Lines found in the PDF: 324
# Bid opening strings found: 9
#
# [347 / 1063]
# Reading (path): guue/2017-OJS095-187880-it.pdf
# Lines found in the PDF: 194
# Bid opening strings found: 5
#
# [348 / 1063]
# Reading (path): guue/2017-OJS096-189347-it.pdf
# Lines found in the PDF: 212
# Bid opening strings found: 8
#
# [349 / 1063]
# Reading (path): guue/2017-OJS096-189370-it.pdf
# Lines found in the PDF: 167
# Bid opening strings found: 2
#
# [350 / 1063]
# Reading (path): guue/2017-OJS096-190432-it.pdf
# Lines found in the PDF: 248
# Bid opening strings found: 3
#
# [351 / 1063]
# Reading (path): guue/2017-OJS097-191829-it.pdf
# Lines found in the PDF: 103
# Bid opening strings found: 2
#
# [352 / 1063]
# Reading (path): guue/2017-OJS097-192619-it.pdf
# Lines found in the PDF: 172
# Bid opening strings found: 5
#
# [353 / 1063]
# Reading (path): guue/2017-OJS097-192666-it.pdf
# Lines found in the PDF: 173
# Bid opening strings found: 7
#
# [354 / 1063]
# Reading (path): guue/2017-OJS098-193915-it.pdf
# Lines found in the PDF: 151
# Bid opening strings found: 2
#
# [355 / 1063]
# Reading (path): guue/2017-OJS098-194546-it.pdf
# Lines found in the PDF: 107
# Bid opening strings found: 0
#
# [356 / 1063]
# Reading (path): guue/2017-OJS098-194902-it.pdf
# Lines found in the PDF: 126
# Bid opening strings found: 1
#
# [357 / 1063]
# Reading (path): guue/2017-OJS098-194912-it.pdf
# Lines found in the PDF: 155
# Bid opening strings found: 4
#
# [358 / 1063]
# Reading (path): guue/2017-OJS098-194915-it.pdf
# Lines found in the PDF: 141
# Bid opening strings found: 5
#
# [359 / 1063]
# Reading (path): guue/2017-OJS098-194917-it.pdf
# Lines found in the PDF: 142
# Bid opening strings found: 5
#
# [360 / 1063]
# Reading (path): guue/2017-OJS099-197253-it.pdf
# Lines found in the PDF: 177
# Bid opening strings found: 8
#
# [361 / 1063]
# Reading (path): guue/2017-OJS100-199681-it.pdf
# Lines found in the PDF: 113
# Bid opening strings found: 0
#
# [362 / 1063]
# Reading (path): guue/2017-OJS101-201489-it.pdf
# Lines found in the PDF: 94
# Bid opening strings found: 2
#
# [363 / 1063]
# Reading (path): guue/2017-OJS101-201528-it.pdf
# Lines found in the PDF: 112
# Bid opening strings found: 2
#
# [364 / 1063]
# Reading (path): guue/2017-OJS102-204147-it.pdf
# Lines found in the PDF: 142
# Bid opening strings found: 2
#
# [365 / 1063]
# Reading (path): guue/2017-OJS104-208769-it.pdf
# Lines found in the PDF: 192
# Bid opening strings found: 7
#
# [366 / 1063]
# Reading (path): guue/2017-OJS105-210172-it.pdf
# Lines found in the PDF: 188
# Bid opening strings found: 2
#
# [367 / 1063]
# Reading (path): guue/2017-OJS105-211106-it.pdf
# Lines found in the PDF: 148
# Bid opening strings found: 4
#
# [368 / 1063]
# Reading (path): guue/2017-OJS106-212961-it.pdf
# Lines found in the PDF: 181
# Bid opening strings found: 5
#
# [369 / 1063]
# Reading (path): guue/2017-OJS108-217290-it.pdf
# Lines found in the PDF: 141
# Bid opening strings found: 7
#
# [370 / 1063]
# Reading (path): guue/2017-OJS110-221369-it.pdf
# Lines found in the PDF: 101
# Bid opening strings found: 5
#
# [371 / 1063]
# Reading (path): guue/2017-OJS111-223318-it.pdf
# Lines found in the PDF: 122
# Bid opening strings found: 4
#
# [372 / 1063]
# Reading (path): guue/2017-OJS111-223330-it.pdf
# Lines found in the PDF: 111
# Bid opening strings found: 6
#
# [373 / 1063]
# Reading (path): guue/2017-OJS111-223465-it.pdf
# Lines found in the PDF: 182
# Bid opening strings found: 7
#
# [374 / 1063]
# Reading (path): guue/2017-OJS111-224406-it.pdf
# Lines found in the PDF: 271
# Bid opening strings found: 8
#
# [375 / 1063]
# Reading (path): guue/2017-OJS113-228607-it.pdf
# Lines found in the PDF: 182
# Bid opening strings found: 8
#
# [376 / 1063]
# Reading (path): guue/2017-OJS114-229567-it.pdf
# Lines found in the PDF: 149
# Bid opening strings found: 5
#
# [377 / 1063]
# Reading (path): guue/2017-OJS116-233502-it.pdf
# Lines found in the PDF: 209
# Bid opening strings found: 7
#
# [378 / 1063]
# Reading (path): guue/2017-OJS116-234141-it.pdf
# Lines found in the PDF: 250
# Bid opening strings found: 8
#
# [379 / 1063]
# Reading (path): guue/2017-OJS117-234989-it.pdf
# Lines found in the PDF: 121
# Bid opening strings found: 4
#
# [380 / 1063]
# Reading (path): guue/2017-OJS117-235879-it.pdf
# Lines found in the PDF: 180
# Bid opening strings found: 8
#
# [381 / 1063]
# Reading (path): guue/2017-OJS118-236570-it.pdf
# Lines found in the PDF: 182
# Bid opening strings found: 8
#
# [382 / 1063]
# Reading (path): guue/2017-OJS118-238397-it.pdf
# Lines found in the PDF: 259
# Bid opening strings found: 5
#
# [383 / 1063]
# Reading (path): guue/2017-OJS119-240234-it.pdf
# Lines found in the PDF: 156
# Bid opening strings found: 6
#
# [384 / 1063]
# Reading (path): guue/2017-OJS119-241481-it.pdf
# Lines found in the PDF: 201
# Bid opening strings found: 7
#
# [385 / 1063]
# Reading (path): guue/2017-OJS119-241527-it.pdf
# Lines found in the PDF: 142
# Bid opening strings found: 5
#
# [386 / 1063]
# Reading (path): guue/2017-OJS119-241528-it.pdf
# Lines found in the PDF: 169
# Bid opening strings found: 6
#
# [387 / 1063]
# Reading (path): guue/2017-OJS119-241570-it.pdf
# Lines found in the PDF: 198
# Bid opening strings found: 5
#
# [388 / 1063]
# Reading (path): guue/2017-OJS120-242865-it.pdf
# Lines found in the PDF: 164
# Bid opening strings found: 6
#
# [389 / 1063]
# Reading (path): guue/2017-OJS121-246183-it.pdf
# Lines found in the PDF: 170
# Bid opening strings found: 6
#
# [390 / 1063]
# Reading (path): guue/2017-OJS123-249373-it.pdf
# Lines found in the PDF: 154
# Bid opening strings found: 6
#
# [391 / 1063]
# Reading (path): guue/2017-OJS123-249376-it.pdf
# Lines found in the PDF: 128
# Bid opening strings found: 4
#
# [392 / 1063]
# Reading (path): guue/2017-OJS123-249382-it.pdf
# Lines found in the PDF: 193
# Bid opening strings found: 4
#
# [393 / 1063]
# Reading (path): guue/2017-OJS123-249531-it.pdf
# Lines found in the PDF: 133
# Bid opening strings found: 5
#
# [394 / 1063]
# Reading (path): guue/2017-OJS123-250224-it.pdf
# Lines found in the PDF: 123
# Bid opening strings found: 8
#
# [395 / 1063]
# Reading (path): guue/2017-OJS124-252142-it.pdf
# Lines found in the PDF: 122
# Bid opening strings found: 7
#
# [396 / 1063]
# Reading (path): guue/2017-OJS124-252340-it.pdf
# Lines found in the PDF: 114
# Bid opening strings found: 2
#
# [397 / 1063]
# Reading (path): guue/2017-OJS124-252369-it.pdf
# Lines found in the PDF: 104
# Bid opening strings found: 2
#
# [398 / 1063]
# Reading (path): guue/2017-OJS125-254163-it.pdf
# Lines found in the PDF: 128
# Bid opening strings found: 7
#
# [399 / 1063]
# Reading (path): guue/2017-OJS125-255500-it.pdf
# Lines found in the PDF: 162
# Bid opening strings found: 6
#
# [400 / 1063]
# Reading (path): guue/2017-OJS126-256826-it.pdf
# Lines found in the PDF: 210
# Bid opening strings found: 4
#
# [401 / 1063]
# Reading (path): guue/2017-OJS126-256896-it.pdf
# Lines found in the PDF: 112
# Bid opening strings found: 8
#
# [402 / 1063]
# Reading (path): guue/2017-OJS127-259064-it.pdf
# Lines found in the PDF: 152
# Bid opening strings found: 4
#
# [403 / 1063]
# Reading (path): guue/2017-OJS128-261356-it.pdf
# Lines found in the PDF: 114
# Bid opening strings found: 6
#
# [404 / 1063]
# Reading (path): guue/2017-OJS128-262534-it.pdf
# Lines found in the PDF: 205
# Bid opening strings found: 7
#
# [405 / 1063]
# Reading (path): guue/2017-OJS129-263801-it.pdf
# Lines found in the PDF: 102
# Bid opening strings found: 2
#
# [406 / 1063]
# Reading (path): guue/2017-OJS130-265896-it.pdf
# Lines found in the PDF: 218
# Bid opening strings found: 8
#
# [407 / 1063]
# Reading (path): guue/2017-OJS130-266030-it.pdf
# Lines found in the PDF: 116
# Bid opening strings found: 7
#
# [408 / 1063]
# Reading (path): guue/2017-OJS130-266430-it.pdf
# ...
#
# [929 / 1063]
# Reading (path): guue/2019-OJS226-554625-it.pdf
# Lines found in the PDF: 242
# Bid opening strings found: 6
#
# [930 / 1063]
# Reading (path): guue/2019-OJS232-569480-it.pdf
# Lines found in the PDF: 123
# Bid opening strings found: 5
#
# [931 / 1063]
# Reading (path): guue/2019-OJS232-569505-it.pdf
# Lines found in the PDF: 145
# Bid opening strings found: 7
#
# [932 / 1063]
# Reading (path): guue/2019-OJS236-578901-it.pdf
# Lines found in the PDF: 117
# Bid opening strings found: 2
#
# [933 / 1063]
# Reading (path): guue/2019-OJS247-609507-it.pdf
# Lines found in the PDF: 276
# Bid opening strings found: 8
#
# [934 / 1063]
# Reading (path): guue/2019-OJS248-614505-it.pdf
# Lines found in the PDF: 131
# Bid opening strings found: 7
#
# [935 / 1063]
# Reading (path): guue/2019-OJS248-614914-it.pdf
# Lines found in the PDF: 129
# Bid opening strings found: 7
#
# [936 / 1063]
# Reading (path): guue/2020-OJS011-021880-it.pdf
# Lines found in the PDF: 129
# Bid opening strings found: 6
#
# [937 / 1063]
# Reading (path): guue/2020-OJS013-026273-it.pdf
# Lines found in the PDF: 138
# Bid opening strings found: 6
#
# [938 / 1063]
# Reading (path): guue/2020-OJS014-028445-it.pdf
# Lines found in the PDF: 121
# Bid opening strings found: 2
#
# [939 / 1063]
# Reading (path): guue/2020-OJS019-042029-it.pdf
# Lines found in the PDF: 104
# Bid opening strings found: 4
#
# [940 / 1063]
# Reading (path): guue/2020-OJS022-048463-it.pdf
# Lines found in the PDF: 141
# Bid opening strings found: 6
#
# [941 / 1063]
# Reading (path): guue/2020-OJS026-059375-it.pdf
# Lines found in the PDF: 148
# Bid opening strings found: 4
#
# [942 / 1063]
# Reading (path): guue/2020-OJS028-064824-it.pdf
# Lines found in the PDF: 388
# Bid opening strings found: 2
#
# [943 / 1063]
# Reading (path): guue/2020-OJS032-075436-it.pdf
# Lines found in the PDF: 334
# Bid opening strings found: 7
#
# [944 / 1063]
# Reading (path): guue/2020-OJS035-082931-it.pdf
# Lines found in the PDF: 191
# Bid opening strings found: 7
#
# [945 / 1063]
# Reading (path): guue/2020-OJS036-085206-it.pdf
# Lines found in the PDF: 113
# Bid opening strings found: 4
#
# [946 / 1063]
# Reading (path): guue/2020-OJS037-087796-it.pdf
# Lines found in the PDF: 96
# Bid opening strings found: 2
#
# [947 / 1063]
# Reading (path): guue/2020-OJS042-099459-it.pdf
# Lines found in the PDF: 187
# Bid opening strings found: 8
#
# [948 / 1063]
# Reading (path): guue/2020-OJS047-111115-it.pdf
# Lines found in the PDF: 120
# Bid opening strings found: 2
#
# [949 / 1063]
# Reading (path): guue/2020-OJS047-111283-it.pdf
# Lines found in the PDF: 198
# Bid opening strings found: 9
#
# [950 / 1063]
# Reading (path): guue/2020-OJS048-113675-it.pdf
# Lines found in the PDF: 112
# Bid opening strings found: 2
#
# [951 / 1063]
# Reading (path): guue/2020-OJS049-116302-it.pdf
# Lines found in the PDF: 156
# Bid opening strings found: 2
#
# [952 / 1063]
# Reading (path): guue/2020-OJS050-118882-it.pdf
# Lines found in the PDF: 153
# Bid opening strings found: 9
#
# [953 / 1063]
# Reading (path): guue/2020-OJS052-123585-it.pdf
# Lines found in the PDF: 126
# Bid opening strings found: 4
#
# [954 / 1063]
# Reading (path): guue/2020-OJS056-132888-it.pdf
# Lines found in the PDF: 132
# Bid opening strings found: 7
#
# [955 / 1063]
# Reading (path): guue/2020-OJS059-141530-it.pdf
# Lines found in the PDF: 281
# Bid opening strings found: 7
#
# [956 / 1063]
# Reading (path): guue/2020-OJS067-158914-it.pdf
# Lines found in the PDF: 140
# Bid opening strings found: 8
#
# [957 / 1063]
# Reading (path): guue/2020-OJS075-178364-it.pdf
# Lines found in the PDF: 102
# Bid opening strings found: 2
#
# [958 / 1063]
# Reading (path): guue/2020-OJS079-186750-it.pdf
# Lines found in the PDF: 177
# Bid opening strings found: 4
#
# [959 / 1063]
# Reading (path): guue/2020-OJS087-207887-it.pdf
# Lines found in the PDF: 109
# Bid opening strings found: 2
#
# [960 / 1063]
# Reading (path): guue/2020-OJS093-222465-it.pdf
# Lines found in the PDF: 109
# Bid opening strings found: 2
#
# [961 / 1063]
# Reading (path): guue/2020-OJS093-222511-it.pdf
# Lines found in the PDF: 109
# Bid opening strings found: 2
#
# [962 / 1063]
# Reading (path): guue/2020-OJS094-224564-it.pdf
# Lines found in the PDF: 109
# Bid opening strings found: 2
#
# [963 / 1063]
# Reading (path): guue/2020-OJS094-224608-it.pdf
# Lines found in the PDF: 126
# Bid opening strings found: 4
#
# [964 / 1063]
# Reading (path): guue/2020-OJS097-231169-it.pdf
# Lines found in the PDF: 289
# Bid opening strings found: 11
#
# [965 / 1063]
# Reading (path): guue/2020-OJS098-233338-it.pdf
# Lines found in the PDF: 288
# Bid opening strings found: 7
#
# [966 / 1063]
# Reading (path): guue/2020-OJS098-234578-it.pdf
# Lines found in the PDF: 106
# Bid opening strings found: 2
#
# [967 / 1063]
# Reading (path): guue/2020-OJS099-237588-it.pdf
# Lines found in the PDF: 103
# Bid opening strings found: 2
#
# [968 / 1063]
# Reading (path): guue/2020-OJS108-262195-it.pdf
# Lines found in the PDF: 99
# Bid opening strings found: 2
#
# [969 / 1063]
# Reading (path): guue/2020-OJS109-264674-it.pdf
# Lines found in the PDF: 410
# Bid opening strings found: 11
#
# [970 / 1063]
# Reading (path): guue/2020-OJS113-274305-it.pdf
# Lines found in the PDF: 132
# Bid opening strings found: 6
#
# [971 / 1063]
# Reading (path): guue/2020-OJS120-292161-it.pdf
# Lines found in the PDF: 117
# Bid opening strings found: 5
#
# [972 / 1063]
# Reading (path): guue/2020-OJS122-299380-it.pdf
# Lines found in the PDF: 159
# Bid opening strings found: 10
#
# [973 / 1063]
# Reading (path): guue/2020-OJS123-301692-it.pdf
# Lines found in the PDF: 146
# Bid opening strings found: 4
#
# [974 / 1063]
# Reading (path): guue/2020-OJS127-311023-it.pdf
# Lines found in the PDF: 135
# Bid opening strings found: 4
#
# [975 / 1063]
# Reading (path): guue/2020-OJS127-311047-it.pdf
# Lines found in the PDF: 98
# Bid opening strings found: 2
#
# [976 / 1063]
# Reading (path): guue/2020-OJS130-319967-it.pdf
# Lines found in the PDF: 138
# Bid opening strings found: 0
#
# [977 / 1063]
# Reading (path): guue/2020-OJS132-323978-it.pdf
# Lines found in the PDF: 109
# Bid opening strings found: 2
#
# [978 / 1063]
# Reading (path): guue/2020-OJS134-330031-it.pdf
# Lines found in the PDF: 182
# Bid opening strings found: 9
#
# [979 / 1063]
# Reading (path): guue/2020-OJS142-349658-it.pdf
# Lines found in the PDF: 182
# Bid opening strings found: 4
#
# [980 / 1063]
# Reading (path): guue/2020-OJS144-354481-it.pdf
# Lines found in the PDF: 220
# Bid opening strings found: 12
#
# [981 / 1063]
# Reading (path): guue/2020-OJS145-357108-it.pdf
# Lines found in the PDF: 128
# Bid opening strings found: 10
#
# [982 / 1063]
# Reading (path): guue/2020-OJS152-371934-it.pdf
# Lines found in the PDF: 195
# Bid opening strings found: 10
#
# [983 / 1063]
# Reading (path): guue/2020-OJS157-382995-it.pdf
# Lines found in the PDF: 106
# Bid opening strings found: 6
#
# [984 / 1063]
# Reading (path): guue/2020-OJS158-385830-it.pdf
# Lines found in the PDF: 97
# Bid opening strings found: 2
#
# [985 / 1063]
# Reading (path): guue/2020-OJS159-388326-it.pdf
# Lines found in the PDF: 135
# Bid opening strings found: 4
#
# [986 / 1063]
# Reading (path): guue/2020-OJS170-411511-it.pdf
# Lines found in the PDF: 215
# Bid opening strings found: 7
#
# [987 / 1063]
# Reading (path): guue/2020-OJS170-411709-it.pdf
# Lines found in the PDF: 141
# Bid opening strings found: 11
#
# [988 / 1063]
# Reading (path): guue/2020-OJS178-430019-it.pdf
# Lines found in the PDF: 395
# Bid opening strings found: 8
#
# [989 / 1063]
# Reading (path): guue/2020-OJS179-432159-it.pdf
# Lines found in the PDF: 138
# Bid opening strings found: 2
#
# [990 / 1063]
# Reading (path): guue/2020-OJS192-462670-it.pdf
# Lines found in the PDF: 154
# Bid opening strings found: 7
#
# [991 / 1063]
# Reading (path): guue/2020-OJS192-462780-it.pdf
# Lines found in the PDF: 1912
# Bid opening strings found: 2
#
# [992 / 1063]
# Reading (path): guue/2020-OJS194-469368-it.pdf
# Lines found in the PDF: 153
# Bid opening strings found: 2
#
# [993 / 1063]
# Reading (path): guue/2020-OJS195-472252-it.pdf
# Lines found in the PDF: 117
# Bid opening strings found: 2
#
# [994 / 1063]
# Reading (path): guue/2020-OJS195-472264-it.pdf
# Lines found in the PDF: 254
# Bid opening strings found: 9
#
# [995 / 1063]
# Reading (path): guue/2020-OJS197-476256-it.pdf
# Lines found in the PDF: 226
# Bid opening strings found: 6
#
# [996 / 1063]
# Reading (path): guue/2020-OJS198-480434-it.pdf
# Lines found in the PDF: 171
# Bid opening strings found: 6
#
# [997 / 1063]
# Reading (path): guue/2020-OJS200-486245-it.pdf
# Lines found in the PDF: 159
# Bid opening strings found: 0
#
# [998 / 1063]
# Reading (path): guue/2020-OJS202-490052-it.pdf
# Lines found in the PDF: 126
# Bid opening strings found: 7
#
# [999 / 1063]
# Reading (path): guue/2020-OJS202-490214-it.pdf
# Lines found in the PDF: 104
# Bid opening strings found: 4
#
# [1000 / 1063]
# Reading (path): guue/2020-OJS202-491415-it.pdf
# Lines found in the PDF: 128
# Bid opening strings found: 0
#
# [1001 / 1063]
# Reading (path): guue/2020-OJS204-496551-it.pdf
# Lines found in the PDF: 196
# Bid opening strings found: 2
#
# [1002 / 1063]
# Reading (path): guue/2020-OJS207-503951-it.pdf
# Lines found in the PDF: 94
# Bid opening strings found: 2
#
# [1003 / 1063]
# Reading (path): guue/2020-OJS214-524668-it.pdf
# Lines found in the PDF: 105
# Bid opening strings found: 4
#
# [1004 / 1063]
# Reading (path): guue/2020-OJS215-527484-it.pdf
# Lines found in the PDF: 95
# Bid opening strings found: 2
#
# [1005 / 1063]
# Reading (path): guue/2020-OJS217-531774-it.pdf
# Lines found in the PDF: 253
# Bid opening strings found: 10
#
# [1006 / 1063]
# Reading (path): guue/2020-OJS217-531887-it.pdf
# Lines found in the PDF: 113
# Bid opening strings found: 2
#
# [1007 / 1063]
# Reading (path): guue/2020-OJS217-531922-it.pdf
# Lines found in the PDF: 157
# Bid opening strings found: 7
#
# [1008 / 1063]
# Reading (path): guue/2020-OJS219-537924-it.pdf
# Lines found in the PDF: 124
# Bid opening strings found: 7
#
# [1009 / 1063]
# Reading (path): guue/2020-OJS220-540698-it.pdf
# Lines found in the PDF: 105
# Bid opening strings found: 2
#
# [1010 / 1063]
# Reading (path): guue/2020-OJS220-540699-it.pdf
# Lines found in the PDF: 195
# Bid opening strings found: 2
#
# [1011 / 1063]
# Reading (path): guue/2020-OJS220-540706-it.pdf
# Lines found in the PDF: 126
# Bid opening strings found: 8
#
# [1012 / 1063]
# Reading (path): guue/2020-OJS220-540717-it.pdf
# Lines found in the PDF: 123
# Bid opening strings found: 7
#
# [1013 / 1063]
# Reading (path): guue/2020-OJS222-545000-it.pdf
# Lines found in the PDF: 137
# Bid opening strings found: 12
#
# [1014 / 1063]
# Reading (path): guue/2020-OJS222-545004-it.pdf
# Lines found in the PDF: 193
# Bid opening strings found: 2
#
# [1015 / 1063]
# Reading (path): guue/2020-OJS224-550924-it.pdf
# Lines found in the PDF: 170
# Bid opening strings found: 2
#
# [1016 / 1063]
# Reading (path): guue/2020-OJS225-553830-it.pdf
# Lines found in the PDF: 104
# Bid opening strings found: 2
#
# [1017 / 1063]
# Reading (path): guue/2020-OJS227-557855-it.pdf
# Lines found in the PDF: 259
# Bid opening strings found: 4
#
# [1018 / 1063]
# Reading (path): guue/2020-OJS227-558122-it.pdf
# Lines found in the PDF: 162
# Bid opening strings found: 6
#
# [1019 / 1063]
# Reading (path): guue/2020-OJS228-562654-it.pdf
# Lines found in the PDF: 95
# Bid opening strings found: 0
#
# [1020 / 1063]
# Reading (path): guue/2020-OJS229-564692-it.pdf
# Lines found in the PDF: 96
# Bid opening strings found: 2
#
# [1021 / 1063]
# Reading (path): guue/2020-OJS232-570013-it.pdf
# Lines found in the PDF: 176
# Bid opening strings found: 10
#
# [1022 / 1063]
# Reading (path): guue/2020-OJS232-571240-it.pdf
# Lines found in the PDF: 143
# Bid opening strings found: 9
#
# [1023 / 1063]
# Reading (path): guue/2020-OJS232-571671-it.pdf
# Lines found in the PDF: 194
# Bid opening strings found: 11
#
# [1024 / 1063]
# Reading (path): guue/2020-OJS233-575413-it.pdf
# Lines found in the PDF: 154
# Bid opening strings found: 4
#
# [1025 / 1063]
# Reading (path): guue/2020-OJS237-584407-it.pdf
# Lines found in the PDF: 133
# Bid opening strings found: 6
#
# [1026 / 1063]
# Reading (path): guue/2020-OJS237-584484-it.pdf
# Lines found in the PDF: 117
# Bid opening strings found: 6
#
# [1027 / 1063]
# Reading (path): guue/2020-OJS240-593616-it.pdf
# Lines found in the PDF: 107
# Bid opening strings found: 2
#
# [1028 / 1063]
# Reading (path): guue/2020-OJS240-593619-it.pdf
# Lines found in the PDF: 108
# Bid opening strings found: 2
#
# [1029 / 1063]
# Reading (path): guue/2020-OJS248-617723-it.pdf
# Lines found in the PDF: 360
# Bid opening strings found: 6
#
# [1030 / 1063]
# Reading (path): guue/2020-OJS250-624835-it.pdf
# Lines found in the PDF: 160
# Bid opening strings found: 6
#
# [1031 / 1063]
# Reading (path): guue/2020-OJS255-639759-it.pdf
# Lines found in the PDF: 154
# Bid opening strings found: 4
#
# [1032 / 1063]
# Reading (path): guue/2020-OJS255-641290-it.pdf
# Lines found in the PDF: 131
# Bid opening strings found: 5
#
# [1033 / 1063]
# Reading (path): guue/2021-OJS005-006205-it.pdf
# Lines found in the PDF: 144
# Bid opening strings found: 6
#
# [1034 / 1063]
# Reading (path): guue/2021-OJS008-014191-it.pdf
# Lines found in the PDF: 168
# Bid opening strings found: 9
#
# [1035 / 1063]
# Reading (path): guue/2021-OJS010-020294-it.pdf
# Lines found in the PDF: 138
# Bid opening strings found: 0
#
# [1036 / 1063]
# Reading (path): guue/2021-OJS017-039024-it.pdf
# Lines found in the PDF: 107
# Bid opening strings found: 2
#
# [1037 / 1063]
# Reading (path): guue/2021-OJS020-045962-it.pdf
# Lines found in the PDF: 107
# Bid opening strings found: 4
#
# [1038 / 1063]
# Reading (path): guue/2021-OJS020-045967-it.pdf
# Lines found in the PDF: 109
# Bid opening strings found: 4
#
# [1039 / 1063]
# Reading (path): guue/2021-OJS027-066775-it.pdf
# Lines found in the PDF: 107
# Bid opening strings found: 2
#
# [1040 / 1063]
# Reading (path): guue/2021-OJS032-079868-it.pdf
# Lines found in the PDF: 158
# Bid opening strings found: 4
#
# [1041 / 1063]
# Reading (path): guue/2021-OJS045-111873-it.pdf
# Lines found in the PDF: 152
# Bid opening strings found: 6
#
# [1042 / 1063]
# Reading (path): guue/2021-OJS045-114117-it.pdf
# Lines found in the PDF: 147
# Bid opening strings found: 0
#
# [1043 / 1063]
# Reading (path): guue/2021-OJS062-157371-it.pdf
# Lines found in the PDF: 165
# Bid opening strings found: 2
#
# [1044 / 1063]
# Reading (path): guue/2021-OJS065-166491-it.pdf
# Lines found in the PDF: 130
# Bid opening strings found: 6
#
# [1045 / 1063]
# Reading (path): guue/2021-OJS076-194570-it.pdf
# Lines found in the PDF: 107
# Bid opening strings found: 2
#
# [1046 / 1063]
# Reading (path): guue/2021-OJS080-205357-it.pdf
# Lines found in the PDF: 122
# Bid opening strings found: 2
#
# [1047 / 1063]
# Reading (path): guue/2021-OJS082-211829-it.pdf
# Lines found in the PDF: 212
# Bid opening strings found: 2
#
# [1048 / 1063]
# Reading (path): guue/2021-OJS089-227709-it.pdf
# Lines found in the PDF: 160
# Bid opening strings found: 6
#
# [1049 / 1063]
# Reading (path): guue/2021-OJS095-249480-it.pdf
# Lines found in the PDF: 159
# Bid opening strings found: 6
#
# [1050 / 1063]
# Reading (path): guue/2021-OJS098-256412-it.pdf
# Lines found in the PDF: 154
# Bid opening strings found: 8
#
# [1051 / 1063]
# Reading (path): guue/2021-OJS104-274165-it.pdf
# Lines found in the PDF: 162
# Bid opening strings found: 9
#
# [1052 / 1063]
# Reading (path): guue/2021-OJS107-281179-it.pdf
# Lines found in the PDF: 131
# Bid opening strings found: 6
#
# [1053 / 1063]
# Reading (path): guue/2021-OJS119-314136-it.pdf
# Lines found in the PDF: 111
# Bid opening strings found: 7
#
# [1054 / 1063]
# Reading (path): guue/2021-OJS124-328041-it.pdf
# Lines found in the PDF: 325
# Bid opening strings found: 7
#
# [1055 / 1063]
# Reading (path): guue/2021-OJS134-356820-it.pdf
# Lines found in the PDF: 123
# Bid opening strings found: 4
#
# [1056 / 1063]
# Reading (path): guue/2021-OJS138-367340-it.pdf
# Lines found in the PDF: 186
# Bid opening strings found: 4
#
# [1057 / 1063]
# Reading (path): guue/2021-OJS148-394419-it.pdf
# Lines found in the PDF: 182
# Bid opening strings found: 4
#
# [1058 / 1063]
# Reading (path): guue/2021-OJS189-491997-it.pdf
# Lines found in the PDF: 162
# Bid opening strings found: 2
#
# [1059 / 1063]
# Reading (path): guue/2021-OJS207-542165-it.pdf
# Lines found in the PDF: 127
# Bid opening strings found: 4
#
# [1060 / 1063]
# Reading (path): guue/2021-OJS255-674964-it.pdf
# Lines found in the PDF: 94
# Bid opening strings found: 2
#
# [1061 / 1063]
# Reading (path): guue/2022-OJS093-255794-it.pdf
# Lines found in the PDF: 175
# Bid opening strings found: 6
#
# [1062 / 1063]
# Reading (path): guue/2022-OJS096-265457-it.pdf
# Lines found in the PDF: 176
# Bid opening strings found: 6
#
# [1063 / 1063]
# Reading (path): guue/2022-OJS148-423809-it.pdf
# Lines found in the PDF: 128
# Bid opening strings found: 6

# %%
# Create a file with the texts extracted from the PDFs
print(">> Saving bid opening texts")
df_bid = pd.DataFrame.from_records(list_bid_opening_dic) # Create a dataframe from a list of dictionaries
df_bid = df_bid.sort_values(by='file_name')
# print(df_bid.head()) # debug
path_out = Path(data_dir) / bid_file_text
print("Path:", path_out)
df_bid.to_csv(path_out, sep=csv_sep, index=False, quoting=csv.QUOTE_ALL)
# Out:
# >> Saving bid opening texts
# Path: data/bid_opening_text.csv

# %%
# program end
end_time = datetime.now().replace(microsecond=0)
delta_time = end_time - start_time

print()
print("End process:", end_time)
print("Time to finish:", delta_time)
print()

print()
print("*** PROGRAM END ***")
print()
# Out:
# End process: 2024-05-08 15:27:34
# Time to finish: 0:00:37
#
#
# *** PROGRAM END ***
