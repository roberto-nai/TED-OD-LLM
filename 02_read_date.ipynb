# %%
# 02_read_date.ipynb
# Reads the PDFs and extracts the portion of text contained in the section 'Modalità di apertura delle offerte'; the texts are saved in a CSV file.

# %%
# Force to reload extrernal modules every new cell execution
# %reload_ext autoreload
# %autoreload 2

# %%
### IMPORT ###
from pathlib import Path
import csv
from datetime import datetime
import pandas as pd
import os 
from openai import OpenAI
from dotenv import load_dotenv # Needed to load the contents of the .env file

# %%
### LOCAL IMPORT ###
from config import config_reader
from utilities import read_csv_data_to_df

# %%
### GLOBALS ###
yaml_config = config_reader.config_read_yaml("config.yml", "config")
# print(yaml_config) # debug
data_dir = str(yaml_config["DATA_DIR"])
bid_file_text = str(yaml_config["FILE_BID_TEXT"])
bid_file_text_date = str(yaml_config["FILE_BID_TEXT_DATE"])
bid_file_text_date_label = str(yaml_config["FILE_BID_TEXT_DATE_LABEL"])
csv_sep = str(yaml_config["CSV_SEP"])
# OpenAI
load_dotenv() # Load environment variables from the .env file
openai_api_key = os.getenv("OPENAI_API_KEY")
openai_model_name = str(yaml_config["OPENAI_MODEL_NAME"])

# %%
### FUNCTIONS ###

# %%
def convert_dmy_to_ymd(date_str:str):
    """
    Converts a date in the format dd/mm/yyyy to yyyyy-mm-dd.

    Args:
        date_str (str): Date in dd/mm/yyyy.

    Returns:
        str: date in yyyyy-mm-dd.
    """
    if date_str == "-1":
        return None
    else:
        # print("Converting:", date_str) # debug
        dt = pd.to_datetime(date_str, format='%d/%m/%Y').strftime('%Y-%m-%d')
        return dt

# %%
def llm_test(model_name:str) -> None:
    """
    Test the connection to the LLM.
    
    Args:
        model_name (str): Name of the model.
    """
    client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    stream = client.chat.completions.create(
    model=model_name,
    messages=[{"role": "user", "content": "Say this is a test connection"}],
    stream=True,
    )
    for chunk in stream:
        print(chunk.choices[0].delta.content or "", end="")

# %%
def llm_find_date(text: str, model_name:str) -> str:
    """
    Extracts and formats a date from a given text string using ChatGPT. The date is returned in the format dd/mm/yyyy.

    Args:
        text (str): The text from which the date needs to be extracted. It should contain a date in any recognisable format.
        model_name (str): Name of the model.

    Returns:
        str: A string representing the date in dd/mm/yyyy format. If an error occurs, it returns the error message.
    """
    client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

    try:
        chat_completion = client.chat.completions.create(
            messages=[
                        {"role": "system", "content": "You are a helpful assistant in finding dates in Italian texts"},
                        {"role": "user", "content": f"Please extract and format only the date in this Italian text as yyyy-mm-dd, without adding anything other than the date. Write -1 if date not found: {text}"}
                    ],
            model=model_name,
        )
        # print(type(chat_completion)) # debug
        # ChatCompletion(id='chatcmpl-9MrwkHcMyDloWUBVqAcWaSv9vr8B2', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='25/02/2016', role='assistant', function_call=None, tool_calls=None))], created=1715237614, model='gpt-4-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=6, prompt_tokens=132, total_tokens=138))
        # The chat_completion vaiable contains a response object ChatCompletion that is is a list of data
        # The textual response is in: choices[0] -> message -> content
        chat_response = chat_completion.choices[0].message.content.strip()
        print("LLM output:", chat_response) # debug
        return chat_response
        # for more than one response: generated_texts = [choice.message["content"].strip() for choice in chat_completion["choices"]]
    except Exception as e:
        print("ERROR! Message from LLM exception:", e)
        return None

# %%
def process_row(row: pd.Series, model_name:str) -> str:
    """
    Process a single row of the DataFrame. If the 'text' field is not None, call llm_find_date() with the 'text'.

    Args:
        row (pd.Series): A pandas Series object representing a single row.
        model_name (str): Name of the model.
    Returns:
        str: The date string returned by llm_find_date if 'text' is not None; otherwise, None.
    """
    if pd.notnull(row['text']):
        print("LLM input:", row['text'])
        return llm_find_date(row['text'], model_name)
    return None  # Return None if 'text' is None

# %%
### MAIN ###
print()
print("*** PROGRAM START ***")
print()

start_time = datetime.now().replace(microsecond=0)
print("Start process:", str(start_time))
print()
# Out:
# *** PROGRAM START ***
#
# Start process: 2024-05-09 12:08:36

# %%
# Create list of PDF files
print(">> Reading CSV file")
path_bid_text = Path(data_dir) / bid_file_text
print("File:", str(path_bid_text))
df_bid_text = read_csv_data_to_df(path_bid_text, None, csv_sep)
df_bid_text_len = len(df_bid_text)
print("Rows in dataframe:", df_bid_text_len)
print("Columns in dataframe:", df_bid_text.columns)
print()
# Out:
# >> Reading CSV file
# File: data/bid_opening_text.csv
# Rows in dataframe: 1063
# Columns in dataframe: Index(['file_name', 'text'], dtype='object')

# %%
# Testing the connection to LLM
print(">> Testing LLM connection")
# print("Open API key:", openai_api_key) # debug
print("Model name:", openai_model_name)
llm_test(openai_model_name)
# Out:
# >> Testing LLM connection
# Model name: gpt-4
# This is a test connection.

# %%
# Parse the files
print(">> Reading CSV text and querying LLM")
# df_bid_text['date'] = df_bid_text.apply(process_row, axis=1)
df_bid_text['date'] = df_bid_text.apply(lambda row: process_row(row, openai_model_name), axis=1)
print()
# Out:
# >> Reading CSV text and querying LLM
# LLM input: Data: 25.2.2016 - 9:00|Luogo:|Provincia di Varese — Piazza Libertà 1 — Varese.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Un rappresentante per ogni |impresa offerente munito di relativa procura.
# LLM output: 2016-02-25
# LLM input: Data: 25.2.2016 - 9:30|Luogo:|Comune di Piacenza — Piazza Cavalli 2.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti delle ditte |concorrenti o persone delegate.
# LLM output: 2016-02-25
# LLM input: Data: 11.3.2016 - 9:00|Luogo:|Settore Gare e Appalti, Via Marchetti 3 — Brescia.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-03-11
# LLM input: Data: 4.3.2016 - 10:00|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-03-04
# LLM input: Data: 10.3.2016 - 10:00|Luogo:|Settore appalti e contratti — Corso Matteotti 3 — piano VI — Lecco.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti/delegati |imprese partecipanti.
# LLM output: 2016-03-10
# LLM input: Data: 14.3.2016 - 9:00|Luogo:|Sala riunioni sita al primo piano dell'edificio «Teatro comunale di Pergine» — Piazza Garibaldi 5/h.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti delle |imprese e persone munite di delega.
# LLM output: 2016-03-14
# LLM input: Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Titolare o legale rappresentante |del soggetto concorrente, ovvero persone munite di specifica delega.
# LLM output: -1
# LLM input: Data: 14.3.2016 - 15:00|Luogo:|Sede Municipale Piazza G. Puchetti 1 — Selvazzano Dentro (PD) — seduta pubblica secondo le modalità |previste nel disciplinare di gara. Le altre sedute pubbliche verranno comunicate tramite PEC o Fax all'indirizzo/|numero indicati dai concorrenti e pubblicate nel sito internet dell'Ente.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Il Titolare o Rappresentante |Legale o soggetto munito di apposita delega conferita dal legale rappresentante.
# LLM output: 2016-03-14
# LLM input: Data: 22.3.2016 - 9:30|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti delle |compagnie partecipanti o loro delegati.
# LLM output: 2016-03-22
# LLM input: Data: 11.3.2016 - 10:00|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta aperta al pubblico.
# LLM output: 2016-03-11
# LLM input: Data: 16.3.2016 - 10:00|Luogo:|presso una sala della Residenza Municipale sita in P.zza del Municipio 2, 44121 Ferrara.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: All'apertura dei plichi sono |ammessi a partecipare tutti i soggetti interessati, I legali rappresentanti degli offerenti o altri soggetti muniti di |delega o procura saranno autorizzati a richiedere la verbalizzazione in sede di gara di eventuali dichiarazioni.
# LLM output: 2016-03-16
# LLM input: Data: 3.3.2016 - 9:30|Luogo:|Città Metropolitana di Genova, Piazzale Mazzini 2 — Genova.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: I soggetti che assistono alla |seduta di gara sono tenuti all'identificazione e alla registrazione della presenza. Possono rilasciare dichiarazioni |a verbale esclusivamente i soggetti muniti di idonei poteri di rappresentanza delle imprese partecipanti.
# LLM output: 2016-03-03
# LLM input: Data: 4.5.2016 - 10:00|Luogo:|Presso il Comune di Trezzano sul Naviglio.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Durante le operazioni di |apertura delle buste saranno ammessi a presentare eventuali osservazioni esclusivamente i soggetti muniti di |idoneo documento comprovante la legittimazione ad agire in nome e per conto delle società partecipanti alla |gara (legali rappresentanti, procuratori, delegati). La procedura di gara avrà inizio all'ora stabilita anche nel caso |in cui nessuna delle società partecipanti sia presente.
# LLM output: 2016-05-04
# LLM input: Data: 7.4.2016 - 9:30|Luogo:|Sede municipale del Comune di Brugherio, Piazza Cesare Battisti 1 — 20861 Brugherio (MB) — Italia.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: I concorrenti che volessero |intervenire potranno presenziare con il proprio titolare, legale rappresentante od altra persona appositamente |delegata (in possesso di delega). Potrà assistere all'apertura della gara un solo rappresentante per ogni |concorrente.
# LLM output: 2016-04-07
# LLM input: Data: 6.4.2016 - 16:00|Luogo:|Comune di Buggiano, Piazza Matteotti 1 Buggiano (PT) Italia.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Sono ammessi tutti i soggetti |ma è facoltà solo dei legali rappresentanti o loro delegati formulare osservazioni a verbale.
# LLM output: 2016-04-06
# LLM input: Data: 5.4.2016 - 9:00|Luogo:|Comune di Desenzano del Garda — Via Carducci 4.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legale rappresentante delle |imprese offerenti o suo delegato in possesso di idonea delega e valido documento di identità.
# LLM output: 2016-04-05
# LLM input: Data: 1.4.2016 - 10:00|Luogo:|Sede comunale.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti|delegati od incaricati.
# LLM output: 2016-04-01
# LLM input: Data: 3.5.2016 - 9:30
# LLM output: 2016-05-03
# LLM input: Data: 30.3.2016 - 9:00|Luogo:|Sala Appalti Settore gare e appalti Via Marchetti 3, Brescia.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-03-30
# LLM input: Data: 18.4.2016 - 9:30|Luogo:|Palazzo Comunale — V.le della Repubblica 24 — 50031 Barberino di Mugello in seduta non aperta al pubblico |in modalità telematica tramite portale regionale Start.|Persone ammesse ad assistere all'apertura delle offerte: no
# LLM output: 2016-04-18
# LLM input: Data: 18.4.2016 - 9:30
# LLM output: 2016-04-18
# LLM input: Data: 21.4.2016 - 15:00|Luogo:|Comune di San Miniato — Loggiati di San Domenico 3 — Settore servizi alla persona e politiche di solidarietà.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Alle fasi della procedura di |gara che si svolgono in seduta pubblica può assistere, in qualità di uditore, il titolare o legale rappresentante del |soggetto concorrente ovvero persone munite di specifica delega.
# LLM output: 2016-04-21
# LLM input: Data: 14.4.2016 - 10:00|Luogo:|Palazzo Giandonati Canacci — Piazza di Parte Guelfa 3 — Firenze.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-04-14
# LLM input: Data: 18.4.2016 - 9:30|Luogo:|Comune di Torri di Quartesolo, Via Roma 174 — 36040 Torri di Quartesolo (VI).|Persone ammesse ad assistere all'apertura delle offerte: no
# LLM output: 2016-04-18
# LLM input: Data: 21.4.2016 - 10:00|Luogo:|Comune di Pescara — Servizio Appalti e Concessioni.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-04-21
# LLM input: Data: 12.4.2016 - 10:30|Luogo:|Servizio Patrimonio e Provveditorato — Piazza della Libertà 1 — Arezzo.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: I rappresentanti delle imprese |concorrenti.
# LLM output: 2016-04-12
# LLM input: Data: 12.5.2016 - 9:30|Luogo:|Residenza Municipale — Piazza Indipendenza 1 — 60035 Jesi.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti delle |Imprese o dei raggruppamenti o da soggetti muniti di apposita delega da parte degli stessi.
# LLM output: 2016-05-12
# LLM input: Data: 10.5.2016 - 9:30|Luogo:|Sede della Provincia di Treviso — Stazione Unica Appaltante, Via Cal di Breda 116, Treviso.
# LLM output: 2016-05-10
# LLM input: Data: 16/05/2016|Ora locale: 10:00|Luogo:|Biblioteca Comunale di Via Marietti — 20010 Bareggio (MI).
# LLM output: 2016-05-16
# LLM input: Data: 24.5.2016 - 10:00|Luogo:|Sala consiliare piano primo — Sede municipale sita in Via Poliseo De Angelis 24 — Cap. 64046 Montorio al |Vomano (TE) Italia.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Si veda la documentazione di |gara.
# LLM output: 2016-05-24
# LLM input: Data: 9.5.2016 - 15:00|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: È ammesso ad assistere |chiunque abbia interesse.|Solo i legali rappresentanti delle imprese offerenti o i soggetti che esibiranno al Presidente della Commissione |una specifica delega potranno intervenire nelle operazioni di svolgimento della gara e far risultare nel verbale le |loro eventuali dichiarazioni.
# LLM output: 2016-05-09
# LLM input: Data: 11.5.2016 - 9:30|Luogo:|Seriate (BG), Piazza Alebardi 1.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Rappresentanti legali e/o |delegati delle imprese partecipanti.
# LLM output: 2016-05-11
# LLM input: Luogo:|Sede municipale del Comune di Castiglione delle Stiviere.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti delle ditte |partecipanti oppure delegati in possesso di delega scritta.
# LLM output: -1
# LLM input: Data: 19.5.2016 - 10:00|Luogo:|Formigine, Via Unità d'Italia 26.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: La seduta di gara è pubblica |ma la facoltà di rilasciare dichiarazioni e di interloquire durante le operazioni di|gara è riconosciuta esclusivamente ai legali rappresentanti delle imprese concorrenti e ai loro delegati, muniti di |procura scritta, previa autorizzazione dell'organo di gara.|Per le altre sedute di gara vedi disciplinare.
# LLM output: 2016-05-19
# LLM input: Data: 5.5.2016 - 9:30|Luogo:|Sede della Provincia di Treviso — Stazione unica appaltante — Via Cal di Breda 116, Treviso.
# LLM output: 2016-05-05
# LLM input: Data: 26.5.2016 - 9:00|Luogo:|SUA-Provincia di Varese.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Un rappresentante dell'impresa |munito di procura.
# LLM output: 2016-05-26
# LLM input: Data: 5.5.2016 - 9:30|Luogo:|Palazzo comunale, V.le della Repubblica 25 — 50031 Barberino di Mugello — in seduta non aperta al pubblico, |in modalità telematica tramite portale regionale Start.|Persone ammesse ad assistere all'apertura delle offerte: no
# LLM output: 2016-05-05
# LLM input: Data: 30.5.2016 - 10:30|Luogo:|Prima seduta pubblica presso Palazzo Municipale — Via Vittorio Veneto 40.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Rappresentanti legali o |delegati.
# LLM output: 2016-05-30
# LLM input: Data: 1.6.2016 - 9:00|Luogo:|Palazzo municipale del Comune di Fossano.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Chiunque è ammesso.
# LLM output: 2016-06-01
# LLM input: Data: 26.5.2016 - 10:00|Luogo:|Ufficio Educazione Formazione e Sport Via F.lli Bandiera 11 — Senigallia.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Nelle sole sedute pubbliche.
# LLM output: 2016-05-26
# LLM input: Data: 27.5.2016 - 9:30|Luogo:|Seriate (BG) Piazza Alebardi 1.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti o delegati |delle imprese partecipanti.
# LLM output: 2016-05-27
# LLM input: Data: 18.5.2016 - 9:30|Luogo:|Sede del Nuovo Circondario Imolese — Via Boccaccio 27 — Imola.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti degli |offerenti o loro procuratori o rappresentanti, purché muniti di procura o delega scritta e di documento di identità |valido.
# LLM output: 2016-05-18
# LLM input: Data: 30.5.2016 - 9:30|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti/delegati |delle imprese partecipanti.
# LLM output: 2016-05-30
# LLM input: Data: 17/05/2016|Ora locale: 15:00|Luogo:|Ospedale Casa di Riposo di Montiglio.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica.
# LLM output: 2016-05-17
# LLM input: Data: 25.5.2016 - 9:30|Luogo:|Sala Underground presso il Comune di Baranzate — Via Conciliazione 19.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali Rappresentanti dei |concorrenti partecipanti o loro incaricati, purché muniti di apposita delega/procura e di regolare documento di |riconoscimento.
# LLM output: 2016-05-25
# LLM input: Data: 8.6.2016 - 10:00|Luogo:|Palazzo Municipale — Sala della Minor Cella, Via Scudari 20 — Modena — Italia.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Nelle sedute pubbliche.
# LLM output: 2016-06-08
# LLM input: Data: 20.5.2016 - 9:30|Luogo:|Comune di Seriate, Piazza Alebardi 1.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti/delegati |delle imprese partecipanti.
# LLM output: 2016-05-20
# LLM input: Data: 7.6.2016 - 9:00|Luogo:|Sala Appalti Settore gare e appalti Via Marchetti 3, Brescia.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-06-07
# LLM input: Data: 19.5.2016 - 9:30|Luogo:|Sede legale del Comune di Buaggiano, Piazza Matteotti 2.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-05-19
# LLM input: Data: 26.5.2016 - 10:00|Luogo:|Formigine, Via Unità d'Italia 26.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: La seduta di gara è |pubblica ma la facoltà di rilasciare dichiarazioni e di interloquire durante le operazioni di gara è riconosciuta |esclusivamente ai legali rappresentanti delle imprese concorrenti e ai loro delegati, muniti di procura scritta, |previa autorizzazione dell'organo di gara.|Per le altre sedute di gara vedi disciplinare.
# LLM output: 2016-05-26
# LLM input: Data: 30.5.2016 - 8:30|Luogo:|Comune di Castelfranco Emilia — Settore Servizi al Cittadino — Ufficio Unico di Committenza — Via |Circondaria Sud 20 — Castelfranco Emilia — Modena.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Tutte le sedute della |Commissione giudicatrice sono pubbliche a eccezione della/e seduta/e — riservata/e –|dedicata/e alla valutazione delle offerte progettuali («Elementi di natura qualitativa»). Alle sedute pubbliche|potranno essere presenti i rappresentanti dei soggetti partecipanti, ai quali, se legali rappresentanti o soggetti|muniti di apposita delega, è data la possibilità di formulare osservazioni da risultare a verbale, anche ai sensi |e|per gli effetti di cui all'art. 243 bis del D.lgs. 163/2006 e ss.mm.ii..
# LLM output: 2016-05-30
# LLM input: Data: 26.5.2016 - 9:30|Luogo:|Sede Comunale Via Goito 2 Vezzano Ligure.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Le imprese possono |presenziare mediante proprio rappresentante munito di delega e documento di identità.
# LLM output: 2016-05-26
# LLM input: Data: 9.6.2016 - 9:00|Luogo:|Sala consiglieri del Comune — Via F. M. Preti 36 — Castelfranco Veneto.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Sedute di gara aperte al |pubblico, ad eccezione di quelle relative alla valutazione delle offerte tecniche che verranno svolte in forma |riservata. Saranno, comunque, messe a verbale eventuali dichiarazioni rese solo dai legali rappresentanti delle |ditte concorrenti ovvero dai soggetti muniti di specifica delega loro conferita dai suddetti legali rappresentanti.
# LLM output: 2016-06-09
# LLM input: Data: 25.5.2016 - 9:30|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti degli |offerenti o loro procuratori o rappresentanti, purché muniti di procura o delega scritta e di documento di identità |valido.
# LLM output: 2016-05-25
# LLM input: Data: 26.5.2016 - 9:30|Luogo:|vedi art. 12 delle Norme di gara|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti delle ditte |partecipanti o loro delegati, nelle sedute pubbliche.
# LLM output: 2016-05-26
# LLM input: Data: 16.5.2016 - 10:00
# LLM output: 2016-05-16
# LLM input: Luogo:|da comunicare ai concorrenti a seguito della nomina della Commissione di gara|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti o soggetti |muniti di delega scritta del concorrente.
# LLM output: -1
# LLM input: Data: 17/05/2016|Ora locale: 09:30|Luogo:|Sede comunale del Comune di Romano d'Ezzelino — Via G. Giardino 1, 36060 Romano d'Ezzelino (VI).
# LLM output: 2016-05-17
# LLM input: Data: 17.5.2016|Luogo:|Comune di Cento — Settore Servizi alla Persona in Cento, Via Olindo Malagodi 12 (piano primo).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Alle sole operazioni di gara |espletate in seduta pubblica potranno presenziare i Legali Rappresentanti delle ditte partecipanti alla gara o altri |incaricati purché in possesso di regolare procura o delega.
# LLM output: 2016-05-17
# LLM input: Data: 16.5.2016 - 10:00|Luogo:|Sede del Centro Unico Appalti (C.U.A.) dell'Unione di Comuni Valdarno e Valdisieve — Via Tanzini 27– |Pontassieve (FI).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Il titolare o legale |rappresentante del soggetto concorrente o persona munita di specifica delega può assistere, in qualità di |uditore, alle sedute pubbliche di gara.
# LLM output: 2016-05-16
# LLM input: Data: 9.6.2016 - 10:00|Luogo:|Servizi educativi, Piazza Europa 1 La Spezia.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti delle |imprese interessate o persone munite di specifica delega loro conferita dai suddetti legali rappresentanti.
# LLM output: 2016-06-09
# LLM input: Data: 30.5.2016 - 11:00|Luogo:|Sala riunioni sita al 1° piano della sede municipale del Comune di Solesino in Via 28 Aprile 19 — Solesino.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Sono ammessi ad assistere |all'apertura dei plichi contenenti le offerte in seduta pubblica il legale rappresentante o un suo delegato (con le |modalità indicate nel Disciplinare di Gara).
# LLM output: 2016-05-30
# LLM input: Data: 31.5.2016 - 8:30|Luogo:|Comune di Castelfranco Emilia — Settore Servizi al Cittadino — Ufficio Unico di Committenza — Via |Circondaria Sud 20 — Castelfranco Emilia — Modena.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Tutte le sedute della |Commissione giudicatrice sono pubbliche a eccezione della/e seduta/e — riservata/e –|dedicata/e alla valutazione delle offerte progettuali («Elementi di natura qualitativa»). Alle sedute pubbliche |potranno essere presenti i rappresentanti dei soggetti partecipanti, ai quali, se legali rappresentanti o soggetti|muniti di apposita delega, è data la possibilità di formulare osservazioni da risultare a verbale, anche ai sensi e |per gli effetti di cui all'art. 243 bis del D.Lgs. 163/2006 e ss.mm.ii..
# LLM output: 2016-05-31
# LLM input: Data: 27.5.2016 - 9:30|Luogo:|Comune di Piacenza Piazza Cavalli 2.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti delle ditte |partecipanti.
# LLM output: 2016-05-27
# LLM input: Data: 8.6.2016 - 10:00|Luogo:|In una sala della residenza municipale in Perugia, Corso Vannucci 19 — Palazzo dei Priori.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti dei |concorrenti oppure soggetti muniti di specifica delega.
# LLM output: 2016-06-08
# LLM input: Data: 13.6.2016 - 9:30|Luogo:|Una sala della residenza municipale.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti delle |imprese concorrenti e soggetti muniti di apposita delega.
# LLM output: 2016-06-13
# LLM input: Data: 24/05/2016|Ora locale: 09:30|Luogo:|Sede comunale del Comune di Romano d'Ezzelino — Via G: Giardino 1, 36060 Romano d'Ezzelino (VI).
# LLM output: 2016-05-24
# LLM input: Data: 14.6.2016 - 10:00|Luogo:|Sala consiliare palazzo municipale Comune di Salsomaggiore Terme — P.zza Libertà 1.|Persone ammesse ad assistere all'apertura delle offerte: no
# LLM output: 2016-06-14
# LLM input: Data: 25.5.2016 - 10:00|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti o soggetti |muniti di procura potranno richiedere inserimento di dichiarazioni nel verbale di gara.
# LLM output: 2016-05-25
# LLM input: Data: 26.5.2016 - 9:30|Luogo:|Palazzo Comunale P.zza Boccaccio 13 — 50052 Certaldo (FI).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Nelle sole sedute pubbliche il |legale rappresentante o persona munita di delega.
# LLM output: 2016-05-26
# LLM input: Data: 26.5.2016 - 9:30|Luogo:|Stanza n. 15, sita al IV Piano della Sede Centrale della Provincia di Fermo, 63900 Fermo, Viale Trento 113.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: 1 (uno) rappresentante per |ciascun operatore concorrente: il titolare, il legale rappresentante o il direttore tecnico ovvero un soggetto |diverso solo se munito di delega ai sensi di legge.
# LLM output: 2016-05-26
# LLM input: Data: 27.5.2016 - 10:00|Luogo:|Sala del Consiglio Comunale di Monfalcone, Piazza della Repubblica 25 — I piano.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti o |delegati.
# LLM output: 2016-05-27
# LLM input: Data: 16.5.2016 - 9:00|Luogo:|Comune di Occhiobello, Piazza Matteotti 15 — Sede Municipale.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti o |Procuratore munito di delega.
# LLM output: 2016-05-16
# LLM input: Data: 8.6.2016 - 10:00|Luogo:|Sede Centrale Unica di Committenza della Provincia di Piacenza — Corso Garibaldi 50 — 29121 Piacenza.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Vedasi disciplinare di gara.
# LLM output: 2016-06-08
# LLM input: Data: 14.6.2016 - 9:00|Luogo:|Sala Consiglio, Palazzo Municipale, Piazza B. Marin 4 — Grado (GO).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti o |delegati.
# LLM output: 2016-06-14
# LLM input: Data: 8.6.2016 - 9:00|Luogo:|Piattaforma START della Regione Toscana|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: La gara si svolge sul Sistema |Telematico Appalti della Regione Toscana.
# LLM output: 2016-06-08
# LLM input: Data: 27.5.2016 - 10:00|Luogo:|Palazzo Comunale- Arona|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legale rappresentante o suo |delegato.
# LLM output: 2016-05-27
# LLM input: Data: 17.5.2016 - 9:30|Luogo:|Sede della Provincia di Treviso — Stazione Unica Appaltante — Via Cal di Breda 116, Treviso.
# LLM output: 2016-05-17
# LLM input: Data: 19.5.2016 - 10:00|Luogo:|Sede del Centro Unico Appalti (C.U.A.) dell'Unione di Comuni Valdarno e Valdisieve — Via Tanzini 27– |Pontassieve (FI).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Il titolare o legale |rappresentante del soggetto concorrente o persona munita di specifica delega può assistere, in qualità di |uditore, alle sedute pubbliche di gara.
# LLM output: 2016-05-19
# LLM input: Data: 18.5.2016 - 9:30|Luogo:|Sede della Provincia di Treviso — Stazione Unica Appaltante — Via Cal di Breda 116 — Treviso.
# LLM output: 2016-05-18
# LLM input: Data: 1.6.2016 - 9:30|Luogo:|Presso una sala del Comune di Genova, Via Garibaldi 9.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-06-01
# LLM input: Data: 16.6.2016 - 9:00|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Sono ammesse ad assistere |tutte le persone interessate.
# LLM output: 2016-06-16
# LLM input: Data: 10/06/2016|Ora locale: 09:00
# LLM output: 2016-06-10
# LLM input: Data: 7.6.2016 - 10:00|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-06-07
# LLM input: Data: 22/06/2016|Ora locale: 09:30
# LLM output: 2016-06-22
# LLM input: Data: 06/07/2016|Ora locale: 15:00|Luogo:|Sede municipale di corso Paolino d'Aquileia 2 a Cividale del Friuli (UD).|Informazioni relative alle persone ammesse e alla procedura di apertura:|Un legale rappresentante per ciascuna delle ditte partecipanti ovvero loro rappresentante munito di apposita |delega (per i raggruppamenti temporanei di imprese è ammesso un solo rappresentante per ciascun |raggruppamento).
# LLM output: 2016-07-06
# LLM input: Data: 08/07/2016|Ora locale: 09:00|Luogo:|Palazzo Martinengo — Via Musei 32 — 25121, Brescia.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica.
# LLM output: 2016-07-08
# LLM input: Data: 29/06/2016|Ora locale: 10:00|Luogo:|Presso i locali della SAAV — Amministrazione Provinciale di Biella — Piazza Unità d'Italia — 13900 Biella.
# LLM output: 2016-06-29
# LLM input: Data: 4.7.2016 - 9:00|Luogo:|Sede comunale di Piazza Manzoni 17.
# LLM output: 2016-07-04
# LLM input: Data: 11.7.2016 - 10:00|Luogo:|Direzione Servizi Educativi.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti delle |Imprese o procuratore dei concorrenti.
# LLM output: 2016-07-11
# LLM input: Data: 13/07/2016|Ora locale: 10:00
# LLM output: 2016-07-13
# LLM input: Data: 12/07/2016|Ora locale: 14:00|Luogo:|Palazzo Martinengo — Via Musei 32 — 25121 Brescia.
# LLM output: 2016-07-12
# LLM input: Data: 27.6.2016 - 9:00|Luogo:|Presso la sede della Città Metropolitana di Genova, Piazzale Mazzini 2 — Sala gare.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: I soggetti che assistono alla |seduta di gara sono tenuti all'identificazione e alla registrazione della presenza. Possono rilasciare dichiarazioni |a verbale esclusivamente i soggetti muniti di idonei poteri di rappresentanza delle imprese partecipanti.
# LLM output: 2016-06-27
# LLM input: Data: 13.7.2016 - 15:00|Persone ammesse ad assistere all'apertura delle offerte: no
# LLM output: 2016-07-13
# LLM input: Data: 20/07/2016|Ora locale: 10:00|Luogo:|Provincia di Perugia, Via Palermo 21/C — 06124 Perugia.|Informazioni relative alle persone ammesse e alla procedura di apertura:|La prima seduta pubblica avrà luogo presso la sede della stazione unica appaltante, il 20.7.2016, ore 10:00, |fatte salve variazioni e differimenti che saranno comunicati a mezzo di avviso pubblicato sul portale della SUA. |Potranno partecipare i legali rappresentanti delle imprese interessate oppure persone munite di specifica |delega, loro conferita da suddetti legali rappresentanti.
# LLM output: 2016-07-20
# LLM input: Data: 14.7.2016 - 9:00|Luogo:|Comune di Piacenza, Piazza Cavalli 2.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali Rappresentanti delle |Ditte concorrenti ovvero soggetti, uno per concorrente, muniti di specifica delega loro conferita dai predetti |Legali Rappresentanti.
# LLM output: 2016-07-14
# LLM input: Data: 20/07/2016|Ora locale: 09:30
# LLM output: 2016-07-20
# LLM input: Data: 28.7.2016 - 10:00|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti o loro |delegati.
# LLM output: 2016-07-28
# LLM input: Data: 19/07/2016|Ora locale: 09:00|Luogo:|Sede dell'Unione «Val d'Enza» in Via XXIV Maggio 47, Barco di Bibbiano (RE) 42021.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Sono ammessi ad assistere alla seduta i legali rappresentanti dei concorrenti, ovvero i soggetti, muniti di |specifica delega in carta libera loro conferita dai suddetti rappresentanti.
# LLM output: 2016-07-19
# LLM input: Data: 29.7.2016 - 9:30|Luogo:|Sala consiliare Comune di Spilimbergo — Piazzetta Tiepolo 1, Spilimbergo (PN).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti.
# LLM output: 2016-07-29
# LLM input: Data: 27/07/2016|Ora locale: 10:00|Luogo:|Prima seduta pubblica presso la sede della Provincia di Como per l'apertura delle buste telematiche contenenti |la documentazione amministrativa e per l'ammissione alla fase di valutazione delle offerte tecniche.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Persone ammesse: Legale Rappresentante dell'Impresa concorrente o altri soggetti, uno per ogni concorrente, |muniti di specifica delega loro conferita dai legali rappresentanti.
# LLM output: 2016-07-27
# LLM input: Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: -1
# LLM input: Data: 22.7.2016 - 9:30|Luogo:|Sala Giunta, 3° piano della Sede Municipale di Via Roma 2 — Buccinasco (MI).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Si veda la documentazione di |gara.
# LLM output: 2016-07-22
# LLM input: Data: 2.8.2016 - 9:30|Luogo:|Ravenna.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti o loro |delegati.
# LLM output: 2016-08-02
# LLM input: Data: 22/07/2016|Ora locale: 14:00|Luogo:|Locate di Triulzi, Via Roma 9, sede della centrale unica di committenza.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica.
# LLM output: 2016-07-22
# LLM input: Data: 03/08/2016|Ora locale: 09:00|Luogo:|Palazzo Martinengo — Via Musei 32 — 25121 Brescia.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica.
# LLM output: 2016-08-03
# LLM input: Data: 27/07/2016|Ora locale: 15:00|Luogo:|Città metropolitana di Venezia — Via Forte Marghera 191 — Venezia-Mestre.
# LLM output: 2016-07-27
# LLM input: Data: 22/07/2016|Ora locale: 10:00
# LLM output: 2016-07-22
# LLM input: Data: 1.9.2016 - 10:00|Luogo:|Comune di Venegono Superiore.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Può presenziare alla gara il |legale rappresentante ovvero suo rappresentante munito di delega.
# LLM output: 2016-09-01
# LLM input: Data: 28.7.2016 - 9:30|Luogo:|Comune di Piacenza, Piazza Cavalli 2.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Rappresentanti legali delle ditte |concorrenti.
# LLM output: 2016-07-28
# LLM input: Data: 26.7.2016 - 15:00|Luogo:|Centrale Unica di Committenza — Vicolo S. Agostino 6/a — 44042 Cento (FE).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Si rimanda alla |documentazione di gara.
# LLM output: 2016-07-26
# LLM input: Data: 21.7.2016 - 9:00|Luogo:|https://start.e.toscana.it/rtrt/  e Comune di Seravezza, Via XXIV Maggio 22 — 55047 Seravezza (LU).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Sono ammessi ad intervenire |esclusivamente il titolare, il legale rappresentante o persona da questi delegata, dell'impresa partecipante; ciò |dovrà essere comprovato da apposita dichiarazione redatta ai sensi del DPR n. 445/2000.
# LLM output: 2016-07-21
# LLM input: Data: 3.8.2016 - 9:00|Luogo:|Sede della Comunità Montana dei Laghi Bergamaschi a Lovere, Via del Cantiere 4.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Rappresentanti dei concorrenti, |debitamente identificati.
# LLM output: 2016-08-03
# LLM input: Data: 10/08/2016|Ora locale: 09:00|Luogo:|Via Galliari 50 — Andorno Micca — la data potrà essere oggetto di variazione che verrà comunicata ai |partecipanti via PEC.
# LLM output: 2016-08-10
# LLM input: Data: 3.8.2016 - 10:00|Luogo:|Sassuolo, Via Fenuzzi 5.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: La seduta di gara è |pubblica, ma la facoltà di rilasciare dichiarazioni e di interloquire durante le operazioni di gara è riconosciuta |esclusivamente ai legali rappresentanti delle imprese concorrenti e ai loro delegati, muniti di procura scritta, |previa autorizzazione dell'organo di gara.|Per le altre sedute, si veda disciplinare di gara.
# LLM output: 2016-08-03
# LLM input: Data: 2.8.2016 - 10:00|Luogo:|Comune di Livorno Piazza del Municipio 1, sala Contratti, 2° piano Palazzo Vecchio.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-08-02
# LLM input: Data: 04/08/2016|Ora locale: 09:00|Luogo:|Piazza della Libertà 6, 42019 Scandiano (Sala Giunta).|Informazioni relative alle persone ammesse e alla procedura di apertura:|Le offerte pervenute saranno aperte in seduta pubblica. Chiunque può assistere all'apertura delle buste. |Sono verbalizzate e riferite direttamente al concorrente le sole dichiarazioni dei rappresentanti delle ditte che |partecipano alle operazioni di gara per mezzo di un rappresentante e/o delegato, munito di delega ad hoc o |rivestito di una specifica carica sociale.
# LLM output: 2016-08-04
# LLM input: Data: 19/08/2016|Ora locale: 09:30
# LLM output: 2016-08-19
# LLM input: Data: 29/08/2016|Ora locale: 09:30|Luogo:|Comune di Cernusco sul Naviglio — Via Tizzoni 2 — 20063 Cernusco sul Naviglio (MI).|Informazioni relative alle persone ammesse e alla procedura di apertura:|Tutti gli interessati.
# LLM output: 2016-08-29
# LLM input: Data: 12/08/2016|Ora locale: 09:00|Luogo:|Unione Romagna Faentina — Stazione Appaltante — Unità Contratti/Gare.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica.
# LLM output: 2016-08-12
# LLM input: Data: 9.8.2016 - 10:00|Luogo:|Piazza della Pace 4 — Vergato (BO)|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti dei |concorrenti o loro procuratori o delegati, purchè muniti di procura o delega scritta e di documento di identità |valido. È ammessa la presenza di una sola persona in rappresentanza di una unica ditta concorrente.
# LLM output: 2016-08-09
# LLM input: Data: 02/08/2016|Ora locale: 10:00|Luogo:|Presso una sala del Comune di Genova (Palazzo Albini — II° piano — sala riunioni).|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica.
# LLM output: 2016-08-02
# LLM input: Data: 11/08/2016|Ora locale: 09:00|Luogo:|Piazza della Libertà 6, 42019 Scandiano (Sala Giunta) Le offerte pervenute saranno aperte in seduta pubblica. |Il concorrente, presente alle operazioni di gara per mezzo di proprio rappresentante, è considerato pienamente |a conoscenza delle determinazioni del seggio di gara assunte e comunicate in tale sede.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Chiunque può assistere all'apertura delle buste. Sono verbalizzate e riferite direttamente al concorrente |le sole dichiarazioni dei rappresentanti delle ditte che partecipano alle operazioni di gara per mezzo di un |rappresentante e/o delegato, munito di delega ad hoc o rivestito di una specifica carica sociale.
# LLM output: 2016-08-11
# LLM input: Data: 13/09/2016|Ora locale: 09:30|Luogo:|Sala del Comune di Genova (Palazzo Albini — II° piano — sala riunioni).|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica.
# LLM output: 2016-09-13
# LLM input: Data: 08/09/2016|Ora locale: 10:00|Luogo:|Civica Residenza — Piazza del Popolo 1 — Pesaro.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica.
# LLM output: 2016-09-08
# LLM input: Data: 29.7.2016 - 9:30|Luogo:|Piazza Palazzo di Città 1 — Torino (presso una Sala del Civico Palazzo).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-07-29
# LLM input: Data: 23/08/2016|Ora locale: 10:00|Luogo:|Comune di Lentate sul Seveso — Via Matteotti 8 — 20823 Lentate sul Seveso (MB).|Informazioni relative alle persone ammesse e alla procedura di apertura:|Alle sedute aperte al pubblico potrà assistere un incaricato di ciascun concorrente dotato di opportuna delega.
# LLM output: 2016-08-23
# LLM input: Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti.
# LLM output: -1
# LLM input: Data: 2.8.2016 - 10:00|Luogo:|Presso i locali dell'Unione Montana dei Comuni del Mugello — Via Togliatti 45 — 50032 Borgo San Lorenzo |(FI).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Può assistere in qualità di |uditore il titolare o legale rappresentante del soggetto concorrente ovvero persone munite di specifica delega |fornita dallo stesso.
# LLM output: 2016-08-02
# LLM input: Data: 24/08/2016|Ora locale: 14:00|Luogo:|Comune di Locate di Triulzi, Via Roma 9 (sede della CUC).|Informazioni relative alle persone ammesse e alla procedura di apertura:|Vedi disciplinare.
# LLM output: 2016-08-24
# LLM input: Data: 31/08/2016|Ora locale: 10:00|Luogo:|Comune di Latina — Servizio Gare e Contratti — Sala Commissioni di Gara.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Per maggiori informazioni si prega di visionare il disciplinare di gara e il CSA.
# LLM output: 2016-08-31
# LLM input: Data: 14/09/2016|Ora locale: 9:30|Luogo:|Palazzo Municipale del Comune di Fossano.
# LLM output: 2016-09-14
# LLM input: Data: 30.8.2016 - 8:30|Luogo:|Comune di Pramaggiore — Ufficio Tecnico, Piazza Libertà 5 / int. 5 — 30020 Pramaggiore (VE)
# LLM output: 2016-08-30
# LLM input: Data: 01/09/2016|Ora locale: 9:00
# LLM output: 2016-09-01
# LLM input: Data: 02/09/2016|Ora locale: 12:00|Luogo:|Comune di Velletri di Piazza Cesare Ottaviano Augusto 1.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Si rimanda al disciplinare di gara.
# LLM output: 2016-09-02
# LLM input: Data: 12.10.2016 - 9:30|Luogo:|Piazza Palazzo di Città 1 — Torino (presso una sala del Civico Palazzo).|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Seduta pubblica.
# LLM output: 2016-10-12
# LLM input: Data: 2.9.2016 - 9:30|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali Rappresentanti o loro |delegati muniti di delega.
# LLM output: 2016-09-02
# LLM input: Data: 23/08/2016|Ora locale: 09:00|Luogo:|Unione Montana Alpi del Mare c/o Comune di Boves — Piazza Italia 64 — 12012, Boves.
# LLM output: 2016-08-23
# LLM input: Data: 23/08/2016|Ora locale: 9:30|Luogo:|Unione Montana Alpi del Mare c/o Comune di Boves — Piazza Italia 64 — 12012 Boves.
# LLM output: 2016-08-23
# LLM input: Data: 05/10/2016|Ora locale: 9:00|Luogo:|Sede della ATS Città Metropolitana di Milano — Corso Italia 19, piano IV — 20122 Milano.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Rappresentanti degli operatori economici partecipanti muniti di apposita delega.
# LLM output: 2016-10-05
# LLM input: Data: 13.9.2016 - 10:30|Luogo:|Comune di Scarlino.|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legale rappresentante o |persona munita di specifica delega.
# LLM output: 2016-09-13
# LLM input: Data: 20/09/2016|Ora locale: 09:00|Luogo:|C/o l'ufficio della Centrale Unica di Committenza del Comune di Rosignano Marittimo in Via Gramsci 80, |Rosignano Marittimo.|Informazioni relative alle persone ammesse e alla procedura di apertura:|La seduta di apertura delle buste virtuali è pubblica; si specifica, tuttavia che solo i titolari o i legali rappresentati |dei partecipanti o persone munite di procura speciale avranno diritto di parola e di chiedere dichiarazioni a |verbale.
# LLM output: 2016-09-20
# LLM input: Data: 21/11/2016|Ora locale: 09:30|Luogo:|Via della Panetteria 18/18/A — 00187 Roma.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Senza alcuna limitazione.
# LLM output: 2016-11-21
# LLM input: Data: 21.9.2016 - 11:00|Luogo:|Servizio Patrimonio e Provveditorato — Piazza della Libertà 1 — Arezzo|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: I legali rappresentanti o altri |soggetti muniti di idoneo documento comprovante la legittimazione ad agire in nome e per conto delle imprese |concorrenti.
# LLM output: 2016-09-21
# LLM input: Data: 12/10/2016|Ora locale: 10:00|Luogo:|Civica Residenza — Piazza del Popolo 1 — Pesaro.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica.
# LLM output: 2016-10-12
# LLM input: Data: 14/09/2016|Ora locale: 9:00|Luogo:|C/o Ufficio della Centrale Unica di Committenza del Comune di Rosignano Marittimo in Via Gramsci 80, |Rosignano Marittimo.|Informazioni relative alle persone ammesse e alla procedura di apertura:|La seduta di apertura delle buste virtuali è pubblica; si specifica che solo i titolari o i legali rappresentanti dei |partecipanti o persone munite di procura speciale avranno diritto di parola e di chiedere dichiarazioni a verbale.
# LLM output: 2016-09-14
# LLM input: Data: 29/09/2016|Ora locale: 9:30
# LLM output: 2016-09-29
# LLM input: Data: 29/09/2016|Ora locale: 10:00|Luogo:|Prima seduta pubblica presso la sede della Provincia di Como, Via Borgo Vico 148 — 22100 Como.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Persone ammesse: Legale Rappresentante dell'Impresa concorrente o altri soggetti, uno per ogni concorrente, |muniti di specifica delega loro conferita dai legali rappresentanti.
# LLM output: 2016-09-29
# LLM input: Data: 6.10.2016 - 15:00|Luogo:|Piazza Cavalli 2|Persone ammesse ad assistere all'apertura delle offerte: sì|Informazioni complementari sulle persone ammesse e la procedura di apertura: Legali rappresentanti delle ditte |concorrenti o persone delegate.
# LLM output: 2016-10-06
# LLM input: Data: 27/09/2016|Ora locale: 9:00|Luogo:|Presso la sede della stazione appaltante e sarà espletata da apposita commissione di gara.|Informazioni relative alle persone ammesse e alla procedura di apertura:|I legali rappresentanti dei concorrenti, ovvero soggetti, uno per ogni concorrente, muniti di specifica delega loro |conferita dai suddetti legali rappresentanti.
# LLM output: 2016-09-27
# LLM input: Data: 28/09/2016|Ora locale: 9:00|Luogo:|Presso la sede della stazione appaltante e sarà espletata da apposita commissione di gara.|Informazioni relative alle persone ammesse e alla procedura di apertura:|I legali rappresentanti dei concorrenti, ovvero soggetti, uno per ogni concorrente, muniti di specifica delega loro |conferita dai suddetti legali rappresentanti.
# LLM output: 2016-09-28
# ...
# LLM output: 2020-10-29
# LLM input: Data: 02/11/2020|Ora locale: 09:30|Luogo:|Videoconferenza da remoto.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Le sedute non sono pubbliche.
# LLM output: 2020-11-02
# LLM input: Data: 05/11/2020|Ora locale: 10:00|Luogo:|Comune di Pescara — settore Gare e contratti — servizio Procedure ordinarie di gara.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica.
# LLM output: 2020-11-05
# LLM input: Data: 30/11/2020|Ora locale: 10:30|Luogo:|Comune di Agnone, via G. Verdi 9 — 86081, Agnone (IS)|Informazioni relative alle persone ammesse e alla procedura di apertura:|Ciascun concorrente può assistere per il tramite di un solo rappresentante in persona del proprio |rappresentante legale ovvero di persona munita di delega appositamente conferita.
# LLM output: 2020-11-30
# LLM input: Data: 25/11/2020|Ora locale: 09:00|Luogo:|Comune di Corato — ufficio Contratti e appalti.
# LLM output: 2020-11-25
# LLM input: Data: 11/11/2020|Ora locale: 10:00
# LLM output: 2020-11-11
# LLM input: Data: 05/11/2020|Ora locale: 15:00
# LLM output: 2020-11-05
# LLM input: Data: 02/12/2020|Ora locale: 10:00|Informazioni relative alle persone ammesse e alla procedura di apertura:|Data indicativa. La data definitiva verrà comunicata sul portale o tramite PEC successivamente.
# LLM output: 2020-12-02
# LLM input: Data: 24/11/2020|Ora locale: 10:00
# LLM output: 2020-11-24
# LLM input: Data: 26/12/2020|Ora locale: 10:00|Luogo:|Presso la sede stazione appaltante|Le operazioni di gara potranno essere aggiornate ad altra ora o ai giorni successivi e le successive eventuali |sedute pubbliche avranno luogo presso la medesima sede all’orario e giorno, che sarà comunicato con congruo |preavviso ai concorrenti per il tramite della piattaforma.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Potranno partecipare i legali rappresentanti delle imprese interessate oppure persone munite di specifica |delega, loro conferita da suddetti legali rappresentanti.
# LLM output: 2020-12-26
# LLM input: Data: 03/12/2020|Ora locale: 09:05
# LLM output: 2020-12-03
# LLM input: Data: 10/12/2020|Ora locale: 09:00|Luogo:|Sede municipale in Siziano, piazza Giacomo Negri 1, 1o piano.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Alla prima seduta, nonché alle successive sedute aperte al pubblico, potranno assistere i legali rappresentanti/|procuratori delle imprese interessate oppure persone munite di specifica delega.
# LLM output: 2020-12-10
# LLM input: Data: 01/12/2020|Ora locale: 09:30|Luogo:|La data sopraindicata è da ritenersi indicativa. Quella effettiva della prima seduta sarà pubblicata con avviso sul |portale dell’ente nella sezione «News».|La prima seduta pubblica di selezione avrà luogo presso gli uffici del VI settore del Libero consorzio comunale di |Caltanissetta — via Enrico De Nicola s.n.
# LLM output: 2020-12-01
# LLM input: Data: 10/12/2020|Ora locale: 10:00
# LLM output: 2020-12-10
# LLM input: Data: 27/11/2020|Ora locale: 10:00
# LLM output: 2020-11-27
# LLM input: Data: 04/12/2020|Ora locale: 10:00|Luogo:|Comune di Marsala, via G. Falcone 5, sede del settore Servizi alla persona.|La data di apertura delle buste è condizionata dalla nomina della commissione giudicatrice, ai sensi del |combinato disposto dell’art. 77 del codice, comma 12 e dell’art. 8 della L.R. n. 12 del 2011, modificato dalla |L.R. n. 8 del 2016, e da ultimo dalla L.R. n. 1 del 2017 e dal regolamento D.P.R.S. n. 13 del 2012, pertanto può |subire variazioni.
# LLM output: 2020-12-04
# LLM input: Data: 04/12/2020|Ora locale: 12:00|Luogo:|Comune di Marsala, via G. Falcone 5, sede del settore Servizi alla persona. La data di apertura delle buste |è condizionata dalla nomina della commissione giudicatrice, ai sensi del combinato disposto dell’art. 77 del |codice, comma 12 e dell’art. 8 del L.R. n. 12 del 2011 modificato dalla L.R. n. 8 del 2016 e da ultimo dalla L.R. |n. 1/2017 e dal regolamento D.P.R.S. n. 13 del 2012 (art. 12), pertanto può subire variazioni.
# LLM output: 2020-12-04
# LLM input: Data: 23/11/2020|Ora locale: 16:00|Luogo:|Presso la sede comunale della città di Campi Salentina e più precisamente all’interno del portale telematico:|https://cucnordsalento.tuttogare.it/gare/id25059-dettagli|Le modalità e le date relative alle successive sedute e valutazione delle offerte sono specificate nel disciplinare |di gara e saranno rese note mediante PEC e con avvisi pubblici.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Tuttavia si precisa nel presente che questa amministrazione non intende esaminare le offerte prima della |verifica della documentazione relativa al possesso dei requisiti di carattere generale e di quelli di idoneità e |di capacità degli offerenti come previsto dall’art. 1, comma 3 della Legge n. 55/2019 (di conv. del D.Lgs. n. |32/2019).
# LLM output: 2020-11-23
# LLM input: Data: 30/11/2020|Ora locale: 09:30
# LLM output: 2020-11-30
# LLM input: Data: 30/11/2020|Ora locale: 16:00
# LLM output: 2020-11-30
# LLM input: Data: 17/12/2020|Ora locale: 09:00
# LLM output: 2020-12-17
# LLM input: Data: 16/12/2020|Ora locale: 09:00|Luogo:|Corato.
# LLM output: 2020-12-16
# LLM input: Data: 09/12/2020|Ora locale: 10:01|Luogo:|La seduta per l'apertura delle offerte si svolgerà in maniera riservata sia in quanto la procedura si svolge |in modalità telematica sia in considerazione della necessità di evitare assembramenti a causa della attuale |emergenza sanitaria.
# LLM output: 2020-12-09
# LLM input: Data: 12/01/2021|Ora locale: 15:00
# LLM output: 2021-01-12
# LLM input: Data: 15/12/2020|Ora locale: 14:30|Luogo:|la prima seduta pubblica avrà luogo presso la sede di piazza Liber Paradisus 10, torre B, piano 0 e si svolgerà |in modalità virtuale attraverso la piattaforma Sater.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Gli operatori economici partecipanti alla procedura di gara che abbiano presentato offerta potranno visualizzare |l’andamento dell’attività di verifica della documentazione amministrativa, seguendo le istruzioni riportate |nell’apposita guida per l’utilizzo della piattaforma, accessibili dal sito: http://intercenter.regione.emilia-romagna.it/|agenzia/utilizzo-del-sistema/guide/
# LLM output: 2020-12-15
# LLM input: Data: 10/12/2020|Ora locale: 11:00|Luogo:|Tenuto conto dell’attuale situazione di emergenza e delle restrizioni previste dai provvedimenti emanati dal |Presidente del Consiglio dei ministri, tutte le sedute pubbliche di gara si svolgeranno a porte chiuse in modalità |telematica mediante l’avvio di apposita videoconferenza.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Si fa presente che la partecipazione alla seduta potrà avvenire esclusivamente da remoto — su:|www.provincia.bergamo.it  — www.ariaspa.it
# LLM output: 2020-12-10
# LLM input: Data: 11/12/2020|Ora locale: 11:00|Luogo:|Presso la sede stazione appaltante in p.za Margherita di Savoia.|Potranno partecipare i legali rappresentanti delle imprese interessate oppure persone munite di specifica |delega, loro conferita da suddetti legali rappresentanti. Causa l’emergenza sanitaria le sedute pubbliche si |svolgeranno con collegamento da remoto.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Le operazioni di gara potranno essere aggiornate ad altra ora o ai giorni successivi e le successive eventuali |sedute pubbliche avranno luogo presso la medesima sede all’orario e giorno che sarà comunicato con congruo |preavviso ai concorrenti per il tramite della piattaforma.
# LLM output: 2020-12-11
# LLM input: Data: 07/01/2021|Ora locale: 15:30|Luogo:|Piazza Eleonora d'Arborea, Oristano.
# LLM output: 2021-01-07
# LLM input: Data: 12/01/2021|Ora locale: 09:30|Luogo:|Regione Toscana — uffici della Giunta regionale — via di Novoli 26, III piano, Palazzo A, stanza 334, Firenze|Informazioni relative alle persone ammesse e alla procedura di apertura:|Titolare o legale rappresentante del soggetto concorrente o persona munita di specifica delega
# LLM output: 2021-01-12
# LLM input: Data: 18/12/2020|Ora locale: 15:00|Luogo:|Via Solferino 11 — Castelfranco di Sotto (PI), ovvero con collegamento telematico.|Informazioni relative alle persone ammesse e alla procedura di apertura:|N. 2 persone.
# LLM output: 2020-12-18
# LLM input: Data: 21/12/2020|Ora locale: 09:30
# LLM output: 2020-12-21
# LLM input: Data: 21/12/2020|Ora locale: 10:05
# LLM output: 2020-12-21
# LLM input: Data: 27/01/2021|Ora locale: 09:30|Luogo:|Torino, sala Gare telematiche, piazza Palazzo di Città 1 – piano terra.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Persone ammesse ad assistere all'apertura delle offerte: sì, nel rispetto delle norme Anticovid.
# LLM output: 2021-01-27
# LLM input: Data: 27/01/2021|Ora locale: 10:30|Luogo:|In ottemperanza alle misure di contenimento e gestione della emergenza epidemiologica da covid-19 e in |ossequio alla delibera ANAC n. 312 del 9.4.2020, la centrale regionale di committenza effettuerà le sedute |pubbliche in video conferenza, secondo le modalità descritte al paragrafo 22 del disciplinare di gara.
# LLM output: 2021-01-27
# LLM input: Data: 05/02/2021|Ora locale: 10:00|Luogo:|Palazzo comunale, p.zza Crivelli Serbelloni 1, Luino.
# LLM output: 2021-02-05
# LLM input: Data: 04/02/2021|Ora locale: 10:00|Luogo:|Poiché la piattaforma Sintel garantisce l’identificazione, la segretezza e l’inalterabilità dell’offerta, l’apertura delle |buste telematiche avverrà in sedute riservate.
# LLM output: 2021-02-04
# LLM input: Data: 08/02/2021|Ora locale: 09:30|Luogo:|Vedi documentazione di gara.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Vedi documentazione di gara.
# LLM output: 2021-02-08
# LLM input: Data: 16/02/2021|Ora locale: 09:00|Luogo:|Sala Giunta del Comune di Catanzaro sita in via Jannoni 68 — 88100, Catanzaro. La modalità di partecipazione |alle sedute pubbliche potrà subire delle modificazioni in dipendenza dell’obbligo di attuazione delle misure |precauzionali, previste dal legislatore, per contrastare e contenere il diffondersi del Covid-19.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Potranno partecipare i legali rappresentanti/procuratori delle imprese interessate oppure persone munite di |specifica delega. In assenza di tali titoli, la partecipazione è ammessa come semplice uditore.
# LLM output: 2021-02-16
# LLM input: Data: 18/02/2021|Ora locale: 09:30
# LLM output: 2021-02-18
# LLM input: Data: 25/03/2021|Ora locale: 10:00|Luogo:|ufficio Gare e procedure di gara
# LLM output: 2021-03-25
# LLM input: Data: 30/03/2021|Ora locale: 10:00|Luogo:|ufficio Gare e procedure di gara
# LLM output: 2021-03-30
# LLM input: Data: 25/02/2021|Ora locale: 14:00
# LLM output: 2021-02-25
# LLM input: Data: 04/03/2021|Ora locale: 13:00|Luogo:|Foligno
# LLM output: 2021-03-04
# LLM input: Data: 12/04/2021|Ora locale: 09:30|Luogo:|piazza Folegatti 15, Comacchio (FE), ITALIA. La procedura di gara sarà svolta in modalità telematica |tramite il portale della Regione Emilia-Romagna Sater accessibile tramite l'indirizzo Internet: https://|piattaformaintercenter.regione.emilia-romagna.it/portale_ic/
# LLM output: 2021-04-12
# LLM input: Data: 07/05/2021|Ora locale: 10:00
# LLM output: 2021-05-07
# LLM input: Data: 21/04/2021|Ora locale: 08:30|Luogo:|Servizio appalti acquisti dell'Unione dei comuni della bassa Romagna — piazza dei Martiri 1, 48022, Lugo (RA).|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica virtuale.
# LLM output: 2021-04-21
# LLM input: Data: 07/05/2021|Ora locale: 10:30
# LLM output: 2021-05-07
# LLM input: Data: 18/05/2021|Ora locale: 14:30
# LLM output: 2021-05-18
# LLM input: Data: 26/05/2021|Ora locale: 13:00
# LLM output: 2021-05-26
# LLM input: Data: 10/06/2021|Ora locale: 14:30|Luogo:|Apertura telematica della busta contenente la documentazione amministrativa.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Nessuna; apertura telematica su piattaforma Sintel gestita da Aria SpA.
# LLM output: 2021-06-10
# LLM input: Data: 09/06/2021|Ora locale: 14:00|Luogo:|Torino, Sala gare telematiche, piazza Palazzo di Città 1 — piano terra|Informazioni relative alle persone ammesse e alla procedura di apertura:|Seduta pubblica nel rispetto delle norme Anticovid.
# LLM output: 2021-06-09
# LLM input: Data: 19/07/2021|Ora locale: 13:00|Luogo:|Sala riunioni c/o via Bacaredda 184, Cagliari, 09127, l'apertura delle offerte avverrà sulla piattaforma telematica |SardegnaCAT.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Ad ogni seduta potrà assistere un incaricato di ciascuna impresa concorrente con mandato di rappresentanza |oprocura attestante i poteri di rappresentare l'impresa e munito di un documento di riconoscimento.
# LLM output: 2021-07-19
# LLM input: Data: 22/06/2021|Ora locale: 10:00|Luogo:|L'Aquila, via Monte Cagno 3.|L'amministrazione si riserva la facoltà di effettuare le sedute pubbliche su piattaforma telematica, per cui |verranno inviate le credenziali di accesso ai soggetti partecipanti.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Legali rappresentanti/procuratori delle imprese interessate oppure persone munite di specifica delega. In |assenza di tali titoli, la partecipazione è ammessa come semplice uditore.
# LLM output: 2021-06-22
# LLM input: Data: 30/06/2021|Ora locale: 09:00|Luogo:|Via Lionello 1, Udine, o telematicamente.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Procedura di gara gestita con sistemi telematici ai sensi dell'art 58 del D.Lgs. 50/2016.
# LLM output: 2021-06-30
# LLM input: Data: 14/07/2021|Ora locale: 09:00|Luogo:|Comune di Palermo, via Roma 209.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Per maggiori informazioni visitare il sito istituzionale https://portaleappalti.comune.palermo.it/PortaleAppalti/it/|homepage.wp .
# LLM output: 2021-07-14
# LLM input: Data: 27/07/2021|Ora locale: 09:30|Luogo:|La prima seduta pubblica sarà svolta telematicamente.|Informazioni relative alle persone ammesse e alla procedura di apertura:|Vi potranno partecipare i legali rappresentanti/procuratori delle imprese interessate oppure persone munite di |specifica delega.
# LLM output: 2021-07-27
# LLM input: Data: 29/07/2021|Ora locale: 10:00|Luogo:|sede municipale — modalità telematica
# LLM output: 2021-07-29
# LLM input: Data: 02/08/2021|Ora locale: 13:00|Luogo:|Sede municipale piazza Costituzione 4, 37047 — San Bonifacio (VR) — 1o piano.
# LLM output: 2021-08-02
# LLM input: Data: 16/08/2021|Ora locale: 10:00|Luogo:|sede comunale San Bonifacio - primo piano
# LLM output: 2021-08-16
# LLM input: Data: 21/10/2021|Ora locale: 10:30
# LLM output: 2021-10-21
# LLM input: Data: 11/11/2021|Ora locale: 12:00|Luogo:|Si veda disciplinare di gara
# LLM output: 2021-11-11
# LLM input: Data: 19/01/2022|Ora locale: 12:00
# LLM output: 2022-01-19
# LLM input: Data: 26/05/2022|Ora locale: 10:00|Luogo:|seduta pubblica virtuale|Informazioni relative alle persone ammesse e alla procedura di apertura:|le sedute pubbliche saranno effettuate attraverso la piattaforma SATER in modalità virtuale come da disciplinare
# LLM output: 2022-05-26
# LLM input: Data: 31/05/2022|Ora locale: 14:30|Luogo:|seduta pubblica virtuale|Informazioni relative alle persone ammesse e alla procedura di apertura:|le sedute pubbliche saranno effettuate attraverso la piattaforma SATER in modalità virtuale come da disciplinare
# LLM output: 2022-05-31
# LLM input: Data: 23/08/2022|Ora locale: 14:00|Luogo:|Comune di Garlasco|Informazioni relative alle persone ammesse e alla procedura di apertura:|legali rappresentanti o loro delegati
# LLM output: 2022-08-23

# %%
print(">> New data obtained from LLM")
# df_bid_text['date'].fillna("-1", inplace=True)
# Replace empty cells (not found) with -1
df_bid_text.loc[df_bid_text['date'].isna(), 'date'] = "-1"
print(df_bid_text.columns)
print(df_bid_text.head())
print()
# Out:
# >> New data obtained from LLM
# Index(['file_name', 'text', 'date'], dtype='object')
#                    file_name  \
# 0  2016-OJS003-002872-it.pdf
# 1  2016-OJS004-004078-it.pdf
# 2  2016-OJS008-009964-it.pdf
# 3  2016-OJS011-015326-it.pdf
# 4  2016-OJS012-017147-it.pdf
#
#                                                 text        date
# 0  Data: 25.2.2016 - 9:00|Luogo:|Provincia di Var...  2016-02-25
# 1                                                NaN          -1
# 2  Data: 25.2.2016 - 9:30|Luogo:|Comune di Piacen...  2016-02-25
# 3  Data: 11.3.2016 - 9:00|Luogo:|Settore Gare e A...  2016-03-11
# 4  Data: 4.3.2016 - 10:00|Persone ammesse ad assi...  2016-03-04

# %%
# Create a file with the texts extracted from the PDFs
print(">> Saving bid opening texts and dates")
print("Dataframe with dates shape:", df_bid_text.shape)  # should be same shape as df_label
path_out = Path(data_dir) / bid_file_text_date
print("Path:", path_out)
df_bid_text.to_csv(path_out, sep=csv_sep, index=False, quoting=csv.QUOTE_ALL)
# Out:
# >> Saving bid opening texts and dates
# Dataframe with dates shape: (1063, 3)
# Path: data/bid_opening_text_date.csv

# %%
# Checking accuracy against the annotated dataset
print(">> Checking accuracy against the annotated dataset")
path_csv_label = Path(data_dir) / bid_file_text_date_label
print("Path:", path_csv_label)
dic_type = {"file_name":object, "text":object, "label":object}
df_label = read_csv_data_to_df(path_csv_label, dic_type, csv_sep)
print("Dataframe with labels shape:", df_label.shape) # should be same shape as df_bid_text
# Convert labels
df_label['label_ymd'] = df_label['label'].apply(convert_dmy_to_ymd)
# Replace empty cells (not found) with -1
df_label.loc[df_label['label_ymd'].isna(), 'label_ymd'] = "-1"

# Gets dates in list format to compare them (removing not found -> -1)
df_bid_text = df_bid_text[df_bid_text['date'] != "-1"]
llm_dates_list = df_bid_text['date'].tolist()
print("Dates from LLM list length:", len(llm_dates_list)) # should be same length as label_dates_list

df_label = df_label[df_label['label_ymd'] != "-1"]
label_dates_list = df_label['label_ymd'].tolist()
print("Dates from LABELS list length:", len(label_dates_list))  # should be same length as llm_dates_list
# Out:
# >> Checking accuracy against the annotated dataset
# Path: data/bid_opening_text_date_label.csv
# Dataframe with labels shape: (1063, 3)
# Dates from LLM list length: 993
# Dates from LABELS list length: 993

# %%
# Computing precision
correct_dates = [date in label_dates_list for date in llm_dates_list]
accuracy = sum(correct_dates) / len(correct_dates) if correct_dates else 0
print(f"Precision: {accuracy * 100:.2f}%")
# Out:
# Precision: 99.50%

# %%
# program end
end_time = datetime.now().replace(microsecond=0)
delta_time = end_time - start_time

print()
print("End process:", end_time)
print("Time to finish:", delta_time)
print()

print()
print("*** PROGRAM END ***")
print()
# Out:
# End process: 2024-05-09 12:24:05
# Time to finish: 0:15:29
#
#
# *** PROGRAM END ***
